# %% [markdown]
# # Satellite Image ConvLSTM Implementation - Durban

# %% [markdown]
# #### For more in depth information behind the motivations of our project, see our various slides and presentations presented at various conferences:
#
# **Slides**:
# - [NASA Presentation Slides](https://canvas.eee.uci.edu/)
# - [CSCI Presentation Slides](https://drive.google.com/file/d/1YK35WO9B00qktuG20KeXM3f4Cs9j4L8b/view?usp=sharing)
# - [ICDATA Presentation Slides](https://drive.google.com/file/d/1rVPlbLMHuCNLStV22K25Eh7RgGrViy3j/view?usp=sharing)
#
#
# **Presentations**:
# - [CSCI Presentation Video](https://youtu.be/2wLF1Szf3Gs)
# - [ICDATA Presentation Video](https://youtu.be/Bd_JWHaKdYQ)

# %% [markdown]
# ## Goal
# Our model seeks to predict hourly spatiotemporal air pollution around Durban over multiple time periods. We utilize input data from various sources to accurately predict PM2.5 spatially continously. In this Jupyter Notebook, we will be focusing on predicting PM2.5.
#
# ## Input Data:
#
# We utilize data from four major sources:
#    - Ground-level air pollution sensor data
#    - Remote-sensing satellite imagery
#    - Wildfire/smoke data
#    - Meteorological/Geographical sensor data
#
# ## Data Parameters:
#    For all data used in the model, we utilized the following temporal and geographic bounds:
#    - *Temporal Bounds*:
#        Hourly spaced data from January 1 2019 - December 31 2021. In total, there are 26304 time steps (24 hours * (365 + 365 + 366 days))
#    - *Geographic Bounds*: We selected an area of roughly 400 mi^2 (20mi by 20mi square) or 900 km^2 of Durban as our geographical boundaries for input data and prediction. For ground level sensor data, we used any sensors within the geographical boundaries, while for remote-sensing satellite imagery, we cropped the remote sensing satellite imagery to fit the geographical boundary we have defined.
#
# ![Area](Images/durbanBounds.png)
#
# ## Data Sources
#
# **Ground-level air pollution sensor data**
#
# We utilize ground level air pollution data of 4 sensors around Durban providing hourly information on 2 air pollutants: PM10 and PM2.5.
#
# **Remote-sensing Satellite Imagery**

# %% [markdown]
# We use remote-sensing satellite imagery from the NASA MODIS MAIAC AOD datasource and the NASA TROPOMI datasource. The MAIAC AOD imagery provides hourly Aerosol Optical Depth (AOD) imagery over our specified geographic bounds, while TROPOMI provides hourly atmospheric pollutant imagery. We use a combination of these data sources in our model.
#
# The NASA Multi-Angle Implementation of Atmospheric Correction (MAIAC), as the name suggests, accomplishes atmospheric correction via a new method that is encoded in a generic algorithm designed to work with Moderate Resolution Imaging Spectroradiometer (MODIS) data to facilitate deriving both aerosol and land surface reflectance products.
#
# We collect remote-sensing satellite imagery from the NASA TROPOMI instrument onboard the Sentinel-5P satellite launched on October 13, 2017, orbiting at a height of 512 miles above sea level, with an orbital swath of 2600 km, and a mission length of 7 years (2017 - 2024).
#
# The Sentinel-5P TROPOspheric Monitoring Instrument (TROPOMI) is a spectrometer capable of sensing ultraviolet (UV), visible (VIS), near (NIR) and short-wavelength infrared (SWIR) light. TROPOMI provides high resolution global hourly images of atmospheric ozone, methane, formaldehyde, aerosol, carbon monoxide, nitrogen dioxide, and sulfur dioxide.
#
# TROPOMI measures in the ultraviolet and visible (270–500 nm), near-infrared (675–775 nm) and shortwave infrared (2305–2385 nm) spectral bands.
#
# In this Jupyter Notebook, we used the TROPOMI imagery of methane, nitrogen dioxide, and carbon monoxide. Although we seek to predict ground-based PM2.5, we find that including data of similar atmospheric air pollutants improves the effectiveness of the model.

# %% [markdown]
# From each of the 13 sensor locations, we collect the following meteorological information:
# - Wind Speed (mph)
# - Wind Direction (deg)
# - Precipitation (inch)
# - AQI
# - Relative Humidity (%)
# - Heat Index/Wind Chill (F)
# - Air Temperature (F)
# - Air Pressure (mb)
# - Dew Point (F)
#
# In order to utilize these meteorological features in combination within the model, we normalized the units of measure for each of these metrics by instead calculating each data point's percentile value. The percentile value is calculated daily and essentially is the current hour's raw value divided by the metric's maximum daily value of the previous day. In this way, we normalize the units so that we retain the important meteorological information, but we do not need the domain-specific units it is associated with.

# %% [markdown]
# **Ground-based Meteorological Data**
#
# We collected the ground-based meteorological data from Iowa State University's METAR ASOS Dataset: [data link](https://mesonet.agron.iastate.edu/request/download.phtml). The METAR dataset is a collection of meteorological data features collected around municipal airports/airstrips. We collected various meteorological features from 13 sensor locations near airports within the geographical bounds of Los Angeles county:

# %% [markdown]
# **Wildfire/Smoke Data**
#
# We use wildfire, smoke, and heat data from the NASA MODIS dataset and the NASA MERRA-2 dataset. MODIS provides satellite imagery of various fire data features, while MERRA-2 provides numerical grid-based raw sensor data values of various fire data features. We explore and utilize a combination of fire data collected from the MODIS and MERRA-2 collections.
#
# ---

# %% [markdown]
# ## Wildfire/Smoke Data Exploration
#
# In this section, we'll discuss a few of the data sources we looked into and why we decided to use or not use them in our model. For reference, in this notebook, we end up using the following Wildfire data:
#  - MERRA-2 PBL Height Grid-based Sensor Data Feature
#  - MERRA-2 Surface Air Temperature Grid-based Sensor Data Feature
#  - MERRA-2 Surface Exchange Coefficient For Heat Grid-based Sensor Data Feature
#  - MODIS FRP Remote Sensing Satellite Imagery
#
# In the remainder of this section, we will visualize a few data collections from the MERRA-2 and MODIS data sources.
#
# ### MERRA-2 Grid-based Sensor Data Exploration
#
# The Modern-Era Retrospective analysis for Research and Applications, version 2 (MERRA-2) is a global atmospheric reanalysis produced by the NASA Global Modeling and Assimilation Office (GMAO). It spans the satellite observing era from 1980 to the present. The goals of MERRA-2 are to provide a regularly-gridded, homogeneous record of the global atmosphere, and to incorporate additional aspects of the climate system including trace gas constituents (stratospheric ozone), and improved land surface representation, and cryospheric processes.
#
# In this section, we review some of the features available through various MERRA-2 collections and the reasoning behind why decided to use or not use each feature in the model. All of the MERRA-2 features explored in this subsection are in the format of multidimensional arrays of grid-based raw values throughout Los Angeles over time. However, some of these grids have a higher resolution than others, which drove the motivations behind using or discarding some of these data sources in the model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pollutant = pd.read_csv("eth_pm_2019-2021.csv",sep=';')
meteo = pd.read_csv("eth_met_2019-2021.csv", sep=';')

# %%
pollutant = pollutant.drop([pollutant.columns[3], pollutant.columns[4]],axis=1)
pollutant = pollutant.drop(pollutant.tail(8).index)
pollutant = pollutant.set_axis(['datetime', 'Durban City Hall', 'New Germany', 'Settlers', 'Wentworth'], axis=1)
pollutant = pollutant.iloc[2: , :]
inter = pollutant.loc[:, pollutant.columns != 'datetime'].stack().reset_index()
inter2 = pd.DataFrame(np.repeat(pollutant.datetime.values, 4, axis=0))
inter2.columns = ['date']
pollutant = inter2.join(inter)
pollutant['PM25'] = 0
pollutant = pollutant.drop([pollutant.columns[1]],axis=1)
pollutant = pollutant.set_axis(['date', 'site', 'PM10', 'PM25'], axis=1)

# %%
p = np.array(pollutant)
for data in p:
    combo = data[2].split(',')
    if len(combo) == 2:
        data[2] = combo[0]
        data[3] = combo[1]

# %%
pollutant = pd.DataFrame(data=p, columns=['date', 'site', 'PM10', 'PM25'])

# %%
pollutant.head()
# Out:
#                date              site PM10 PM25
# 0  01/01/2019 00:00  Durban City Hall   31    6
# 1  01/01/2019 00:00       New Germany   14    1
# 2  01/01/2019 00:00          Settlers   23    2
# 3  01/01/2019 00:00         Wentworth   11    1
# 4  01/01/2019 01:00  Durban City Hall   27    9

# %%
pollutant['site'].unique()
# Out:
# array(['Durban City Hall', 'New Germany', 'Settlers', 'Wentworth'],
#       dtype=object)

# %%
sites = pd.read_csv("sitelist.csv")
sites
# Out:
#                site   latitude  longitude   x   y
# 0  Durban City Hall -29.858217  31.027273  27  10
# 1       New Germany -29.798654  30.876540  12   4
# 2          Settlers -29.958842  30.978683  22  20
# 3         Wentworth -29.934095  30.988598  23  18

# %%
def generate_PM25_grid(df):
    frames = []
    count = 0
    for d in np.unique(df[0]):
        try:
            if count == 24:
                print("Generating grid for:", d)
                count = 0
            grid = np.zeros((30,30))
            for i in range(df.shape[1]):
                if df[0,i] == d:
                    site = df[1,i]
                    x = sites.loc[sites['site'] == site].iloc[0]['x']
                    y = sites.loc[sites['site'] == site].iloc[0]['y']
                    grid[x,y] = df[3,i]
            frames.append(grid)
            count += 1
        except ValueError:
            continue
    return frames

# %%
def generate_PM10_grid(df):
    frames = []
    count = 0
    for d in np.unique(df[0]):
        try:
            if count == 24:
                print("Generating grid for:", d)
                count = 0
            grid = np.zeros((30,30))
            for i in range(df.shape[1]):
                if df[0,i] == d:
                    site = df[1,i]
                    x = sites.loc[sites['site'] == site].iloc[0]['x']
                    y = sites.loc[sites['site'] == site].iloc[0]['y']
                    grid[x,y] = df[2,i]
            frames.append(grid)
            count += 1
        except ValueError:
            continue
    return frames

# %%
pm25_raw = np.array(pollutant.dropna(subset=['PM25'])).T
pm25_frames = generate_PM25_grid(pm25_raw)
# Out:
# Generating grid for: 01/01/2020 00:00
# Generating grid for: 01/01/2021 00:00
# Generating grid for: 01/02/2019 00:00
# Generating grid for: 01/02/2020 00:00
# Generating grid for: 01/02/2021 00:00
# Generating grid for: 01/03/2019 00:00
# Generating grid for: 01/03/2020 00:00
# Generating grid for: 01/03/2021 00:00
# Generating grid for: 01/04/2019 00:00
# Generating grid for: 01/04/2020 00:00
# Generating grid for: 01/04/2021 00:00
# Generating grid for: 01/05/2019 00:00
# Generating grid for: 01/05/2020 00:00
# Generating grid for: 01/05/2021 00:00
# Generating grid for: 01/06/2019 00:00
# Generating grid for: 01/06/2020 00:00
# Generating grid for: 01/06/2021 00:00
# Generating grid for: 01/07/2019 00:00
# Generating grid for: 01/07/2020 00:00
# Generating grid for: 01/07/2021 00:00
# Generating grid for: 01/08/2019 00:00
# Generating grid for: 01/08/2020 00:00
# Generating grid for: 01/08/2021 00:00
# Generating grid for: 01/09/2019 00:00
# Generating grid for: 01/09/2020 00:00
# Generating grid for: 01/09/2021 00:00
# Generating grid for: 01/10/2019 00:00
# Generating grid for: 01/10/2020 00:00
# Generating grid for: 01/10/2021 00:00
# Generating grid for: 01/11/2019 00:00
# Generating grid for: 01/11/2020 00:00
# Generating grid for: 01/11/2021 00:00
# Generating grid for: 01/12/2019 00:00
# Generating grid for: 01/12/2020 00:00
# Generating grid for: 01/12/2021 00:00
# Generating grid for: 02/01/2019 00:00
# Generating grid for: 02/01/2020 00:00
# Generating grid for: 02/01/2021 00:00
# Generating grid for: 02/02/2019 00:00
# Generating grid for: 02/02/2020 00:00
# Generating grid for: 02/02/2021 00:00
# Generating grid for: 02/03/2019 00:00
# Generating grid for: 02/03/2020 00:00
# Generating grid for: 02/03/2021 00:00
# Generating grid for: 02/04/2019 00:00
# Generating grid for: 02/04/2020 00:00
# Generating grid for: 02/04/2021 00:00
# Generating grid for: 02/05/2019 00:00
# Generating grid for: 02/05/2020 00:00
# Generating grid for: 02/05/2021 00:00
# Generating grid for: 02/06/2019 00:00
# Generating grid for: 02/06/2020 00:00
# Generating grid for: 02/06/2021 00:00
# Generating grid for: 02/07/2019 00:00
# Generating grid for: 02/07/2020 00:00
# Generating grid for: 02/07/2021 00:00
# Generating grid for: 02/08/2019 00:00
# Generating grid for: 02/08/2020 00:00
# Generating grid for: 02/08/2021 00:00
# Generating grid for: 02/09/2019 00:00
# Generating grid for: 02/09/2020 00:00
# Generating grid for: 02/09/2021 00:00
# Generating grid for: 02/10/2019 00:00
# Generating grid for: 02/10/2020 00:00
# Generating grid for: 02/10/2021 00:00
# Generating grid for: 02/11/2019 00:00
# Generating grid for: 02/11/2020 00:00
# Generating grid for: 02/11/2021 00:00
# Generating grid for: 02/12/2019 00:00
# Generating grid for: 02/12/2020 00:00
# Generating grid for: 02/12/2021 00:00
# Generating grid for: 03/01/2019 00:00
# Generating grid for: 03/01/2020 00:00
# Generating grid for: 03/01/2021 00:00
# Generating grid for: 03/02/2019 00:00
# Generating grid for: 03/02/2020 00:00
# Generating grid for: 03/02/2021 00:00
# Generating grid for: 03/03/2019 00:00
# Generating grid for: 03/03/2020 00:00
# Generating grid for: 03/03/2021 00:00
# Generating grid for: 03/04/2019 00:00
# Generating grid for: 03/04/2020 00:00
# Generating grid for: 03/04/2021 00:00
# Generating grid for: 03/05/2019 00:00
# Generating grid for: 03/05/2020 00:00
# Generating grid for: 03/05/2021 00:00
# Generating grid for: 03/06/2019 00:00
# Generating grid for: 03/06/2020 00:00
# Generating grid for: 03/06/2021 00:00
# Generating grid for: 03/07/2019 00:00
# Generating grid for: 03/07/2020 00:00
# Generating grid for: 03/07/2021 00:00
# Generating grid for: 03/08/2019 00:00
# Generating grid for: 03/08/2020 00:00
# Generating grid for: 03/08/2021 00:00
# Generating grid for: 03/09/2019 00:00
# Generating grid for: 03/09/2020 00:00
# Generating grid for: 03/09/2021 00:00
# Generating grid for: 03/10/2019 00:00
# Generating grid for: 03/10/2020 00:00
# Generating grid for: 03/10/2021 00:00
# Generating grid for: 03/11/2019 00:00
# Generating grid for: 03/11/2020 00:00
# Generating grid for: 03/11/2021 00:00
# Generating grid for: 03/12/2019 00:00
# Generating grid for: 03/12/2020 00:00
# Generating grid for: 03/12/2021 00:00
# Generating grid for: 04/01/2019 00:00
# Generating grid for: 04/01/2020 00:00
# Generating grid for: 04/01/2021 00:00
# Generating grid for: 04/02/2019 00:00
# Generating grid for: 04/02/2020 00:00
# Generating grid for: 04/02/2021 00:00
# Generating grid for: 04/03/2019 00:00
# Generating grid for: 04/03/2020 00:00
# Generating grid for: 04/03/2021 00:00
# Generating grid for: 04/04/2019 00:00
# Generating grid for: 04/04/2020 00:00
# Generating grid for: 04/04/2021 00:00
# Generating grid for: 04/05/2019 00:00
# Generating grid for: 04/05/2020 00:00
# Generating grid for: 04/05/2021 00:00
# Generating grid for: 04/06/2019 00:00
# Generating grid for: 04/06/2020 00:00
# Generating grid for: 04/06/2021 00:00
# Generating grid for: 04/07/2019 00:00
# Generating grid for: 04/07/2020 00:00
# Generating grid for: 04/07/2021 00:00
# Generating grid for: 04/08/2019 00:00
# Generating grid for: 04/08/2020 00:00
# Generating grid for: 04/08/2021 00:00
# Generating grid for: 04/09/2019 00:00
# Generating grid for: 04/09/2020 00:00
# Generating grid for: 04/09/2021 00:00
# Generating grid for: 04/10/2019 00:00
# Generating grid for: 04/10/2020 00:00
# Generating grid for: 04/10/2021 00:00
# Generating grid for: 04/11/2019 00:00
# Generating grid for: 04/11/2020 00:00
# Generating grid for: 04/11/2021 00:00
# Generating grid for: 04/12/2019 00:00
# Generating grid for: 04/12/2020 00:00
# Generating grid for: 04/12/2021 00:00
# Generating grid for: 05/01/2019 00:00
# Generating grid for: 05/01/2020 00:00
# Generating grid for: 05/01/2021 00:00
# Generating grid for: 05/02/2019 00:00
# Generating grid for: 05/02/2020 00:00
# Generating grid for: 05/02/2021 00:00
# Generating grid for: 05/03/2019 00:00
# Generating grid for: 05/03/2020 00:00
# Generating grid for: 05/03/2021 00:00
# Generating grid for: 05/04/2019 00:00
# Generating grid for: 05/04/2020 00:00
# Generating grid for: 05/04/2021 00:00
# Generating grid for: 05/05/2019 00:00
# Generating grid for: 05/05/2020 00:00
# Generating grid for: 05/05/2021 00:00
# Generating grid for: 05/06/2019 00:00
# Generating grid for: 05/06/2020 00:00
# Generating grid for: 05/06/2021 00:00
# Generating grid for: 05/07/2019 00:00
# Generating grid for: 05/07/2020 00:00
# Generating grid for: 05/07/2021 00:00
# Generating grid for: 05/08/2019 00:00
# Generating grid for: 05/08/2020 00:00
# Generating grid for: 05/08/2021 00:00
# Generating grid for: 05/09/2019 00:00
# Generating grid for: 05/09/2020 00:00
# Generating grid for: 05/09/2021 00:00
# Generating grid for: 05/10/2019 00:00
# Generating grid for: 05/10/2020 00:00
# Generating grid for: 05/10/2021 00:00
# Generating grid for: 05/11/2019 00:00
# Generating grid for: 05/11/2020 00:00
# Generating grid for: 05/11/2021 00:00
# Generating grid for: 05/12/2019 00:00
# Generating grid for: 05/12/2020 00:00
# Generating grid for: 05/12/2021 00:00
# Generating grid for: 06/01/2019 00:00
# Generating grid for: 06/01/2020 00:00
# Generating grid for: 06/01/2021 00:00
# Generating grid for: 06/02/2019 00:00
# Generating grid for: 06/02/2020 00:00
# Generating grid for: 06/02/2021 00:00
# Generating grid for: 06/03/2019 00:00
# Generating grid for: 06/03/2020 00:00
# Generating grid for: 06/03/2021 00:00
# Generating grid for: 06/04/2019 00:00
# Generating grid for: 06/04/2020 00:00
# Generating grid for: 06/04/2021 00:00
# Generating grid for: 06/05/2019 00:00
# Generating grid for: 06/05/2020 00:00
# Generating grid for: 06/05/2021 00:00
# Generating grid for: 06/06/2019 00:00
# Generating grid for: 06/06/2020 00:00
# Generating grid for: 06/06/2021 00:00
# Generating grid for: 06/07/2019 00:00
# Generating grid for: 06/07/2020 00:00
# Generating grid for: 06/07/2021 00:00
# Generating grid for: 06/08/2019 00:00
# Generating grid for: 06/08/2020 00:00
# Generating grid for: 06/08/2021 00:00
# Generating grid for: 06/09/2019 00:00
# Generating grid for: 06/09/2020 00:00
# Generating grid for: 06/09/2021 00:00
# Generating grid for: 06/10/2019 00:00
# Generating grid for: 06/10/2020 00:00
# Generating grid for: 06/10/2021 00:00
# Generating grid for: 06/11/2019 00:00
# Generating grid for: 06/11/2020 00:00
# Generating grid for: 06/11/2021 00:00
# Generating grid for: 06/12/2019 00:00
# Generating grid for: 06/12/2020 00:00
# Generating grid for: 06/12/2021 00:00
# Generating grid for: 07/01/2019 00:00
# Generating grid for: 07/01/2020 00:00
# Generating grid for: 07/01/2021 00:00
# Generating grid for: 07/02/2019 00:00
# Generating grid for: 07/02/2020 00:00
# Generating grid for: 07/02/2021 00:00
# Generating grid for: 07/03/2019 00:00
# Generating grid for: 07/03/2020 00:00
# Generating grid for: 07/03/2021 00:00
# Generating grid for: 07/04/2019 00:00
# Generating grid for: 07/04/2020 00:00
# Generating grid for: 07/04/2021 00:00
# Generating grid for: 07/05/2019 00:00
# Generating grid for: 07/05/2020 00:00
# Generating grid for: 07/05/2021 00:00
# Generating grid for: 07/06/2019 00:00
# Generating grid for: 07/06/2020 00:00
# Generating grid for: 07/06/2021 00:00
# Generating grid for: 07/07/2019 00:00
# Generating grid for: 07/07/2020 00:00
# Generating grid for: 07/07/2021 00:00
# Generating grid for: 07/08/2019 00:00
# Generating grid for: 07/08/2020 00:00
# Generating grid for: 07/08/2021 00:00
# Generating grid for: 07/09/2019 00:00
# Generating grid for: 07/09/2020 00:00
# Generating grid for: 07/09/2021 00:00
# Generating grid for: 07/10/2019 00:00
# Generating grid for: 07/10/2020 00:00
# Generating grid for: 07/10/2021 00:00
# Generating grid for: 07/11/2019 00:00
# Generating grid for: 07/11/2020 00:00
# Generating grid for: 07/11/2021 00:00
# Generating grid for: 07/12/2019 00:00
# Generating grid for: 07/12/2020 00:00
# Generating grid for: 07/12/2021 00:00
# Generating grid for: 08/01/2019 00:00
# Generating grid for: 08/01/2020 00:00
# Generating grid for: 08/01/2021 00:00
# Generating grid for: 08/02/2019 00:00
# Generating grid for: 08/02/2020 00:00
# Generating grid for: 08/02/2021 00:00
# Generating grid for: 08/03/2019 00:00
# Generating grid for: 08/03/2020 00:00
# Generating grid for: 08/03/2021 00:00
# Generating grid for: 08/04/2019 00:00
# Generating grid for: 08/04/2020 00:00
# Generating grid for: 08/04/2021 00:00
# Generating grid for: 08/05/2019 00:00
# Generating grid for: 08/05/2020 00:00
# Generating grid for: 08/05/2021 00:00
# Generating grid for: 08/06/2019 00:00
# Generating grid for: 08/06/2020 00:00
# Generating grid for: 08/06/2021 00:00
# Generating grid for: 08/07/2019 00:00
# Generating grid for: 08/07/2020 00:00
# Generating grid for: 08/07/2021 00:00
# Generating grid for: 08/08/2019 00:00
# Generating grid for: 08/08/2020 00:00
# Generating grid for: 08/08/2021 00:00
# Generating grid for: 08/09/2019 00:00
# Generating grid for: 08/09/2020 00:00
# Generating grid for: 08/09/2021 00:00
# Generating grid for: 08/10/2019 00:00
# Generating grid for: 08/10/2020 00:00
# Generating grid for: 08/10/2021 00:00
# Generating grid for: 08/11/2019 00:00
# Generating grid for: 08/11/2020 00:00
# Generating grid for: 08/11/2021 00:00
# Generating grid for: 08/12/2019 00:00
# Generating grid for: 08/12/2020 00:00
# Generating grid for: 08/12/2021 00:00
# Generating grid for: 09/01/2019 00:00
# Generating grid for: 09/01/2020 00:00
# Generating grid for: 09/01/2021 00:00
# Generating grid for: 09/02/2019 00:00
# Generating grid for: 09/02/2020 00:00
# Generating grid for: 09/02/2021 00:00
# Generating grid for: 09/03/2019 00:00
# Generating grid for: 09/03/2020 00:00
# Generating grid for: 09/03/2021 00:00
# Generating grid for: 09/04/2019 00:00
# Generating grid for: 09/04/2020 00:00
# Generating grid for: 09/04/2021 00:00
# Generating grid for: 09/05/2019 00:00
# Generating grid for: 09/05/2020 00:00
# Generating grid for: 09/05/2021 00:00
# Generating grid for: 09/06/2019 00:00
# Generating grid for: 09/06/2020 00:00
# Generating grid for: 09/06/2021 00:00
# Generating grid for: 09/07/2019 00:00
# Generating grid for: 09/07/2020 00:00
# Generating grid for: 09/07/2021 00:00
# Generating grid for: 09/08/2019 00:00
# Generating grid for: 09/08/2020 00:00
# Generating grid for: 09/08/2021 00:00
# Generating grid for: 09/09/2019 00:00
# Generating grid for: 09/09/2020 00:00
# Generating grid for: 09/09/2021 00:00
# Generating grid for: 09/10/2019 00:00
# Generating grid for: 09/10/2020 00:00
# Generating grid for: 09/10/2021 00:00
# Generating grid for: 09/11/2019 00:00
# Generating grid for: 09/11/2020 00:00
# Generating grid for: 09/11/2021 00:00
# Generating grid for: 09/12/2019 00:00
# Generating grid for: 09/12/2020 00:00
# Generating grid for: 09/12/2021 00:00
# Generating grid for: 10/01/2019 00:00
# Generating grid for: 10/01/2020 00:00
# Generating grid for: 10/01/2021 00:00
# Generating grid for: 10/02/2019 00:00
# Generating grid for: 10/02/2020 00:00
# Generating grid for: 10/02/2021 00:00
# Generating grid for: 10/03/2019 00:00
# Generating grid for: 10/03/2020 00:00
# Generating grid for: 10/03/2021 00:00
# Generating grid for: 10/04/2019 00:00
# Generating grid for: 10/04/2020 00:00
# Generating grid for: 10/04/2021 00:00
# Generating grid for: 10/05/2019 00:00
# Generating grid for: 10/05/2020 00:00
# Generating grid for: 10/05/2021 00:00
# Generating grid for: 10/06/2019 00:00
# Generating grid for: 10/06/2020 00:00
# Generating grid for: 10/06/2021 00:00
# Generating grid for: 10/07/2019 00:00
# Generating grid for: 10/07/2020 00:00
# Generating grid for: 10/07/2021 00:00
# Generating grid for: 10/08/2019 00:00
# Generating grid for: 10/08/2020 00:00
# Generating grid for: 10/08/2021 00:00
# Generating grid for: 10/09/2019 00:00
# Generating grid for: 10/09/2020 00:00
# Generating grid for: 10/09/2021 00:00
# Generating grid for: 10/10/2019 00:00
# Generating grid for: 10/10/2020 00:00
# Generating grid for: 10/10/2021 00:00
# Generating grid for: 10/11/2019 00:00
# Generating grid for: 10/11/2020 00:00
# Generating grid for: 10/11/2021 00:00
# Generating grid for: 10/12/2019 00:00
# Generating grid for: 10/12/2020 00:00
# Generating grid for: 10/12/2021 00:00
# Generating grid for: 11/01/2019 00:00
# Generating grid for: 11/01/2020 00:00
# Generating grid for: 11/01/2021 00:00
# Generating grid for: 11/02/2019 00:00
# Generating grid for: 11/02/2020 00:00
# Generating grid for: 11/02/2021 00:00
# Generating grid for: 11/03/2019 00:00
# Generating grid for: 11/03/2020 00:00
# Generating grid for: 11/03/2021 00:00
# Generating grid for: 11/04/2019 00:00
# Generating grid for: 11/04/2020 00:00
# Generating grid for: 11/04/2021 00:00
# Generating grid for: 11/05/2019 00:00
# Generating grid for: 11/05/2020 00:00
# Generating grid for: 11/05/2021 00:00
# Generating grid for: 11/06/2019 00:00
# Generating grid for: 11/06/2020 00:00
# Generating grid for: 11/06/2021 00:00
# Generating grid for: 11/07/2019 00:00
# Generating grid for: 11/07/2020 00:00
# Generating grid for: 11/07/2021 00:00
# Generating grid for: 11/08/2019 00:00
# Generating grid for: 11/08/2020 00:00
# Generating grid for: 11/08/2021 00:00
# Generating grid for: 11/09/2019 00:00
# Generating grid for: 11/09/2020 00:00
# Generating grid for: 11/09/2021 00:00
# Generating grid for: 11/10/2019 00:00
# Generating grid for: 11/10/2020 00:00
# Generating grid for: 11/10/2021 00:00
# Generating grid for: 11/11/2019 00:00
# Generating grid for: 11/11/2020 00:00
# Generating grid for: 11/11/2021 00:00
# Generating grid for: 11/12/2019 00:00
# Generating grid for: 11/12/2020 00:00
# Generating grid for: 11/12/2021 00:00
# Generating grid for: 12/01/2019 00:00
# Generating grid for: 12/01/2020 00:00
# Generating grid for: 12/01/2021 00:00
# Generating grid for: 12/02/2019 00:00
# Generating grid for: 12/02/2020 00:00
# Generating grid for: 12/02/2021 00:00
# Generating grid for: 12/03/2019 00:00
# Generating grid for: 12/03/2020 00:00
# Generating grid for: 12/03/2021 00:00
# Generating grid for: 12/04/2019 00:00
# Generating grid for: 12/04/2020 00:00
# Generating grid for: 12/04/2021 00:00
# Generating grid for: 12/05/2019 00:00
# Generating grid for: 12/05/2020 00:00
# Generating grid for: 12/05/2021 00:00
# Generating grid for: 12/06/2019 00:00
# Generating grid for: 12/06/2020 00:00
# Generating grid for: 12/06/2021 00:00
# Generating grid for: 12/07/2019 00:00
# Generating grid for: 12/07/2020 00:00
# Generating grid for: 12/07/2021 00:00
# Generating grid for: 12/08/2019 00:00
# Generating grid for: 12/08/2020 00:00
# Generating grid for: 12/08/2021 00:00
# Generating grid for: 12/09/2019 00:00
# Generating grid for: 12/09/2020 00:00
# Generating grid for: 12/09/2021 00:00
# Generating grid for: 12/10/2019 00:00
# Generating grid for: 12/10/2020 00:00
# Generating grid for: 12/10/2021 00:00
# Generating grid for: 12/11/2019 00:00
# Generating grid for: 12/11/2020 00:00
# Generating grid for: 12/11/2021 00:00
# Generating grid for: 12/12/2019 00:00
# Generating grid for: 12/12/2020 00:00
# Generating grid for: 12/12/2021 00:00
# Generating grid for: 13/01/2019 00:00
# Generating grid for: 13/01/2020 00:00
# Generating grid for: 13/01/2021 00:00
# Generating grid for: 13/02/2019 00:00
# Generating grid for: 13/02/2020 00:00
# Generating grid for: 13/02/2021 00:00
# Generating grid for: 13/03/2019 00:00
# Generating grid for: 13/03/2020 00:00
# Generating grid for: 13/03/2021 00:00
# Generating grid for: 13/04/2019 00:00
# Generating grid for: 13/04/2020 00:00
# Generating grid for: 13/04/2021 00:00
# Generating grid for: 13/05/2019 00:00
# Generating grid for: 13/05/2020 00:00
# Generating grid for: 13/05/2021 00:00
# Generating grid for: 13/06/2019 00:00
# Generating grid for: 13/06/2020 00:00
# Generating grid for: 13/06/2021 00:00
# Generating grid for: 13/07/2019 00:00
# Generating grid for: 13/07/2020 00:00
# Generating grid for: 13/07/2021 00:00
# Generating grid for: 13/08/2019 00:00
# Generating grid for: 13/08/2020 00:00
# Generating grid for: 13/08/2021 00:00
# Generating grid for: 13/09/2019 00:00
# Generating grid for: 13/09/2020 00:00
# Generating grid for: 13/09/2021 00:00
# Generating grid for: 13/10/2019 00:00
# Generating grid for: 13/10/2020 00:00
# Generating grid for: 13/10/2021 00:00
# Generating grid for: 13/11/2019 00:00
# Generating grid for: 13/11/2020 00:00
# Generating grid for: 13/11/2021 00:00
# Generating grid for: 13/12/2019 00:00
# Generating grid for: 13/12/2020 00:00
# Generating grid for: 13/12/2021 00:00
# Generating grid for: 14/01/2019 00:00
# Generating grid for: 14/01/2020 00:00
# Generating grid for: 14/01/2021 00:00
# Generating grid for: 14/02/2019 00:00
# Generating grid for: 14/02/2020 00:00
# Generating grid for: 14/02/2021 00:00
# Generating grid for: 14/03/2019 00:00
# Generating grid for: 14/03/2020 00:00
# Generating grid for: 14/03/2021 00:00
# Generating grid for: 14/04/2019 00:00
# Generating grid for: 14/04/2020 00:00
# Generating grid for: 14/04/2021 00:00
# Generating grid for: 14/05/2019 00:00
# Generating grid for: 14/05/2020 00:00
# Generating grid for: 14/05/2021 00:00
# Generating grid for: 14/06/2019 00:00
# Generating grid for: 14/06/2020 00:00
# Generating grid for: 14/06/2021 00:00
# Generating grid for: 14/07/2019 00:00
# Generating grid for: 14/07/2020 00:00
# Generating grid for: 14/07/2021 00:00
# Generating grid for: 14/08/2019 00:00
# Generating grid for: 14/08/2020 00:00
# Generating grid for: 14/08/2021 00:00
# Generating grid for: 14/09/2019 00:00
# Generating grid for: 14/09/2020 00:00
# Generating grid for: 14/09/2021 00:00
# Generating grid for: 14/10/2019 00:00
# Generating grid for: 14/10/2020 00:00
# Generating grid for: 14/10/2021 00:00
# Generating grid for: 14/11/2019 00:00
# Generating grid for: 14/11/2020 00:00
# Generating grid for: 14/11/2021 00:00
# Generating grid for: 14/12/2019 00:00
# Generating grid for: 14/12/2020 00:00
# Generating grid for: 14/12/2021 00:00
# Generating grid for: 15/01/2019 00:00
# Generating grid for: 15/01/2020 00:00
# Generating grid for: 15/01/2021 00:00
# Generating grid for: 15/02/2019 00:00
# Generating grid for: 15/02/2020 00:00
# Generating grid for: 15/02/2021 00:00
# Generating grid for: 15/03/2019 00:00
# Generating grid for: 15/03/2020 00:00
# Generating grid for: 15/03/2021 00:00
# Generating grid for: 15/04/2019 00:00
# Generating grid for: 15/04/2020 00:00
# Generating grid for: 15/04/2021 00:00
# Generating grid for: 15/05/2019 00:00
# Generating grid for: 15/05/2020 00:00
# Generating grid for: 15/05/2021 00:00
# Generating grid for: 15/06/2019 00:00
# Generating grid for: 15/06/2020 00:00
# Generating grid for: 15/06/2021 00:00
# Generating grid for: 15/07/2019 00:00
# Generating grid for: 15/07/2020 00:00
# Generating grid for: 15/07/2021 00:00
# Generating grid for: 15/08/2019 00:00
# Generating grid for: 15/08/2020 00:00
# Generating grid for: 15/08/2021 00:00
# Generating grid for: 15/09/2019 00:00
# Generating grid for: 15/09/2020 00:00
# Generating grid for: 15/09/2021 00:00
# Generating grid for: 15/10/2019 00:00
# Generating grid for: 15/10/2020 00:00
# Generating grid for: 15/10/2021 00:00
# Generating grid for: 15/11/2019 00:00
# Generating grid for: 15/11/2020 00:00
# Generating grid for: 15/11/2021 00:00
# Generating grid for: 15/12/2019 00:00
# Generating grid for: 15/12/2020 00:00
# Generating grid for: 15/12/2021 00:00
# Generating grid for: 16/01/2019 00:00
# Generating grid for: 16/01/2020 00:00
# Generating grid for: 16/01/2021 00:00
# Generating grid for: 16/02/2019 00:00
# Generating grid for: 16/02/2020 00:00
# Generating grid for: 16/02/2021 00:00
# Generating grid for: 16/03/2019 00:00
# Generating grid for: 16/03/2020 00:00
# Generating grid for: 16/03/2021 00:00
# Generating grid for: 16/04/2019 00:00
# Generating grid for: 16/04/2020 00:00
# Generating grid for: 16/04/2021 00:00
# Generating grid for: 16/05/2019 00:00
# Generating grid for: 16/05/2020 00:00
# Generating grid for: 16/05/2021 00:00
# Generating grid for: 16/06/2019 00:00
# Generating grid for: 16/06/2020 00:00
# Generating grid for: 16/06/2021 00:00
# Generating grid for: 16/07/2019 00:00
# Generating grid for: 16/07/2020 00:00
# Generating grid for: 16/07/2021 00:00
# Generating grid for: 16/08/2019 00:00
# Generating grid for: 16/08/2020 00:00
# Generating grid for: 16/08/2021 00:00
# Generating grid for: 16/09/2019 00:00
# Generating grid for: 16/09/2020 00:00
# Generating grid for: 16/09/2021 00:00
# Generating grid for: 16/10/2019 00:00
# Generating grid for: 16/10/2020 00:00
# Generating grid for: 16/10/2021 00:00
# Generating grid for: 16/11/2019 00:00
# Generating grid for: 16/11/2020 00:00
# Generating grid for: 16/11/2021 00:00
# Generating grid for: 16/12/2019 00:00
# Generating grid for: 16/12/2020 00:00
# Generating grid for: 16/12/2021 00:00
# Generating grid for: 17/01/2019 00:00
# Generating grid for: 17/01/2020 00:00
# Generating grid for: 17/01/2021 00:00
# Generating grid for: 17/02/2019 00:00
# Generating grid for: 17/02/2020 00:00
# Generating grid for: 17/02/2021 00:00
# Generating grid for: 17/03/2019 00:00
# Generating grid for: 17/03/2020 00:00
# Generating grid for: 17/03/2021 00:00
# Generating grid for: 17/04/2019 00:00
# Generating grid for: 17/04/2020 00:00
# Generating grid for: 17/04/2021 00:00
# Generating grid for: 17/05/2019 00:00
# Generating grid for: 17/05/2020 00:00
# Generating grid for: 17/05/2021 00:00
# Generating grid for: 17/06/2019 00:00
# Generating grid for: 17/06/2020 00:00
# Generating grid for: 17/06/2021 00:00
# Generating grid for: 17/07/2019 00:00
# Generating grid for: 17/07/2020 00:00
# Generating grid for: 17/07/2021 00:00
# Generating grid for: 17/08/2019 00:00
# Generating grid for: 17/08/2020 00:00
# Generating grid for: 17/08/2021 00:00
# Generating grid for: 17/09/2019 00:00
# Generating grid for: 17/09/2020 00:00
# Generating grid for: 17/09/2021 00:00
# Generating grid for: 17/10/2019 00:00
# Generating grid for: 17/10/2020 00:00
# Generating grid for: 17/10/2021 00:00
# Generating grid for: 17/11/2019 00:00
# Generating grid for: 17/11/2020 00:00
# Generating grid for: 17/11/2021 00:00
# Generating grid for: 17/12/2019 00:00
# Generating grid for: 17/12/2020 00:00
# Generating grid for: 17/12/2021 00:00
# Generating grid for: 18/01/2019 00:00
# Generating grid for: 18/01/2020 00:00
# Generating grid for: 18/01/2021 00:00
# Generating grid for: 18/02/2019 00:00
# Generating grid for: 18/02/2020 00:00
# Generating grid for: 18/02/2021 00:00
# Generating grid for: 18/03/2019 00:00
# Generating grid for: 18/03/2020 00:00
# Generating grid for: 18/03/2021 00:00
# Generating grid for: 18/04/2019 00:00
# Generating grid for: 18/04/2020 00:00
# Generating grid for: 18/04/2021 00:00
# Generating grid for: 18/05/2019 00:00
# Generating grid for: 18/05/2020 00:00
# Generating grid for: 18/05/2021 00:00
# Generating grid for: 18/06/2019 00:00
# Generating grid for: 18/06/2020 00:00
# Generating grid for: 18/06/2021 00:00
# Generating grid for: 18/07/2019 00:00
# Generating grid for: 18/07/2020 00:00
# Generating grid for: 18/07/2021 00:00
# Generating grid for: 18/08/2019 00:00
# Generating grid for: 18/08/2020 00:00
# Generating grid for: 18/08/2021 00:00
# Generating grid for: 18/09/2019 00:00
# Generating grid for: 18/09/2020 00:00
# Generating grid for: 18/09/2021 00:00
# Generating grid for: 18/10/2019 00:00
# Generating grid for: 18/10/2020 00:00
# Generating grid for: 18/10/2021 00:00
# Generating grid for: 18/11/2019 00:00
# Generating grid for: 18/11/2020 00:00
# Generating grid for: 18/11/2021 00:00
# Generating grid for: 18/12/2019 00:00
# Generating grid for: 18/12/2020 00:00
# Generating grid for: 18/12/2021 00:00
# Generating grid for: 19/01/2019 00:00
# Generating grid for: 19/01/2020 00:00
# Generating grid for: 19/01/2021 00:00
# Generating grid for: 19/02/2019 00:00
# Generating grid for: 19/02/2020 00:00
# Generating grid for: 19/02/2021 00:00
# Generating grid for: 19/03/2019 00:00
# Generating grid for: 19/03/2020 00:00
# Generating grid for: 19/03/2021 00:00
# Generating grid for: 19/04/2019 00:00
# Generating grid for: 19/04/2020 00:00
# Generating grid for: 19/04/2021 00:00
# Generating grid for: 19/05/2019 00:00
# Generating grid for: 19/05/2020 00:00
# Generating grid for: 19/05/2021 00:00
# Generating grid for: 19/06/2019 00:00
# Generating grid for: 19/06/2020 00:00
# Generating grid for: 19/06/2021 00:00
# Generating grid for: 19/07/2019 00:00
# Generating grid for: 19/07/2020 00:00
# Generating grid for: 19/07/2021 00:00
# Generating grid for: 19/08/2019 00:00
# Generating grid for: 19/08/2020 00:00
# Generating grid for: 19/08/2021 00:00
# Generating grid for: 19/09/2019 00:00
# Generating grid for: 19/09/2020 00:00
# Generating grid for: 19/09/2021 00:00
# Generating grid for: 19/10/2019 00:00
# Generating grid for: 19/10/2020 00:00
# Generating grid for: 19/10/2021 00:00
# Generating grid for: 19/11/2019 00:00
# Generating grid for: 19/11/2020 00:00
# Generating grid for: 19/11/2021 00:00
# Generating grid for: 19/12/2019 00:00
# Generating grid for: 19/12/2020 00:00
# Generating grid for: 19/12/2021 00:00
# Generating grid for: 20/01/2019 00:00
# Generating grid for: 20/01/2020 00:00
# Generating grid for: 20/01/2021 00:00
# Generating grid for: 20/02/2019 00:00
# Generating grid for: 20/02/2020 00:00
# Generating grid for: 20/02/2021 00:00
# Generating grid for: 20/03/2019 00:00
# Generating grid for: 20/03/2020 00:00
# Generating grid for: 20/03/2021 00:00
# Generating grid for: 20/04/2019 00:00
# Generating grid for: 20/04/2020 00:00
# Generating grid for: 20/04/2021 00:00
# Generating grid for: 20/05/2019 00:00
# Generating grid for: 20/05/2020 00:00
# Generating grid for: 20/05/2021 00:00
# Generating grid for: 20/06/2019 00:00
# Generating grid for: 20/06/2020 00:00
# Generating grid for: 20/06/2021 00:00
# Generating grid for: 20/07/2019 00:00
# Generating grid for: 20/07/2020 00:00
# Generating grid for: 20/07/2021 00:00
# Generating grid for: 20/08/2019 00:00
# Generating grid for: 20/08/2020 00:00
# Generating grid for: 20/08/2021 00:00
# Generating grid for: 20/09/2019 00:00
# Generating grid for: 20/09/2020 00:00
# Generating grid for: 20/09/2021 00:00
# Generating grid for: 20/10/2019 00:00
# Generating grid for: 20/10/2020 00:00
# Generating grid for: 20/10/2021 00:00
# Generating grid for: 20/11/2019 00:00
# Generating grid for: 20/11/2020 00:00
# Generating grid for: 20/11/2021 00:00
# Generating grid for: 20/12/2019 00:00
# Generating grid for: 20/12/2020 00:00
# Generating grid for: 20/12/2021 00:00
# Generating grid for: 21/01/2019 00:00
# Generating grid for: 21/01/2020 00:00
# Generating grid for: 21/01/2021 00:00
# Generating grid for: 21/02/2019 00:00
# Generating grid for: 21/02/2020 00:00
# Generating grid for: 21/02/2021 00:00
# Generating grid for: 21/03/2019 00:00
# Generating grid for: 21/03/2020 00:00
# Generating grid for: 21/03/2021 00:00
# Generating grid for: 21/04/2019 00:00
# Generating grid for: 21/04/2020 00:00
# Generating grid for: 21/04/2021 00:00
# Generating grid for: 21/05/2019 00:00
# Generating grid for: 21/05/2020 00:00
# Generating grid for: 21/05/2021 00:00
# Generating grid for: 21/06/2019 00:00
# Generating grid for: 21/06/2020 00:00
# Generating grid for: 21/06/2021 00:00
# Generating grid for: 21/07/2019 00:00
# Generating grid for: 21/07/2020 00:00
# Generating grid for: 21/07/2021 00:00
# Generating grid for: 21/08/2019 00:00
# Generating grid for: 21/08/2020 00:00
# Generating grid for: 21/08/2021 00:00
# Generating grid for: 21/09/2019 00:00
# Generating grid for: 21/09/2020 00:00
# Generating grid for: 21/09/2021 00:00
# Generating grid for: 21/10/2019 00:00
# Generating grid for: 21/10/2020 00:00
# Generating grid for: 21/10/2021 00:00
# Generating grid for: 21/11/2019 00:00
# Generating grid for: 21/11/2020 00:00
# Generating grid for: 21/11/2021 00:00
# Generating grid for: 21/12/2019 00:00
# Generating grid for: 21/12/2020 00:00
# Generating grid for: 21/12/2021 00:00
# Generating grid for: 22/01/2019 00:00
# Generating grid for: 22/01/2020 00:00
# Generating grid for: 22/01/2021 00:00
# Generating grid for: 22/02/2019 00:00
# Generating grid for: 22/02/2020 00:00
# Generating grid for: 22/02/2021 00:00
# Generating grid for: 22/03/2019 00:00
# Generating grid for: 22/03/2020 00:00
# Generating grid for: 22/03/2021 00:00
# Generating grid for: 22/04/2019 00:00
# Generating grid for: 22/04/2020 00:00
# Generating grid for: 22/04/2021 00:00
# Generating grid for: 22/05/2019 00:00
# Generating grid for: 22/05/2020 00:00
# Generating grid for: 22/05/2021 00:00
# Generating grid for: 22/06/2019 00:00
# Generating grid for: 22/06/2020 00:00
# Generating grid for: 22/06/2021 00:00
# Generating grid for: 22/07/2019 00:00
# Generating grid for: 22/07/2020 00:00
# Generating grid for: 22/07/2021 00:00
# Generating grid for: 22/08/2019 00:00
# Generating grid for: 22/08/2020 00:00
# Generating grid for: 22/08/2021 00:00
# Generating grid for: 22/09/2019 00:00
# Generating grid for: 22/09/2020 00:00
# Generating grid for: 22/09/2021 00:00
# Generating grid for: 22/10/2019 00:00
# Generating grid for: 22/10/2020 00:00
# Generating grid for: 22/10/2021 00:00
# Generating grid for: 22/11/2019 00:00
# Generating grid for: 22/11/2020 00:00
# Generating grid for: 22/11/2021 00:00
# Generating grid for: 22/12/2019 00:00
# Generating grid for: 22/12/2020 00:00
# Generating grid for: 22/12/2021 00:00
# Generating grid for: 23/01/2019 00:00
# Generating grid for: 23/01/2020 00:00
# Generating grid for: 23/01/2021 00:00
# Generating grid for: 23/02/2019 00:00
# Generating grid for: 23/02/2020 00:00
# Generating grid for: 23/02/2021 00:00
# Generating grid for: 23/03/2019 00:00
# Generating grid for: 23/03/2020 00:00
# Generating grid for: 23/03/2021 00:00
# Generating grid for: 23/04/2019 00:00
# Generating grid for: 23/04/2020 00:00
# Generating grid for: 23/04/2021 00:00
# Generating grid for: 23/05/2019 00:00
# Generating grid for: 23/05/2020 00:00
# Generating grid for: 23/05/2021 00:00
# Generating grid for: 23/06/2019 00:00
# Generating grid for: 23/06/2020 00:00
# Generating grid for: 23/06/2021 00:00
# Generating grid for: 23/07/2019 00:00
# Generating grid for: 23/07/2020 00:00
# Generating grid for: 23/07/2021 00:00
# Generating grid for: 23/08/2019 00:00
# Generating grid for: 23/08/2020 00:00
# Generating grid for: 23/08/2021 00:00
# Generating grid for: 23/09/2019 00:00
# Generating grid for: 23/09/2020 00:00
# Generating grid for: 23/09/2021 00:00
# Generating grid for: 23/10/2019 00:00
# Generating grid for: 23/10/2020 00:00
# Generating grid for: 23/10/2021 00:00
# Generating grid for: 23/11/2019 00:00
# Generating grid for: 23/11/2020 00:00
# Generating grid for: 23/11/2021 00:00
# Generating grid for: 23/12/2019 00:00
# Generating grid for: 23/12/2020 00:00
# Generating grid for: 23/12/2021 00:00
# Generating grid for: 24/01/2019 00:00
# Generating grid for: 24/01/2020 00:00
# Generating grid for: 24/01/2021 00:00
# Generating grid for: 24/02/2019 00:00
# Generating grid for: 24/02/2020 00:00
# Generating grid for: 24/02/2021 00:00
# Generating grid for: 24/03/2019 00:00
# Generating grid for: 24/03/2020 00:00
# Generating grid for: 24/03/2021 00:00
# Generating grid for: 24/04/2019 00:00
# Generating grid for: 24/04/2020 00:00
# Generating grid for: 24/04/2021 00:00
# Generating grid for: 24/05/2019 00:00
# Generating grid for: 24/05/2020 00:00
# Generating grid for: 24/05/2021 00:00
# Generating grid for: 24/06/2019 00:00
# Generating grid for: 24/06/2020 00:00
# Generating grid for: 24/06/2021 00:00
# Generating grid for: 24/07/2019 00:00
# Generating grid for: 24/07/2020 00:00
# Generating grid for: 24/07/2021 00:00
# Generating grid for: 24/08/2019 00:00
# Generating grid for: 24/08/2020 00:00
# Generating grid for: 24/08/2021 00:00
# Generating grid for: 24/09/2019 00:00
# Generating grid for: 24/09/2020 00:00
# Generating grid for: 24/09/2021 00:00
# Generating grid for: 24/10/2019 00:00
# Generating grid for: 24/10/2020 00:00
# Generating grid for: 24/10/2021 00:00
# Generating grid for: 24/11/2019 00:00
# Generating grid for: 24/11/2020 00:00
# Generating grid for: 24/11/2021 00:00
# Generating grid for: 24/12/2019 00:00
# Generating grid for: 24/12/2020 00:00
# Generating grid for: 24/12/2021 00:00
# Generating grid for: 25/01/2019 00:00
# Generating grid for: 25/01/2020 00:00
# Generating grid for: 25/01/2021 00:00
# Generating grid for: 25/02/2019 00:00
# Generating grid for: 25/02/2020 00:00
# Generating grid for: 25/02/2021 00:00
# Generating grid for: 25/03/2019 00:00
# Generating grid for: 25/03/2020 00:00
# Generating grid for: 25/03/2021 00:00
# Generating grid for: 25/04/2019 00:00
# Generating grid for: 25/04/2020 00:00
# Generating grid for: 25/04/2021 00:00
# Generating grid for: 25/05/2019 00:00
# Generating grid for: 25/05/2020 00:00
# Generating grid for: 25/05/2021 00:00
# Generating grid for: 25/06/2019 00:00
# Generating grid for: 25/06/2020 00:00
# Generating grid for: 25/06/2021 00:00
# Generating grid for: 25/07/2019 00:00
# Generating grid for: 25/07/2020 00:00
# Generating grid for: 25/07/2021 00:00
# Generating grid for: 25/08/2019 00:00
# Generating grid for: 25/08/2020 00:00
# Generating grid for: 25/08/2021 00:00
# Generating grid for: 25/09/2019 00:00
# Generating grid for: 25/09/2020 00:00
# Generating grid for: 25/09/2021 00:00
# Generating grid for: 25/10/2019 00:00
# Generating grid for: 25/10/2020 00:00
# Generating grid for: 25/10/2021 00:00
# Generating grid for: 25/11/2019 00:00
# Generating grid for: 25/11/2020 00:00
# Generating grid for: 25/11/2021 00:00
# Generating grid for: 25/12/2019 00:00
# Generating grid for: 25/12/2020 00:00
# Generating grid for: 25/12/2021 00:00
# Generating grid for: 26/01/2019 00:00
# Generating grid for: 26/01/2020 00:00
# Generating grid for: 26/01/2021 00:00
# Generating grid for: 26/02/2019 00:00
# Generating grid for: 26/02/2020 00:00
# Generating grid for: 26/02/2021 00:00
# Generating grid for: 26/03/2019 00:00
# Generating grid for: 26/03/2020 00:00
# Generating grid for: 26/03/2021 00:00
# Generating grid for: 26/04/2019 00:00
# Generating grid for: 26/04/2020 00:00
# Generating grid for: 26/04/2021 00:00
# Generating grid for: 26/05/2019 00:00
# Generating grid for: 26/05/2020 00:00
# Generating grid for: 26/05/2021 00:00
# Generating grid for: 26/06/2019 00:00
# Generating grid for: 26/06/2020 00:00
# Generating grid for: 26/06/2021 00:00
# Generating grid for: 26/07/2019 00:00
# Generating grid for: 26/07/2020 00:00
# Generating grid for: 26/07/2021 00:00
# Generating grid for: 26/08/2019 00:00
# Generating grid for: 26/08/2020 00:00
# Generating grid for: 26/08/2021 00:00
# Generating grid for: 26/09/2019 00:00
# Generating grid for: 26/09/2020 00:00
# Generating grid for: 26/09/2021 00:00
# Generating grid for: 26/10/2019 00:00
# Generating grid for: 26/10/2020 00:00
# Generating grid for: 26/10/2021 00:00
# Generating grid for: 26/11/2019 00:00
# Generating grid for: 26/11/2020 00:00
# Generating grid for: 26/11/2021 00:00
# Generating grid for: 26/12/2019 00:00
# Generating grid for: 26/12/2020 00:00
# Generating grid for: 26/12/2021 00:00
# Generating grid for: 27/01/2019 00:00
# Generating grid for: 27/01/2020 00:00
# Generating grid for: 27/01/2021 00:00
# Generating grid for: 27/02/2019 00:00
# Generating grid for: 27/02/2020 00:00
# Generating grid for: 27/02/2021 00:00
# Generating grid for: 27/03/2019 00:00
# Generating grid for: 27/03/2020 00:00
# Generating grid for: 27/03/2021 00:00
# Generating grid for: 27/04/2019 00:00
# Generating grid for: 27/04/2020 00:00
# Generating grid for: 27/04/2021 00:00
# Generating grid for: 27/05/2019 00:00
# Generating grid for: 27/05/2020 00:00
# Generating grid for: 27/05/2021 00:00
# Generating grid for: 27/06/2019 00:00
# Generating grid for: 27/06/2020 00:00
# Generating grid for: 27/06/2021 00:00
# Generating grid for: 27/07/2019 00:00
# Generating grid for: 27/07/2020 00:00
# Generating grid for: 27/07/2021 00:00
# Generating grid for: 27/08/2019 00:00
# Generating grid for: 27/08/2020 00:00
# Generating grid for: 27/08/2021 00:00
# Generating grid for: 27/09/2019 00:00
# Generating grid for: 27/09/2020 00:00
# Generating grid for: 27/09/2021 00:00
# Generating grid for: 27/10/2019 00:00
# Generating grid for: 27/10/2020 00:00
# Generating grid for: 27/10/2021 00:00
# Generating grid for: 27/11/2019 00:00
# Generating grid for: 27/11/2020 00:00
# Generating grid for: 27/11/2021 00:00
# Generating grid for: 27/12/2019 00:00
# Generating grid for: 27/12/2020 00:00
# Generating grid for: 27/12/2021 00:00
# Generating grid for: 28/01/2019 00:00
# Generating grid for: 28/01/2020 00:00
# Generating grid for: 28/01/2021 00:00
# Generating grid for: 28/02/2019 00:00
# Generating grid for: 28/02/2020 00:00
# Generating grid for: 28/02/2021 00:00
# Generating grid for: 28/03/2019 00:00
# Generating grid for: 28/03/2020 00:00
# Generating grid for: 28/03/2021 00:00
# Generating grid for: 28/04/2019 00:00
# Generating grid for: 28/04/2020 00:00
# Generating grid for: 28/04/2021 00:00
# Generating grid for: 28/05/2019 00:00
# Generating grid for: 28/05/2020 00:00
# Generating grid for: 28/05/2021 00:00
# Generating grid for: 28/06/2019 00:00
# Generating grid for: 28/06/2020 00:00
# Generating grid for: 28/06/2021 00:00
# Generating grid for: 28/07/2019 00:00
# Generating grid for: 28/07/2020 00:00
# Generating grid for: 28/07/2021 00:00
# Generating grid for: 28/08/2019 00:00
# Generating grid for: 28/08/2020 00:00
# Generating grid for: 28/08/2021 00:00
# Generating grid for: 28/09/2019 00:00
# Generating grid for: 28/09/2020 00:00
# Generating grid for: 28/09/2021 00:00
# Generating grid for: 28/10/2019 00:00
# Generating grid for: 28/10/2020 00:00
# Generating grid for: 28/10/2021 00:00
# Generating grid for: 28/11/2019 00:00
# Generating grid for: 28/11/2020 00:00
# Generating grid for: 28/11/2021 00:00
# Generating grid for: 28/12/2019 00:00
# Generating grid for: 28/12/2020 00:00
# Generating grid for: 28/12/2021 00:00
# Generating grid for: 29/01/2019 00:00
# Generating grid for: 29/01/2020 00:00
# Generating grid for: 29/01/2021 00:00
# Generating grid for: 29/02/2020 00:00
# Generating grid for: 29/03/2019 00:00
# Generating grid for: 29/03/2020 00:00
# Generating grid for: 29/03/2021 00:00
# Generating grid for: 29/04/2019 00:00
# Generating grid for: 29/04/2020 00:00
# Generating grid for: 29/04/2021 00:00
# Generating grid for: 29/05/2019 00:00
# Generating grid for: 29/05/2020 00:00
# Generating grid for: 29/05/2021 00:00
# Generating grid for: 29/06/2019 00:00
# Generating grid for: 29/06/2020 00:00
# Generating grid for: 29/06/2021 00:00
# Generating grid for: 29/07/2019 00:00
# Generating grid for: 29/07/2020 00:00
# Generating grid for: 29/07/2021 00:00
# Generating grid for: 29/08/2019 00:00
# Generating grid for: 29/08/2020 00:00
# Generating grid for: 29/08/2021 00:00
# Generating grid for: 29/09/2019 00:00
# Generating grid for: 29/09/2020 00:00
# Generating grid for: 29/09/2021 00:00
# Generating grid for: 29/10/2019 00:00
# Generating grid for: 29/10/2020 00:00
# Generating grid for: 29/10/2021 00:00
# Generating grid for: 29/11/2019 00:00
# Generating grid for: 29/11/2020 00:00
# Generating grid for: 29/11/2021 00:00
# Generating grid for: 29/12/2019 00:00
# Generating grid for: 29/12/2020 00:00
# Generating grid for: 29/12/2021 00:00
# Generating grid for: 30/01/2019 00:00
# Generating grid for: 30/01/2020 00:00
# Generating grid for: 30/01/2021 00:00
# Generating grid for: 30/03/2019 00:00
# Generating grid for: 30/03/2020 00:00
# Generating grid for: 30/03/2021 00:00
# Generating grid for: 30/04/2019 00:00
# Generating grid for: 30/04/2020 00:00
# Generating grid for: 30/04/2021 00:00
# Generating grid for: 30/05/2019 00:00
# Generating grid for: 30/05/2020 00:00
# Generating grid for: 30/05/2021 00:00
# Generating grid for: 30/06/2019 00:00
# Generating grid for: 30/06/2020 00:00
# Generating grid for: 30/06/2021 00:00
# Generating grid for: 30/07/2019 00:00
# Generating grid for: 30/07/2020 00:00
# Generating grid for: 30/07/2021 00:00
# Generating grid for: 30/08/2019 00:00
# Generating grid for: 30/08/2020 00:00
# Generating grid for: 30/08/2021 00:00
# Generating grid for: 30/09/2019 00:00
# Generating grid for: 30/09/2020 00:00
# Generating grid for: 30/09/2021 00:00
# Generating grid for: 30/10/2019 00:00
# Generating grid for: 30/10/2020 00:00
# Generating grid for: 30/10/2021 00:00
# Generating grid for: 30/11/2019 00:00
# Generating grid for: 30/11/2020 00:00
# Generating grid for: 30/11/2021 00:00
# Generating grid for: 30/12/2019 00:00
# Generating grid for: 30/12/2020 00:00
# Generating grid for: 30/12/2021 00:00
# Generating grid for: 31/01/2019 00:00
# Generating grid for: 31/01/2020 00:00
# Generating grid for: 31/01/2021 00:00
# Generating grid for: 31/03/2019 00:00
# Generating grid for: 31/03/2020 00:00
# Generating grid for: 31/03/2021 00:00
# Generating grid for: 31/05/2019 00:00
# Generating grid for: 31/05/2020 00:00
# Generating grid for: 31/05/2021 00:00
# Generating grid for: 31/07/2019 00:00
# Generating grid for: 31/07/2020 00:00
# Generating grid for: 31/07/2021 00:00
# Generating grid for: 31/08/2019 00:00
# Generating grid for: 31/08/2020 00:00
# Generating grid for: 31/08/2021 00:00
# Generating grid for: 31/10/2019 00:00
# Generating grid for: 31/10/2020 00:00
# Generating grid for: 31/10/2021 00:00
# Generating grid for: 31/12/2019 00:00
# Generating grid for: 31/12/2020 00:00
# Generating grid for: 31/12/2021 00:00

# %%
pm10_raw = np.array(pollutant.dropna(subset=['PM10'])).T
pm10_frames = generate_PM10_grid(pm10_raw)
# Out:
# Generating grid for: 01/01/2020 07:00
# Generating grid for: 01/01/2021 07:00
# Generating grid for: 01/02/2019 07:00
# Generating grid for: 01/02/2020 07:00
# Generating grid for: 01/03/2019 09:00
# Generating grid for: 01/03/2020 09:00
# Generating grid for: 01/03/2021 09:00
# Generating grid for: 01/04/2019 09:00
# Generating grid for: 01/04/2020 09:00
# Generating grid for: 01/04/2021 09:00
# Generating grid for: 01/05/2019 09:00
# Generating grid for: 01/05/2020 09:00
# Generating grid for: 01/05/2021 09:00
# Generating grid for: 01/06/2019 09:00
# Generating grid for: 01/06/2020 09:00
# Generating grid for: 01/06/2021 09:00
# Generating grid for: 01/07/2019 11:00
# Generating grid for: 01/08/2019 11:00
# Generating grid for: 01/08/2020 11:00
# Generating grid for: 01/08/2021 11:00
# Generating grid for: 01/09/2019 11:00
# Generating grid for: 01/09/2020 11:00
# Generating grid for: 01/09/2021 13:00
# Generating grid for: 01/10/2019 13:00
# Generating grid for: 01/10/2020 13:00
# Generating grid for: 01/10/2021 13:00
# Generating grid for: 01/11/2019 13:00
# Generating grid for: 01/11/2021 13:00
# Generating grid for: 01/12/2019 13:00
# Generating grid for: 01/12/2020 13:00
# Generating grid for: 01/12/2021 13:00
# Generating grid for: 02/01/2019 13:00
# Generating grid for: 02/01/2020 13:00
# Generating grid for: 02/01/2021 13:00
# Generating grid for: 02/02/2019 13:00
# Generating grid for: 02/02/2020 15:00
# Generating grid for: 02/03/2019 16:00
# Generating grid for: 02/03/2020 16:00
# Generating grid for: 02/03/2021 16:00
# Generating grid for: 02/04/2019 16:00
# Generating grid for: 02/04/2020 16:00
# Generating grid for: 02/04/2021 16:00
# Generating grid for: 02/05/2019 16:00
# Generating grid for: 02/05/2020 16:00
# Generating grid for: 02/05/2021 16:00
# Generating grid for: 02/06/2019 16:00
# Generating grid for: 02/06/2020 16:00
# Generating grid for: 02/07/2019 02:00
# Generating grid for: 02/08/2019 02:00
# Generating grid for: 02/08/2020 02:00
# Generating grid for: 02/08/2021 02:00
# Generating grid for: 02/09/2019 02:00
# Generating grid for: 02/09/2020 09:00
# Generating grid for: 02/09/2021 14:00
# Generating grid for: 02/10/2019 14:00
# Generating grid for: 02/10/2020 14:00
# Generating grid for: 02/10/2021 14:00
# Generating grid for: 02/11/2019 14:00
# Generating grid for: 02/11/2021 14:00
# Generating grid for: 02/12/2019 16:00
# Generating grid for: 02/12/2020 16:00
# Generating grid for: 02/12/2021 16:00
# Generating grid for: 03/01/2019 16:00
# Generating grid for: 03/01/2020 16:00
# Generating grid for: 03/01/2021 16:00
# Generating grid for: 03/02/2019 16:00
# Generating grid for: 03/02/2020 20:00
# Generating grid for: 03/03/2019 20:00
# Generating grid for: 03/03/2020 20:00
# Generating grid for: 03/03/2021 20:00
# Generating grid for: 03/04/2020 05:00
# Generating grid for: 03/04/2021 05:00
# Generating grid for: 03/05/2019 05:00
# Generating grid for: 03/05/2020 05:00
# Generating grid for: 03/05/2021 05:00
# Generating grid for: 03/06/2019 05:00
# Generating grid for: 03/06/2020 05:00
# Generating grid for: 03/06/2021 05:00
# Generating grid for: 03/07/2019 09:00
# Generating grid for: 03/07/2020 23:00
# Generating grid for: 03/08/2019 23:00
# Generating grid for: 03/08/2020 23:00
# Generating grid for: 03/08/2021 23:00
# Generating grid for: 03/09/2019 23:00
# Generating grid for: 03/09/2021 05:00
# Generating grid for: 03/10/2019 05:00
# Generating grid for: 03/10/2020 05:00
# Generating grid for: 03/10/2021 05:00
# Generating grid for: 03/11/2019 05:00
# Generating grid for: 03/11/2021 05:00
# Generating grid for: 03/12/2019 05:00
# Generating grid for: 03/12/2020 05:00
# Generating grid for: 03/12/2021 18:00
# Generating grid for: 04/01/2019 18:00
# Generating grid for: 04/01/2020 18:00
# Generating grid for: 04/01/2021 18:00
# Generating grid for: 04/02/2019 18:00
# Generating grid for: 04/02/2020 20:00
# Generating grid for: 04/03/2019 10:00
# Generating grid for: 04/03/2020 10:00
# Generating grid for: 04/03/2021 10:00
# Generating grid for: 04/04/2020 05:00
# Generating grid for: 04/04/2021 05:00
# Generating grid for: 04/05/2019 05:00
# Generating grid for: 04/05/2020 05:00
# Generating grid for: 04/05/2021 05:00
# Generating grid for: 04/06/2019 05:00
# Generating grid for: 04/06/2020 05:00
# Generating grid for: 04/06/2021 05:00
# Generating grid for: 04/07/2019 07:00
# Generating grid for: 04/07/2020 07:00
# Generating grid for: 04/08/2019 07:00
# Generating grid for: 04/08/2020 07:00
# Generating grid for: 04/08/2021 07:00
# Generating grid for: 04/09/2019 07:00
# Generating grid for: 04/09/2020 07:00
# Generating grid for: 04/09/2021 09:00
# Generating grid for: 04/10/2019 09:00
# Generating grid for: 04/10/2020 09:00
# Generating grid for: 04/10/2021 09:00
# Generating grid for: 04/11/2019 09:00
# Generating grid for: 04/11/2021 09:00
# Generating grid for: 04/12/2019 09:00
# Generating grid for: 04/12/2020 20:00
# Generating grid for: 04/12/2021 20:00
# Generating grid for: 05/01/2019 20:00
# Generating grid for: 05/01/2020 23:00
# Generating grid for: 05/01/2021 23:00
# Generating grid for: 05/02/2019 23:00
# Generating grid for: 05/02/2021 06:00
# Generating grid for: 05/03/2019 06:00
# Generating grid for: 05/03/2020 12:00
# Generating grid for: 05/03/2021 12:00
# Generating grid for: 05/04/2019 12:00
# Generating grid for: 05/04/2020 12:00
# Generating grid for: 05/04/2021 12:00
# Generating grid for: 05/05/2019 12:00
# Generating grid for: 05/05/2020 12:00
# Generating grid for: 05/05/2021 12:00
# Generating grid for: 05/06/2019 15:00
# Generating grid for: 05/06/2020 15:00
# Generating grid for: 05/06/2021 17:00
# Generating grid for: 05/07/2019 17:00
# Generating grid for: 05/07/2020 17:00
# Generating grid for: 05/08/2019 17:00
# Generating grid for: 05/08/2020 17:00
# Generating grid for: 05/08/2021 17:00
# Generating grid for: 05/09/2019 17:00
# Generating grid for: 05/09/2020 19:00
# Generating grid for: 05/09/2021 19:00
# Generating grid for: 05/10/2019 19:00
# Generating grid for: 05/10/2020 19:00
# Generating grid for: 05/10/2021 19:00
# Generating grid for: 05/11/2019 19:00
# Generating grid for: 05/11/2021 19:00
# Generating grid for: 05/12/2019 21:00
# Generating grid for: 05/12/2020 21:00
# Generating grid for: 05/12/2021 23:00
# Generating grid for: 06/01/2019 23:00
# Generating grid for: 06/01/2020 23:00
# Generating grid for: 06/01/2021 23:00
# Generating grid for: 06/02/2020 00:00
# Generating grid for: 06/02/2021 02:00
# Generating grid for: 06/03/2020 04:00
# Generating grid for: 06/03/2021 04:00
# Generating grid for: 06/04/2019 04:00
# Generating grid for: 06/04/2020 04:00
# Generating grid for: 06/04/2021 04:00
# Generating grid for: 06/05/2019 04:00
# Generating grid for: 06/05/2020 04:00
# Generating grid for: 06/05/2021 04:00
# Generating grid for: 06/06/2019 04:00
# Generating grid for: 06/06/2020 05:00
# Generating grid for: 06/06/2021 05:00
# Generating grid for: 06/07/2019 05:00
# Generating grid for: 06/07/2020 05:00
# Generating grid for: 06/08/2019 05:00
# Generating grid for: 06/08/2020 05:00
# Generating grid for: 06/08/2021 05:00
# Generating grid for: 06/09/2019 05:00
# Generating grid for: 06/09/2020 05:00
# Generating grid for: 06/09/2021 05:00
# Generating grid for: 06/10/2019 05:00
# Generating grid for: 06/10/2020 05:00
# Generating grid for: 06/10/2021 05:00
# Generating grid for: 06/11/2019 05:00
# Generating grid for: 06/11/2020 22:00
# Generating grid for: 06/12/2019 00:00
# Generating grid for: 06/12/2020 03:00
# Generating grid for: 06/12/2021 03:00
# Generating grid for: 07/01/2019 03:00
# Generating grid for: 07/01/2020 03:00
# Generating grid for: 07/01/2021 03:00
# Generating grid for: 07/02/2019 05:00
# Generating grid for: 07/02/2020 07:00
# Generating grid for: 07/02/2021 09:00
# Generating grid for: 07/03/2020 08:00
# Generating grid for: 07/03/2021 08:00
# Generating grid for: 07/04/2019 08:00
# Generating grid for: 07/04/2020 08:00
# Generating grid for: 07/04/2021 08:00
# Generating grid for: 07/05/2019 08:00
# Generating grid for: 07/05/2020 08:00
# Generating grid for: 07/05/2021 08:00
# Generating grid for: 07/06/2019 08:00
# Generating grid for: 07/06/2020 08:00
# Generating grid for: 07/06/2021 08:00
# Generating grid for: 07/07/2019 08:00
# Generating grid for: 07/07/2020 08:00
# Generating grid for: 07/08/2019 08:00
# Generating grid for: 07/08/2020 08:00
# Generating grid for: 07/08/2021 08:00
# Generating grid for: 07/09/2019 08:00
# Generating grid for: 07/09/2020 08:00
# Generating grid for: 07/09/2021 08:00
# Generating grid for: 07/10/2019 08:00
# Generating grid for: 07/10/2020 08:00
# Generating grid for: 07/10/2021 08:00
# Generating grid for: 07/11/2019 10:00
# Generating grid for: 07/11/2020 10:00
# Generating grid for: 07/11/2021 10:00
# Generating grid for: 07/12/2019 14:00
# Generating grid for: 07/12/2020 14:00
# Generating grid for: 07/12/2021 14:00
# Generating grid for: 08/01/2019 14:00
# Generating grid for: 08/01/2020 14:00
# Generating grid for: 08/01/2021 16:00
# Generating grid for: 08/02/2019 16:00
# Generating grid for: 08/02/2020 18:00
# Generating grid for: 08/02/2021 18:00
# Generating grid for: 08/03/2020 17:00
# Generating grid for: 08/03/2021 17:00
# Generating grid for: 08/04/2019 17:00
# Generating grid for: 08/04/2020 17:00
# Generating grid for: 08/04/2021 17:00
# Generating grid for: 08/05/2019 17:00
# Generating grid for: 08/05/2020 17:00
# Generating grid for: 08/06/2019 07:00
# Generating grid for: 08/06/2020 07:00
# Generating grid for: 08/06/2021 07:00
# Generating grid for: 08/07/2019 09:00
# Generating grid for: 08/07/2020 09:00
# Generating grid for: 08/08/2019 09:00
# Generating grid for: 08/08/2020 09:00
# Generating grid for: 08/08/2021 09:00
# Generating grid for: 08/09/2019 09:00
# Generating grid for: 08/09/2020 09:00
# Generating grid for: 08/09/2021 09:00
# Generating grid for: 08/10/2019 09:00
# Generating grid for: 08/10/2020 09:00
# Generating grid for: 08/10/2021 09:00
# Generating grid for: 08/11/2019 12:00
# Generating grid for: 08/11/2020 12:00
# Generating grid for: 08/11/2021 16:00
# Generating grid for: 08/12/2019 22:00
# Generating grid for: 08/12/2020 22:00
# Generating grid for: 08/12/2021 22:00
# Generating grid for: 09/01/2019 22:00
# Generating grid for: 09/01/2021 02:00
# Generating grid for: 09/02/2019 02:00
# Generating grid for: 09/02/2020 04:00
# Generating grid for: 09/02/2021 05:00
# Generating grid for: 09/03/2020 05:00
# Generating grid for: 09/03/2021 05:00
# Generating grid for: 09/04/2019 05:00
# Generating grid for: 09/04/2020 05:00
# Generating grid for: 09/04/2021 05:00
# Generating grid for: 09/05/2019 05:00
# Generating grid for: 09/05/2020 05:00
# Generating grid for: 09/06/2019 05:00
# Generating grid for: 09/06/2020 05:00
# Generating grid for: 09/06/2021 05:00
# Generating grid for: 09/07/2019 10:00
# Generating grid for: 09/07/2020 10:00
# Generating grid for: 09/08/2019 10:00
# Generating grid for: 09/08/2020 10:00
# Generating grid for: 09/08/2021 10:00
# Generating grid for: 09/09/2019 10:00
# Generating grid for: 09/09/2020 10:00
# Generating grid for: 09/09/2021 10:00
# Generating grid for: 09/10/2020 02:00
# Generating grid for: 09/10/2021 02:00
# Generating grid for: 09/11/2019 04:00
# Generating grid for: 09/11/2020 04:00
# Generating grid for: 09/11/2021 06:00
# Generating grid for: 09/12/2019 17:00
# Generating grid for: 09/12/2020 17:00
# Generating grid for: 09/12/2021 19:00
# Generating grid for: 10/01/2019 19:00
# Generating grid for: 10/01/2020 21:00
# Generating grid for: 10/01/2021 21:00
# Generating grid for: 10/02/2019 23:00
# Generating grid for: 10/02/2020 23:00
# Generating grid for: 10/03/2020 16:00
# Generating grid for: 10/03/2021 16:00
# Generating grid for: 10/04/2019 18:00
# Generating grid for: 10/04/2020 18:00
# Generating grid for: 10/04/2021 18:00
# Generating grid for: 10/05/2019 18:00
# Generating grid for: 10/05/2020 18:00
# Generating grid for: 10/06/2019 19:00
# Generating grid for: 10/06/2020 19:00
# Generating grid for: 10/07/2019 03:00
# Generating grid for: 10/07/2020 03:00
# Generating grid for: 10/08/2019 03:00
# Generating grid for: 10/08/2020 03:00
# Generating grid for: 10/08/2021 03:00
# Generating grid for: 10/09/2019 03:00
# Generating grid for: 10/09/2020 03:00
# Generating grid for: 10/09/2021 03:00
# Generating grid for: 10/10/2020 03:00
# Generating grid for: 10/10/2021 03:00
# Generating grid for: 10/11/2019 05:00
# Generating grid for: 10/11/2020 05:00
# Generating grid for: 10/11/2021 05:00
# Generating grid for: 10/12/2019 16:00
# Generating grid for: 10/12/2020 17:00
# Generating grid for: 10/12/2021 17:00
# Generating grid for: 11/01/2019 17:00
# Generating grid for: 11/01/2020 17:00
# Generating grid for: 11/01/2021 17:00
# Generating grid for: 11/02/2019 19:00
# Generating grid for: 11/02/2020 21:00
# Generating grid for: 11/03/2020 13:00
# Generating grid for: 11/04/2019 07:00
# Generating grid for: 11/04/2020 07:00
# Generating grid for: 11/04/2021 07:00
# Generating grid for: 11/05/2019 07:00
# Generating grid for: 11/05/2020 07:00
# Generating grid for: 11/06/2019 07:00
# Generating grid for: 11/06/2020 07:00
# Generating grid for: 11/06/2021 07:00
# Generating grid for: 11/07/2019 07:00
# Generating grid for: 11/07/2020 07:00
# Generating grid for: 11/08/2019 08:00
# Generating grid for: 11/08/2020 08:00
# Generating grid for: 11/08/2021 08:00
# Generating grid for: 11/09/2019 08:00
# Generating grid for: 11/09/2020 08:00
# Generating grid for: 11/09/2021 08:00
# Generating grid for: 11/10/2020 05:00
# Generating grid for: 11/10/2021 08:00
# Generating grid for: 11/11/2019 10:00
# Generating grid for: 11/11/2020 10:00
# Generating grid for: 11/11/2021 10:00
# Generating grid for: 11/12/2019 16:00
# Generating grid for: 11/12/2020 16:00
# Generating grid for: 11/12/2021 16:00
# Generating grid for: 12/01/2019 16:00
# Generating grid for: 12/01/2020 16:00
# Generating grid for: 12/01/2021 16:00
# Generating grid for: 12/02/2019 18:00
# Generating grid for: 12/02/2020 18:00
# Generating grid for: 12/03/2019 09:00
# Generating grid for: 12/03/2020 09:00
# Generating grid for: 12/04/2019 10:00
# Generating grid for: 12/04/2020 10:00
# Generating grid for: 12/05/2019 04:00
# Generating grid for: 12/05/2020 04:00
# Generating grid for: 12/06/2019 04:00
# Generating grid for: 12/06/2020 04:00
# Generating grid for: 12/06/2021 04:00
# Generating grid for: 12/07/2019 04:00
# Generating grid for: 12/07/2020 04:00
# Generating grid for: 12/08/2019 05:00
# Generating grid for: 12/08/2020 05:00
# Generating grid for: 12/08/2021 05:00
# Generating grid for: 12/09/2019 05:00
# Generating grid for: 12/09/2020 05:00
# Generating grid for: 12/09/2021 05:00
# Generating grid for: 12/10/2019 07:00
# Generating grid for: 12/10/2020 07:00
# Generating grid for: 12/10/2021 07:00
# Generating grid for: 12/11/2019 09:00
# Generating grid for: 12/11/2020 09:00
# Generating grid for: 12/11/2021 09:00
# Generating grid for: 12/12/2019 09:00
# Generating grid for: 12/12/2020 13:00
# Generating grid for: 12/12/2021 13:00
# Generating grid for: 13/01/2019 16:00
# Generating grid for: 13/01/2020 16:00
# Generating grid for: 13/01/2021 16:00
# Generating grid for: 13/02/2019 20:00
# Generating grid for: 13/02/2020 20:00
# Generating grid for: 13/02/2021 20:00
# Generating grid for: 13/03/2019 23:00
# Generating grid for: 13/03/2021 04:00
# Generating grid for: 13/04/2019 06:00
# Generating grid for: 13/04/2020 06:00
# Generating grid for: 13/04/2021 16:00
# Generating grid for: 13/05/2019 16:00
# Generating grid for: 13/05/2020 16:00
# Generating grid for: 13/06/2019 05:00
# Generating grid for: 13/06/2020 05:00
# Generating grid for: 13/06/2021 05:00
# Generating grid for: 13/07/2019 05:00
# Generating grid for: 13/07/2020 05:00
# Generating grid for: 13/08/2019 07:00
# Generating grid for: 13/08/2020 07:00
# Generating grid for: 13/08/2021 09:00
# Generating grid for: 13/09/2019 09:00
# Generating grid for: 13/09/2020 09:00
# Generating grid for: 13/09/2021 09:00
# Generating grid for: 13/10/2019 09:00
# Generating grid for: 13/10/2020 09:00
# Generating grid for: 13/10/2021 11:00
# Generating grid for: 13/11/2019 13:00
# Generating grid for: 13/11/2020 13:00
# Generating grid for: 13/11/2021 13:00
# Generating grid for: 13/12/2019 16:00
# Generating grid for: 13/12/2020 16:00
# Generating grid for: 13/12/2021 16:00
# Generating grid for: 14/01/2019 16:00
# Generating grid for: 14/01/2020 16:00
# Generating grid for: 14/01/2021 16:00
# Generating grid for: 14/02/2019 20:00
# Generating grid for: 14/02/2020 20:00
# Generating grid for: 14/02/2021 20:00
# Generating grid for: 14/03/2020 04:00
# Generating grid for: 14/03/2021 06:00
# Generating grid for: 14/04/2019 08:00
# Generating grid for: 14/04/2020 08:00
# Generating grid for: 14/04/2021 15:00
# Generating grid for: 14/05/2019 22:00
# Generating grid for: 14/05/2020 22:00
# Generating grid for: 14/05/2021 22:00
# Generating grid for: 14/06/2019 22:00
# Generating grid for: 14/06/2021 02:00
# Generating grid for: 14/07/2019 02:00
# Generating grid for: 14/07/2020 02:00
# Generating grid for: 14/08/2019 04:00
# Generating grid for: 14/08/2020 04:00
# Generating grid for: 14/08/2021 06:00
# Generating grid for: 14/09/2019 06:00
# Generating grid for: 14/09/2020 06:00
# Generating grid for: 14/09/2021 07:00
# Generating grid for: 14/10/2019 07:00
# Generating grid for: 14/10/2020 07:00
# Generating grid for: 14/10/2021 07:00
# Generating grid for: 14/11/2019 07:00
# Generating grid for: 14/11/2020 07:00
# Generating grid for: 14/11/2021 07:00
# Generating grid for: 14/12/2019 07:00
# Generating grid for: 14/12/2020 07:00
# Generating grid for: 14/12/2021 07:00
# Generating grid for: 15/01/2019 07:00
# Generating grid for: 15/01/2020 07:00
# Generating grid for: 15/01/2021 18:00
# Generating grid for: 15/02/2019 18:00
# Generating grid for: 15/02/2020 20:00
# Generating grid for: 15/02/2021 23:00
# Generating grid for: 15/03/2020 01:00
# Generating grid for: 15/03/2021 01:00
# Generating grid for: 15/04/2019 05:00
# Generating grid for: 15/04/2020 14:00
# Generating grid for: 15/04/2021 14:00
# Generating grid for: 15/05/2019 22:00
# Generating grid for: 15/05/2020 22:00
# Generating grid for: 15/06/2019 14:00
# Generating grid for: 15/06/2020 23:00
# Generating grid for: 15/06/2021 23:00
# Generating grid for: 15/07/2019 23:00
# Generating grid for: 15/07/2020 23:00
# Generating grid for: 15/08/2019 23:00
# Generating grid for: 15/08/2020 23:00
# Generating grid for: 15/08/2021 23:00
# Generating grid for: 15/09/2019 23:00
# Generating grid for: 15/09/2021 12:00
# Generating grid for: 15/10/2019 12:00
# Generating grid for: 15/10/2020 12:00
# Generating grid for: 15/10/2021 12:00
# Generating grid for: 15/11/2019 12:00
# Generating grid for: 15/11/2020 12:00
# Generating grid for: 15/11/2021 12:00
# Generating grid for: 15/12/2019 12:00
# Generating grid for: 15/12/2020 12:00
# Generating grid for: 15/12/2021 12:00
# Generating grid for: 16/01/2019 12:00
# Generating grid for: 16/01/2020 12:00
# Generating grid for: 16/01/2021 12:00
# Generating grid for: 16/02/2019 12:00
# Generating grid for: 16/02/2020 15:00
# Generating grid for: 16/02/2021 16:00
# Generating grid for: 16/03/2019 20:00
# Generating grid for: 16/03/2020 20:00
# Generating grid for: 16/03/2021 22:00
# Generating grid for: 16/04/2020 11:00
# Generating grid for: 16/04/2021 11:00
# Generating grid for: 16/05/2019 11:00
# Generating grid for: 16/05/2020 12:00
# Generating grid for: 16/06/2019 12:00
# Generating grid for: 16/06/2020 12:00
# Generating grid for: 16/06/2021 12:00
# Generating grid for: 16/07/2019 12:00
# Generating grid for: 16/07/2020 14:00
# Generating grid for: 16/08/2019 14:00
# Generating grid for: 16/08/2020 15:00
# Generating grid for: 16/08/2021 15:00
# Generating grid for: 16/09/2019 15:00
# Generating grid for: 16/09/2021 01:00
# Generating grid for: 16/10/2019 01:00
# Generating grid for: 16/10/2020 04:00
# Generating grid for: 16/10/2021 04:00
# Generating grid for: 16/11/2019 04:00
# Generating grid for: 16/11/2020 04:00
# Generating grid for: 16/11/2021 04:00
# Generating grid for: 16/12/2019 04:00
# Generating grid for: 16/12/2020 04:00
# Generating grid for: 16/12/2021 04:00
# Generating grid for: 17/01/2019 04:00
# Generating grid for: 17/01/2020 04:00
# Generating grid for: 17/01/2021 04:00
# Generating grid for: 17/02/2019 07:00
# Generating grid for: 17/02/2020 07:00
# Generating grid for: 17/03/2019 06:00
# Generating grid for: 17/03/2020 10:00
# Generating grid for: 17/03/2021 10:00
# Generating grid for: 17/04/2020 12:00
# Generating grid for: 17/04/2021 12:00
# Generating grid for: 17/05/2019 12:00
# Generating grid for: 17/05/2020 12:00
# Generating grid for: 17/06/2019 12:00
# Generating grid for: 17/06/2021 06:00
# Generating grid for: 17/07/2019 06:00
# Generating grid for: 17/07/2020 06:00
# Generating grid for: 17/08/2019 06:00
# Generating grid for: 17/08/2020 06:00
# Generating grid for: 17/08/2021 06:00
# Generating grid for: 17/09/2019 08:00
# Generating grid for: 17/09/2020 08:00
# Generating grid for: 17/09/2021 08:00
# Generating grid for: 17/10/2019 08:00
# Generating grid for: 17/10/2020 10:00
# Generating grid for: 17/10/2021 10:00
# Generating grid for: 17/11/2019 22:00
# Generating grid for: 17/11/2020 22:00
# Generating grid for: 17/11/2021 22:00
# Generating grid for: 17/12/2020 00:00
# Generating grid for: 17/12/2021 00:00
# Generating grid for: 18/01/2019 00:00
# Generating grid for: 18/01/2020 00:00
# Generating grid for: 18/01/2021 00:00
# Generating grid for: 18/02/2019 02:00
# Generating grid for: 18/02/2020 02:00
# Generating grid for: 18/02/2021 13:00
# Generating grid for: 18/03/2019 17:00
# Generating grid for: 18/03/2020 17:00
# Generating grid for: 18/03/2021 17:00
# Generating grid for: 18/04/2020 19:00
# Generating grid for: 18/04/2021 19:00
# Generating grid for: 18/05/2020 19:00
# Generating grid for: 18/06/2019 19:00
# Generating grid for: 18/06/2021 19:00
# Generating grid for: 18/07/2019 19:00
# Generating grid for: 18/07/2020 19:00
# Generating grid for: 18/08/2019 19:00
# Generating grid for: 18/08/2020 19:00
# Generating grid for: 18/08/2021 19:00
# Generating grid for: 18/09/2019 19:00
# Generating grid for: 18/09/2020 19:00
# Generating grid for: 18/09/2021 19:00
# Generating grid for: 18/10/2019 19:00
# Generating grid for: 18/10/2020 19:00
# Generating grid for: 18/11/2019 19:00
# Generating grid for: 18/11/2020 21:00
# Generating grid for: 18/11/2021 23:00
# Generating grid for: 18/12/2019 23:00
# Generating grid for: 18/12/2020 23:00
# Generating grid for: 18/12/2021 23:00
# Generating grid for: 19/01/2019 23:00
# Generating grid for: 19/01/2020 23:00
# Generating grid for: 19/01/2021 23:00
# Generating grid for: 19/02/2019 23:00
# Generating grid for: 19/02/2020 23:00
# Generating grid for: 19/02/2021 23:00
# Generating grid for: 19/03/2020 02:00
# Generating grid for: 19/03/2021 02:00
# Generating grid for: 19/04/2020 04:00
# Generating grid for: 19/04/2021 04:00
# Generating grid for: 19/05/2020 06:00
# Generating grid for: 19/06/2019 06:00
# Generating grid for: 19/06/2020 14:00
# Generating grid for: 19/06/2021 14:00
# Generating grid for: 19/07/2019 14:00
# Generating grid for: 19/07/2020 14:00
# Generating grid for: 19/08/2019 04:00
# Generating grid for: 19/08/2020 04:00
# Generating grid for: 19/08/2021 06:00
# Generating grid for: 19/09/2019 06:00
# Generating grid for: 19/09/2020 06:00
# Generating grid for: 19/09/2021 06:00
# Generating grid for: 19/10/2019 06:00
# Generating grid for: 19/10/2020 07:00
# Generating grid for: 19/11/2019 07:00
# Generating grid for: 19/11/2020 07:00
# Generating grid for: 19/11/2021 07:00
# Generating grid for: 19/12/2019 07:00
# Generating grid for: 19/12/2020 07:00
# Generating grid for: 19/12/2021 07:00
# Generating grid for: 20/01/2019 07:00
# Generating grid for: 20/01/2020 07:00
# Generating grid for: 20/01/2021 07:00
# Generating grid for: 20/02/2019 08:00
# Generating grid for: 20/02/2020 08:00
# Generating grid for: 20/02/2021 10:00
# Generating grid for: 20/03/2019 10:00
# Generating grid for: 20/03/2020 16:00
# Generating grid for: 20/04/2020 16:00
# Generating grid for: 20/04/2021 16:00
# Generating grid for: 20/05/2020 01:00
# Generating grid for: 20/06/2019 01:00
# Generating grid for: 20/06/2020 01:00
# Generating grid for: 20/06/2021 01:00
# Generating grid for: 20/07/2019 01:00
# Generating grid for: 20/07/2020 01:00
# Generating grid for: 20/07/2021 01:00
# Generating grid for: 20/08/2019 01:00
# Generating grid for: 20/08/2020 01:00
# Generating grid for: 20/08/2021 03:00
# Generating grid for: 20/09/2019 03:00
# Generating grid for: 20/09/2020 03:00
# Generating grid for: 20/09/2021 03:00
# Generating grid for: 20/10/2019 03:00
# Generating grid for: 20/10/2020 03:00
# Generating grid for: 20/10/2021 16:00
# Generating grid for: 20/11/2019 16:00
# Generating grid for: 20/11/2020 16:00
# Generating grid for: 20/12/2019 01:00
# Generating grid for: 20/12/2020 05:00
# Generating grid for: 20/12/2021 05:00
# Generating grid for: 21/01/2019 05:00
# Generating grid for: 21/01/2020 05:00
# Generating grid for: 21/01/2021 05:00
# Generating grid for: 21/02/2019 05:00
# Generating grid for: 21/02/2020 07:00
# Generating grid for: 21/02/2021 09:00
# Generating grid for: 21/03/2019 09:00
# Generating grid for: 21/03/2020 21:00
# Generating grid for: 21/04/2020 21:00
# Generating grid for: 21/04/2021 21:00
# Generating grid for: 21/05/2020 01:00
# Generating grid for: 21/06/2019 01:00
# Generating grid for: 21/06/2020 01:00
# Generating grid for: 21/06/2021 01:00
# Generating grid for: 21/07/2019 01:00
# Generating grid for: 21/07/2020 01:00
# Generating grid for: 21/07/2021 01:00
# Generating grid for: 21/08/2019 01:00
# Generating grid for: 21/08/2020 01:00
# Generating grid for: 21/08/2021 01:00
# Generating grid for: 21/09/2019 01:00
# Generating grid for: 21/09/2020 01:00
# Generating grid for: 21/09/2021 01:00
# Generating grid for: 21/10/2019 01:00
# Generating grid for: 21/10/2020 01:00
# Generating grid for: 21/10/2021 01:00
# Generating grid for: 21/11/2019 01:00
# Generating grid for: 21/11/2020 01:00
# Generating grid for: 21/11/2021 01:00
# Generating grid for: 21/12/2020 01:00
# Generating grid for: 21/12/2021 01:00
# Generating grid for: 22/01/2019 01:00
# Generating grid for: 22/01/2020 01:00
# Generating grid for: 22/01/2021 11:00
# Generating grid for: 22/02/2019 11:00
# Generating grid for: 22/02/2020 13:00
# Generating grid for: 22/02/2021 13:00
# Generating grid for: 22/03/2020 04:00
# Generating grid for: 22/04/2020 04:00
# Generating grid for: 22/04/2021 04:00
# Generating grid for: 22/05/2019 04:00
# Generating grid for: 22/05/2020 04:00
# Generating grid for: 22/06/2019 04:00
# Generating grid for: 22/06/2020 04:00
# Generating grid for: 22/06/2021 13:00
# Generating grid for: 22/07/2019 13:00
# Generating grid for: 22/07/2020 13:00
# Generating grid for: 22/07/2021 13:00
# Generating grid for: 22/08/2019 13:00
# Generating grid for: 22/08/2020 13:00
# Generating grid for: 22/08/2021 13:00
# Generating grid for: 22/09/2019 13:00
# Generating grid for: 22/09/2020 13:00
# Generating grid for: 22/09/2021 13:00
# Generating grid for: 22/10/2019 13:00
# Generating grid for: 22/10/2020 13:00
# Generating grid for: 22/10/2021 13:00
# Generating grid for: 22/11/2019 13:00
# Generating grid for: 22/11/2020 13:00
# Generating grid for: 22/11/2021 13:00
# Generating grid for: 22/12/2020 13:00
# Generating grid for: 22/12/2021 13:00
# Generating grid for: 23/01/2019 13:00
# Generating grid for: 23/01/2020 23:00
# Generating grid for: 23/01/2021 23:00
# Generating grid for: 23/02/2019 23:00
# Generating grid for: 23/02/2020 23:00
# Generating grid for: 23/02/2021 23:00
# Generating grid for: 23/03/2020 23:00
# Generating grid for: 23/04/2020 13:00
# Generating grid for: 23/04/2021 13:00
# Generating grid for: 23/05/2019 13:00
# Generating grid for: 23/05/2020 13:00
# Generating grid for: 23/06/2019 13:00
# Generating grid for: 23/06/2021 13:00
# Generating grid for: 23/07/2019 13:00
# Generating grid for: 23/07/2020 13:00
# Generating grid for: 23/07/2021 13:00
# Generating grid for: 23/08/2019 13:00
# Generating grid for: 23/08/2020 13:00
# Generating grid for: 23/08/2021 13:00
# Generating grid for: 23/09/2019 13:00
# Generating grid for: 23/09/2020 13:00
# Generating grid for: 23/09/2021 13:00
# Generating grid for: 23/10/2019 13:00
# Generating grid for: 23/10/2020 13:00
# Generating grid for: 23/10/2021 13:00
# Generating grid for: 23/11/2019 13:00
# Generating grid for: 23/11/2020 13:00
# Generating grid for: 23/11/2021 13:00
# Generating grid for: 23/12/2019 14:00
# Generating grid for: 23/12/2020 14:00
# Generating grid for: 23/12/2021 14:00
# Generating grid for: 24/01/2019 14:00
# Generating grid for: 24/01/2020 14:00
# Generating grid for: 24/01/2021 14:00
# Generating grid for: 24/02/2019 14:00
# Generating grid for: 24/02/2020 14:00
# Generating grid for: 24/02/2021 14:00
# Generating grid for: 24/03/2020 14:00
# Generating grid for: 24/03/2021 14:00
# Generating grid for: 24/04/2020 14:00
# Generating grid for: 24/04/2021 14:00
# Generating grid for: 24/05/2019 14:00
# Generating grid for: 24/05/2020 22:00
# Generating grid for: 24/06/2019 08:00
# Generating grid for: 24/06/2021 08:00
# Generating grid for: 24/07/2019 08:00
# Generating grid for: 24/07/2020 08:00
# Generating grid for: 24/07/2021 08:00
# Generating grid for: 24/08/2019 08:00
# Generating grid for: 24/08/2020 08:00
# Generating grid for: 24/08/2021 08:00
# Generating grid for: 24/09/2019 08:00
# Generating grid for: 24/09/2020 08:00
# Generating grid for: 24/09/2021 08:00
# Generating grid for: 24/10/2019 08:00
# Generating grid for: 24/10/2020 08:00
# Generating grid for: 24/10/2021 08:00
# Generating grid for: 24/11/2019 10:00
# Generating grid for: 24/11/2020 10:00
# Generating grid for: 24/11/2021 10:00
# Generating grid for: 24/12/2019 10:00
# Generating grid for: 24/12/2020 10:00
# Generating grid for: 24/12/2021 10:00
# Generating grid for: 25/01/2019 10:00
# Generating grid for: 25/01/2020 10:00
# Generating grid for: 25/01/2021 10:00
# Generating grid for: 25/02/2019 10:00
# Generating grid for: 25/02/2020 10:00
# Generating grid for: 25/02/2021 11:00
# Generating grid for: 25/03/2020 11:00
# Generating grid for: 25/03/2021 11:00
# Generating grid for: 25/04/2020 11:00
# Generating grid for: 25/04/2021 11:00
# Generating grid for: 25/05/2019 11:00
# Generating grid for: 25/05/2020 11:00
# Generating grid for: 25/05/2021 12:00
# Generating grid for: 25/06/2019 12:00
# Generating grid for: 25/06/2021 12:00
# Generating grid for: 25/07/2019 12:00
# Generating grid for: 25/07/2020 12:00
# Generating grid for: 25/07/2021 12:00
# Generating grid for: 25/08/2019 12:00
# Generating grid for: 25/08/2020 12:00
# Generating grid for: 25/08/2021 12:00
# Generating grid for: 25/09/2019 12:00
# Generating grid for: 25/09/2020 12:00
# Generating grid for: 25/09/2021 12:00
# Generating grid for: 25/10/2019 12:00
# Generating grid for: 25/10/2020 12:00
# Generating grid for: 25/10/2021 13:00
# Generating grid for: 25/11/2019 13:00
# Generating grid for: 25/11/2020 13:00
# Generating grid for: 25/11/2021 13:00
# Generating grid for: 25/12/2019 13:00
# Generating grid for: 25/12/2020 13:00
# Generating grid for: 25/12/2021 13:00
# Generating grid for: 26/01/2019 13:00
# Generating grid for: 26/01/2021 11:00
# Generating grid for: 26/02/2019 11:00
# Generating grid for: 26/02/2020 11:00
# Generating grid for: 26/02/2021 11:00
# Generating grid for: 26/03/2019 23:00
# Generating grid for: 26/03/2020 23:00
# Generating grid for: 26/03/2021 23:00
# Generating grid for: 26/04/2020 23:00
# Generating grid for: 26/04/2021 23:00
# Generating grid for: 26/05/2019 23:00
# Generating grid for: 26/05/2020 23:00
# Generating grid for: 26/05/2021 23:00
# Generating grid for: 26/06/2019 23:00
# Generating grid for: 26/06/2021 23:00
# Generating grid for: 26/07/2019 23:00
# Generating grid for: 26/07/2020 23:00
# Generating grid for: 26/07/2021 23:00
# Generating grid for: 26/08/2019 23:00
# Generating grid for: 26/08/2020 23:00
# Generating grid for: 26/08/2021 23:00
# Generating grid for: 26/09/2019 23:00
# Generating grid for: 26/09/2020 23:00
# Generating grid for: 26/09/2021 23:00
# Generating grid for: 26/10/2020 00:00
# Generating grid for: 26/10/2021 00:00
# Generating grid for: 26/11/2019 02:00
# Generating grid for: 26/11/2020 02:00
# Generating grid for: 26/11/2021 02:00
# Generating grid for: 26/12/2019 02:00
# Generating grid for: 26/12/2020 02:00
# Generating grid for: 26/12/2021 02:00
# Generating grid for: 27/01/2019 02:00
# Generating grid for: 27/01/2021 02:00
# Generating grid for: 27/02/2019 02:00
# Generating grid for: 27/02/2020 02:00
# Generating grid for: 27/02/2021 02:00
# Generating grid for: 27/03/2019 02:00
# Generating grid for: 27/03/2020 02:00
# Generating grid for: 27/03/2021 02:00
# Generating grid for: 27/04/2020 02:00
# Generating grid for: 27/04/2021 02:00
# Generating grid for: 27/05/2019 02:00
# Generating grid for: 27/05/2020 02:00
# Generating grid for: 27/05/2021 02:00
# Generating grid for: 27/06/2019 02:00
# Generating grid for: 27/06/2021 02:00
# Generating grid for: 27/07/2019 02:00
# Generating grid for: 27/07/2020 02:00
# Generating grid for: 27/07/2021 02:00
# Generating grid for: 27/08/2019 02:00
# Generating grid for: 27/08/2020 02:00
# Generating grid for: 27/08/2021 02:00
# Generating grid for: 27/09/2019 02:00
# Generating grid for: 27/09/2020 02:00
# Generating grid for: 27/09/2021 02:00
# Generating grid for: 27/10/2019 02:00
# Generating grid for: 27/10/2020 02:00
# Generating grid for: 27/10/2021 02:00
# Generating grid for: 27/11/2019 07:00
# Generating grid for: 27/11/2020 07:00
# Generating grid for: 27/11/2021 07:00
# Generating grid for: 27/12/2019 07:00
# Generating grid for: 27/12/2020 07:00
# Generating grid for: 27/12/2021 07:00
# Generating grid for: 28/01/2019 07:00
# Generating grid for: 28/01/2021 07:00
# Generating grid for: 28/02/2019 07:00
# Generating grid for: 28/02/2020 07:00
# Generating grid for: 28/02/2021 07:00
# Generating grid for: 28/03/2019 07:00
# Generating grid for: 28/03/2020 07:00
# Generating grid for: 28/03/2021 07:00
# Generating grid for: 28/04/2020 07:00
# Generating grid for: 28/04/2021 07:00
# Generating grid for: 28/05/2019 07:00
# Generating grid for: 28/05/2020 07:00
# Generating grid for: 28/05/2021 07:00
# Generating grid for: 28/06/2019 07:00
# Generating grid for: 28/06/2021 07:00
# Generating grid for: 28/07/2019 07:00
# Generating grid for: 28/07/2020 07:00
# Generating grid for: 28/07/2021 07:00
# Generating grid for: 28/08/2019 07:00
# Generating grid for: 28/08/2020 07:00
# Generating grid for: 28/08/2021 07:00
# Generating grid for: 28/09/2019 07:00
# Generating grid for: 28/09/2020 07:00
# Generating grid for: 28/09/2021 07:00
# Generating grid for: 28/10/2019 07:00
# Generating grid for: 28/10/2020 07:00
# Generating grid for: 28/10/2021 07:00
# Generating grid for: 28/11/2019 15:00
# Generating grid for: 28/11/2020 15:00
# Generating grid for: 28/11/2021 15:00
# Generating grid for: 28/12/2019 15:00
# Generating grid for: 28/12/2020 15:00
# Generating grid for: 28/12/2021 15:00
# Generating grid for: 29/01/2019 15:00
# Generating grid for: 29/01/2021 15:00
# Generating grid for: 29/02/2020 15:00
# Generating grid for: 29/03/2019 15:00
# Generating grid for: 29/03/2020 15:00
# Generating grid for: 29/03/2021 15:00
# Generating grid for: 29/04/2020 15:00
# Generating grid for: 29/04/2021 15:00
# Generating grid for: 29/05/2019 15:00
# Generating grid for: 29/05/2020 15:00
# Generating grid for: 29/05/2021 15:00
# Generating grid for: 29/06/2019 15:00
# Generating grid for: 29/06/2021 15:00
# Generating grid for: 29/07/2019 15:00
# Generating grid for: 29/07/2020 15:00
# Generating grid for: 29/07/2021 15:00
# Generating grid for: 29/08/2019 15:00
# Generating grid for: 29/08/2020 15:00
# Generating grid for: 29/08/2021 15:00
# Generating grid for: 29/09/2019 15:00
# Generating grid for: 29/09/2020 15:00
# Generating grid for: 29/09/2021 15:00
# Generating grid for: 29/10/2019 15:00
# Generating grid for: 29/10/2020 15:00
# Generating grid for: 29/10/2021 16:00
# Generating grid for: 29/11/2019 16:00
# Generating grid for: 29/11/2020 16:00
# Generating grid for: 29/11/2021 16:00
# Generating grid for: 29/12/2019 16:00
# Generating grid for: 29/12/2021 00:00
# Generating grid for: 30/01/2019 00:00
# Generating grid for: 30/01/2020 00:00
# Generating grid for: 30/03/2019 03:00
# Generating grid for: 30/03/2020 03:00
# Generating grid for: 30/03/2021 03:00
# Generating grid for: 30/04/2019 18:00
# Generating grid for: 30/04/2020 18:00
# Generating grid for: 30/04/2021 18:00
# Generating grid for: 30/05/2019 18:00
# Generating grid for: 30/05/2020 18:00
# Generating grid for: 30/05/2021 18:00
# Generating grid for: 30/06/2019 18:00
# Generating grid for: 30/07/2019 06:00
# Generating grid for: 30/07/2020 06:00
# Generating grid for: 30/07/2021 06:00
# Generating grid for: 30/08/2019 06:00
# Generating grid for: 30/08/2020 06:00
# Generating grid for: 30/08/2021 06:00
# Generating grid for: 30/09/2019 06:00
# Generating grid for: 30/09/2020 06:00
# Generating grid for: 30/09/2021 06:00
# Generating grid for: 30/10/2019 06:00
# Generating grid for: 30/10/2020 06:00
# Generating grid for: 30/10/2021 13:00
# Generating grid for: 30/11/2019 13:00
# Generating grid for: 30/11/2020 13:00
# Generating grid for: 30/11/2021 13:00
# Generating grid for: 30/12/2019 13:00
# Generating grid for: 30/12/2020 13:00
# Generating grid for: 30/12/2021 15:00
# Generating grid for: 31/01/2019 15:00
# Generating grid for: 31/01/2020 20:00
# Generating grid for: 31/03/2019 18:00
# Generating grid for: 31/03/2020 18:00
# Generating grid for: 31/03/2021 18:00
# Generating grid for: 31/05/2019 18:00
# Generating grid for: 31/05/2020 18:00
# Generating grid for: 31/05/2021 18:00
# Generating grid for: 31/07/2019 18:00
# Generating grid for: 31/07/2020 18:00
# Generating grid for: 31/07/2021 18:00
# Generating grid for: 31/08/2019 18:00
# Generating grid for: 31/08/2020 18:00
# Generating grid for: 31/08/2021 18:00
# Generating grid for: 31/10/2019 18:00
# Generating grid for: 31/10/2021 18:00
# Generating grid for: 31/12/2019 18:00
# Generating grid for: 31/12/2020 18:00
# Generating grid for: 31/12/2021 18:00

# %%
for i in range(len(pm10_inter)):
    pm10_inter[i] = np.fliplr(np.rot90(np.rot90(np.rot90(pm10_inter[i]))))

# %%
for i in range(len(pm25_inter)):
    pm25_inter[i] = np.fliplr(np.rot90(np.rot90(np.rot90(pm25_inter[i]))))

# %%
from scipy.interpolate import NearestNDInterpolator
import matplotlib.pyplot as plt
def interpolate_frames(frames):
    i = 0
    interpolated = []
    count = 0
    idx = 0
    for f in frames:
        try:
            if count == 24:
                print("Interpolating grid for day ", idx)
                idx += 1
                count = 0
            x_list = []
            y_list = []
            values = []
            for x in range(f.shape[0]):
                for y in range(f.shape[1]):
                    if f[x,y] != 0:
                        x_list.append(x)
                        y_list.append(y)
                        values.append(f[x,y])
            coords = list(zip(x_list,y_list))
            interp = NearestNDInterpolator(coords, values)
            X = np.arange(0,30)
            Y = np.arange(0,30)
            X, Y = np.meshgrid(X, Y)
            Z = interp(X, Y)
            interpolated.append(Z)
            count += 1
            i += 1
        except ValueError:
            continue
    interpolated = np.array(interpolated)
    return interpolated

# %%
pm25_inter = interpolate_frames(pm25_frames)
# Out:
# Interpolating grid for day  0
# Interpolating grid for day  1
# Interpolating grid for day  2
# Interpolating grid for day  3
# Interpolating grid for day  4
# Interpolating grid for day  5
# Interpolating grid for day  6
# Interpolating grid for day  7
# Interpolating grid for day  8
# Interpolating grid for day  9
# Interpolating grid for day  10
# Interpolating grid for day  11
# Interpolating grid for day  12
# Interpolating grid for day  13
# Interpolating grid for day  14
# Interpolating grid for day  15
# Interpolating grid for day  16
# Interpolating grid for day  17
# Interpolating grid for day  18
# Interpolating grid for day  19
# Interpolating grid for day  20
# Interpolating grid for day  21
# Interpolating grid for day  22
# Interpolating grid for day  23
# Interpolating grid for day  24
# Interpolating grid for day  25
# Interpolating grid for day  26
# Interpolating grid for day  27
# Interpolating grid for day  28
# Interpolating grid for day  29
# Interpolating grid for day  30
# Interpolating grid for day  31
# Interpolating grid for day  32
# Interpolating grid for day  33
# Interpolating grid for day  34
# Interpolating grid for day  35
# Interpolating grid for day  36
# Interpolating grid for day  37
# Interpolating grid for day  38
# Interpolating grid for day  39
# Interpolating grid for day  40
# Interpolating grid for day  41
# Interpolating grid for day  42
# Interpolating grid for day  43
# Interpolating grid for day  44
# Interpolating grid for day  45
# Interpolating grid for day  46
# Interpolating grid for day  47
# Interpolating grid for day  48
# Interpolating grid for day  49
# Interpolating grid for day  50
# Interpolating grid for day  51
# Interpolating grid for day  52
# Interpolating grid for day  53
# Interpolating grid for day  54
# Interpolating grid for day  55
# Interpolating grid for day  56
# Interpolating grid for day  57
# Interpolating grid for day  58
# Interpolating grid for day  59
# Interpolating grid for day  60
# Interpolating grid for day  61
# Interpolating grid for day  62
# Interpolating grid for day  63
# Interpolating grid for day  64
# Interpolating grid for day  65
# Interpolating grid for day  66
# Interpolating grid for day  67
# Interpolating grid for day  68
# Interpolating grid for day  69
# Interpolating grid for day  70
# Interpolating grid for day  71
# Interpolating grid for day  72
# Interpolating grid for day  73
# Interpolating grid for day  74
# Interpolating grid for day  75
# Interpolating grid for day  76
# Interpolating grid for day  77
# Interpolating grid for day  78
# Interpolating grid for day  79
# Interpolating grid for day  80
# Interpolating grid for day  81
# Interpolating grid for day  82
# Interpolating grid for day  83
# Interpolating grid for day  84
# Interpolating grid for day  85
# Interpolating grid for day  86
# Interpolating grid for day  87
# Interpolating grid for day  88
# Interpolating grid for day  89
# Interpolating grid for day  90
# Interpolating grid for day  91
# Interpolating grid for day  92
# Interpolating grid for day  93
# Interpolating grid for day  94
# Interpolating grid for day  95
# Interpolating grid for day  96
# Interpolating grid for day  97
# Interpolating grid for day  98
# Interpolating grid for day  99
# Interpolating grid for day  100
# Interpolating grid for day  101
# Interpolating grid for day  102
# Interpolating grid for day  103
# Interpolating grid for day  104
# Interpolating grid for day  105
# Interpolating grid for day  106
# Interpolating grid for day  107
# Interpolating grid for day  108
# Interpolating grid for day  109
# Interpolating grid for day  110
# Interpolating grid for day  111
# Interpolating grid for day  112
# Interpolating grid for day  113
# Interpolating grid for day  114
# Interpolating grid for day  115
# Interpolating grid for day  116
# Interpolating grid for day  117
# Interpolating grid for day  118
# Interpolating grid for day  119
# Interpolating grid for day  120
# Interpolating grid for day  121
# Interpolating grid for day  122
# Interpolating grid for day  123
# Interpolating grid for day  124
# Interpolating grid for day  125
# Interpolating grid for day  126
# Interpolating grid for day  127
# Interpolating grid for day  128
# Interpolating grid for day  129
# Interpolating grid for day  130
# Interpolating grid for day  131
# Interpolating grid for day  132
# Interpolating grid for day  133
# Interpolating grid for day  134
# Interpolating grid for day  135
# Interpolating grid for day  136
# Interpolating grid for day  137
# Interpolating grid for day  138
# Interpolating grid for day  139
# Interpolating grid for day  140
# Interpolating grid for day  141
# Interpolating grid for day  142
# Interpolating grid for day  143
# Interpolating grid for day  144
# Interpolating grid for day  145
# Interpolating grid for day  146
# Interpolating grid for day  147
# Interpolating grid for day  148
# Interpolating grid for day  149
# Interpolating grid for day  150
# Interpolating grid for day  151
# Interpolating grid for day  152
# Interpolating grid for day  153
# Interpolating grid for day  154
# Interpolating grid for day  155
# Interpolating grid for day  156
# Interpolating grid for day  157
# Interpolating grid for day  158
# Interpolating grid for day  159
# Interpolating grid for day  160
# Interpolating grid for day  161
# Interpolating grid for day  162
# Interpolating grid for day  163
# Interpolating grid for day  164
# Interpolating grid for day  165
# Interpolating grid for day  166
# Interpolating grid for day  167
# Interpolating grid for day  168
# Interpolating grid for day  169
# Interpolating grid for day  170
# Interpolating grid for day  171
# Interpolating grid for day  172
# Interpolating grid for day  173
# Interpolating grid for day  174
# Interpolating grid for day  175
# Interpolating grid for day  176
# Interpolating grid for day  177
# Interpolating grid for day  178
# Interpolating grid for day  179
# Interpolating grid for day  180
# Interpolating grid for day  181
# Interpolating grid for day  182
# Interpolating grid for day  183
# Interpolating grid for day  184
# Interpolating grid for day  185
# Interpolating grid for day  186
# Interpolating grid for day  187
# Interpolating grid for day  188
# Interpolating grid for day  189
# Interpolating grid for day  190
# Interpolating grid for day  191
# Interpolating grid for day  192
# Interpolating grid for day  193
# Interpolating grid for day  194
# Interpolating grid for day  195
# Interpolating grid for day  196
# Interpolating grid for day  197
# Interpolating grid for day  198
# Interpolating grid for day  199
# Interpolating grid for day  200
# Interpolating grid for day  201
# Interpolating grid for day  202
# Interpolating grid for day  203
# Interpolating grid for day  204
# Interpolating grid for day  205
# Interpolating grid for day  206
# Interpolating grid for day  207
# Interpolating grid for day  208
# Interpolating grid for day  209
# Interpolating grid for day  210
# Interpolating grid for day  211
# Interpolating grid for day  212
# Interpolating grid for day  213
# Interpolating grid for day  214
# Interpolating grid for day  215
# Interpolating grid for day  216
# Interpolating grid for day  217
# Interpolating grid for day  218
# Interpolating grid for day  219
# Interpolating grid for day  220
# Interpolating grid for day  221
# Interpolating grid for day  222
# Interpolating grid for day  223
# Interpolating grid for day  224
# Interpolating grid for day  225
# Interpolating grid for day  226
# Interpolating grid for day  227
# Interpolating grid for day  228
# Interpolating grid for day  229
# Interpolating grid for day  230
# Interpolating grid for day  231
# Interpolating grid for day  232
# Interpolating grid for day  233
# Interpolating grid for day  234
# Interpolating grid for day  235
# Interpolating grid for day  236
# Interpolating grid for day  237
# Interpolating grid for day  238
# Interpolating grid for day  239
# Interpolating grid for day  240
# Interpolating grid for day  241
# Interpolating grid for day  242
# Interpolating grid for day  243
# Interpolating grid for day  244
# Interpolating grid for day  245
# Interpolating grid for day  246
# Interpolating grid for day  247
# Interpolating grid for day  248
# Interpolating grid for day  249
# Interpolating grid for day  250
# Interpolating grid for day  251
# Interpolating grid for day  252
# Interpolating grid for day  253
# Interpolating grid for day  254
# Interpolating grid for day  255
# Interpolating grid for day  256
# Interpolating grid for day  257
# Interpolating grid for day  258
# Interpolating grid for day  259
# Interpolating grid for day  260
# Interpolating grid for day  261
# Interpolating grid for day  262
# Interpolating grid for day  263
# Interpolating grid for day  264
# Interpolating grid for day  265
# Interpolating grid for day  266
# Interpolating grid for day  267
# Interpolating grid for day  268
# Interpolating grid for day  269
# Interpolating grid for day  270
# Interpolating grid for day  271
# Interpolating grid for day  272
# Interpolating grid for day  273
# Interpolating grid for day  274
# Interpolating grid for day  275
# Interpolating grid for day  276
# Interpolating grid for day  277
# Interpolating grid for day  278
# Interpolating grid for day  279
# Interpolating grid for day  280
# Interpolating grid for day  281
# Interpolating grid for day  282
# Interpolating grid for day  283
# Interpolating grid for day  284
# Interpolating grid for day  285
# Interpolating grid for day  286
# Interpolating grid for day  287
# Interpolating grid for day  288
# Interpolating grid for day  289
# Interpolating grid for day  290
# Interpolating grid for day  291
# Interpolating grid for day  292
# Interpolating grid for day  293
# Interpolating grid for day  294
# Interpolating grid for day  295
# Interpolating grid for day  296
# Interpolating grid for day  297
# Interpolating grid for day  298
# Interpolating grid for day  299
# Interpolating grid for day  300
# Interpolating grid for day  301
# Interpolating grid for day  302
# Interpolating grid for day  303
# Interpolating grid for day  304
# Interpolating grid for day  305
# Interpolating grid for day  306
# Interpolating grid for day  307
# Interpolating grid for day  308
# Interpolating grid for day  309
# Interpolating grid for day  310
# Interpolating grid for day  311
# Interpolating grid for day  312
# Interpolating grid for day  313
# Interpolating grid for day  314
# Interpolating grid for day  315
# Interpolating grid for day  316
# Interpolating grid for day  317
# Interpolating grid for day  318
# Interpolating grid for day  319
# Interpolating grid for day  320
# Interpolating grid for day  321
# Interpolating grid for day  322
# Interpolating grid for day  323
# Interpolating grid for day  324
# Interpolating grid for day  325
# Interpolating grid for day  326
# Interpolating grid for day  327
# Interpolating grid for day  328
# Interpolating grid for day  329
# Interpolating grid for day  330
# Interpolating grid for day  331
# Interpolating grid for day  332
# Interpolating grid for day  333
# Interpolating grid for day  334
# Interpolating grid for day  335
# Interpolating grid for day  336
# Interpolating grid for day  337
# Interpolating grid for day  338
# Interpolating grid for day  339
# Interpolating grid for day  340
# Interpolating grid for day  341
# Interpolating grid for day  342
# Interpolating grid for day  343
# Interpolating grid for day  344
# Interpolating grid for day  345
# Interpolating grid for day  346
# Interpolating grid for day  347
# Interpolating grid for day  348
# Interpolating grid for day  349
# Interpolating grid for day  350
# Interpolating grid for day  351
# Interpolating grid for day  352
# Interpolating grid for day  353
# Interpolating grid for day  354
# Interpolating grid for day  355
# Interpolating grid for day  356
# Interpolating grid for day  357
# Interpolating grid for day  358
# Interpolating grid for day  359
# Interpolating grid for day  360
# Interpolating grid for day  361
# Interpolating grid for day  362
# Interpolating grid for day  363
# Interpolating grid for day  364
# Interpolating grid for day  365
# Interpolating grid for day  366
# Interpolating grid for day  367
# Interpolating grid for day  368
# Interpolating grid for day  369
# Interpolating grid for day  370
# Interpolating grid for day  371
# Interpolating grid for day  372
# Interpolating grid for day  373
# Interpolating grid for day  374
# Interpolating grid for day  375
# Interpolating grid for day  376
# Interpolating grid for day  377
# Interpolating grid for day  378
# Interpolating grid for day  379
# Interpolating grid for day  380
# Interpolating grid for day  381
# Interpolating grid for day  382
# Interpolating grid for day  383
# Interpolating grid for day  384
# Interpolating grid for day  385
# Interpolating grid for day  386
# Interpolating grid for day  387
# Interpolating grid for day  388
# Interpolating grid for day  389
# Interpolating grid for day  390
# Interpolating grid for day  391
# Interpolating grid for day  392
# Interpolating grid for day  393
# Interpolating grid for day  394
# Interpolating grid for day  395
# Interpolating grid for day  396
# Interpolating grid for day  397
# Interpolating grid for day  398
# Interpolating grid for day  399
# Interpolating grid for day  400
# Interpolating grid for day  401
# Interpolating grid for day  402
# Interpolating grid for day  403
# Interpolating grid for day  404
# Interpolating grid for day  405
# Interpolating grid for day  406
# Interpolating grid for day  407
# Interpolating grid for day  408
# Interpolating grid for day  409
# Interpolating grid for day  410
# Interpolating grid for day  411
# Interpolating grid for day  412
# Interpolating grid for day  413
# Interpolating grid for day  414
# Interpolating grid for day  415
# Interpolating grid for day  416
# Interpolating grid for day  417
# Interpolating grid for day  418
# Interpolating grid for day  419
# Interpolating grid for day  420
# Interpolating grid for day  421
# Interpolating grid for day  422
# Interpolating grid for day  423
# Interpolating grid for day  424
# Interpolating grid for day  425
# Interpolating grid for day  426
# Interpolating grid for day  427
# Interpolating grid for day  428
# Interpolating grid for day  429
# Interpolating grid for day  430
# Interpolating grid for day  431
# Interpolating grid for day  432
# Interpolating grid for day  433
# Interpolating grid for day  434
# Interpolating grid for day  435
# Interpolating grid for day  436
# Interpolating grid for day  437
# Interpolating grid for day  438
# Interpolating grid for day  439
# Interpolating grid for day  440
# Interpolating grid for day  441
# Interpolating grid for day  442
# Interpolating grid for day  443
# Interpolating grid for day  444
# Interpolating grid for day  445
# Interpolating grid for day  446
# Interpolating grid for day  447
# Interpolating grid for day  448
# Interpolating grid for day  449
# Interpolating grid for day  450
# Interpolating grid for day  451
# Interpolating grid for day  452
# Interpolating grid for day  453
# Interpolating grid for day  454
# Interpolating grid for day  455
# Interpolating grid for day  456
# Interpolating grid for day  457
# Interpolating grid for day  458
# Interpolating grid for day  459
# Interpolating grid for day  460
# Interpolating grid for day  461
# Interpolating grid for day  462
# Interpolating grid for day  463
# Interpolating grid for day  464
# Interpolating grid for day  465
# Interpolating grid for day  466
# Interpolating grid for day  467
# Interpolating grid for day  468
# Interpolating grid for day  469
# Interpolating grid for day  470
# Interpolating grid for day  471
# Interpolating grid for day  472
# Interpolating grid for day  473
# Interpolating grid for day  474
# Interpolating grid for day  475
# Interpolating grid for day  476
# Interpolating grid for day  477
# Interpolating grid for day  478
# Interpolating grid for day  479
# Interpolating grid for day  480
# Interpolating grid for day  481
# Interpolating grid for day  482
# Interpolating grid for day  483
# Interpolating grid for day  484
# Interpolating grid for day  485
# Interpolating grid for day  486
# Interpolating grid for day  487
# Interpolating grid for day  488
# Interpolating grid for day  489
# Interpolating grid for day  490
# Interpolating grid for day  491
# Interpolating grid for day  492
# Interpolating grid for day  493
# Interpolating grid for day  494
# Interpolating grid for day  495
# Interpolating grid for day  496
# Interpolating grid for day  497
# Interpolating grid for day  498
# Interpolating grid for day  499
# Interpolating grid for day  500
# Interpolating grid for day  501
# Interpolating grid for day  502
# Interpolating grid for day  503
# Interpolating grid for day  504
# Interpolating grid for day  505
# Interpolating grid for day  506
# Interpolating grid for day  507
# Interpolating grid for day  508
# Interpolating grid for day  509
# Interpolating grid for day  510
# Interpolating grid for day  511
# Interpolating grid for day  512
# Interpolating grid for day  513
# Interpolating grid for day  514
# Interpolating grid for day  515
# Interpolating grid for day  516
# Interpolating grid for day  517
# Interpolating grid for day  518
# Interpolating grid for day  519
# Interpolating grid for day  520
# Interpolating grid for day  521
# Interpolating grid for day  522
# Interpolating grid for day  523
# Interpolating grid for day  524
# Interpolating grid for day  525
# Interpolating grid for day  526
# Interpolating grid for day  527
# Interpolating grid for day  528
# Interpolating grid for day  529
# Interpolating grid for day  530
# Interpolating grid for day  531
# Interpolating grid for day  532
# Interpolating grid for day  533
# Interpolating grid for day  534
# Interpolating grid for day  535
# Interpolating grid for day  536
# Interpolating grid for day  537
# Interpolating grid for day  538
# Interpolating grid for day  539
# Interpolating grid for day  540
# Interpolating grid for day  541
# Interpolating grid for day  542
# Interpolating grid for day  543
# Interpolating grid for day  544
# Interpolating grid for day  545
# Interpolating grid for day  546
# Interpolating grid for day  547
# Interpolating grid for day  548
# Interpolating grid for day  549
# Interpolating grid for day  550
# Interpolating grid for day  551
# Interpolating grid for day  552
# Interpolating grid for day  553
# Interpolating grid for day  554
# Interpolating grid for day  555
# Interpolating grid for day  556
# Interpolating grid for day  557
# Interpolating grid for day  558
# Interpolating grid for day  559
# Interpolating grid for day  560
# Interpolating grid for day  561
# Interpolating grid for day  562
# Interpolating grid for day  563
# Interpolating grid for day  564
# Interpolating grid for day  565
# Interpolating grid for day  566
# Interpolating grid for day  567
# Interpolating grid for day  568
# Interpolating grid for day  569
# Interpolating grid for day  570
# Interpolating grid for day  571
# Interpolating grid for day  572
# Interpolating grid for day  573
# Interpolating grid for day  574
# Interpolating grid for day  575
# Interpolating grid for day  576
# Interpolating grid for day  577
# Interpolating grid for day  578
# Interpolating grid for day  579
# Interpolating grid for day  580
# Interpolating grid for day  581
# Interpolating grid for day  582
# Interpolating grid for day  583
# Interpolating grid for day  584
# Interpolating grid for day  585
# Interpolating grid for day  586
# Interpolating grid for day  587
# Interpolating grid for day  588
# Interpolating grid for day  589
# Interpolating grid for day  590
# Interpolating grid for day  591
# Interpolating grid for day  592
# Interpolating grid for day  593
# Interpolating grid for day  594
# Interpolating grid for day  595
# Interpolating grid for day  596
# Interpolating grid for day  597
# Interpolating grid for day  598
# Interpolating grid for day  599
# Interpolating grid for day  600
# Interpolating grid for day  601
# Interpolating grid for day  602
# Interpolating grid for day  603
# Interpolating grid for day  604
# Interpolating grid for day  605
# Interpolating grid for day  606
# Interpolating grid for day  607
# Interpolating grid for day  608
# Interpolating grid for day  609
# Interpolating grid for day  610
# Interpolating grid for day  611
# Interpolating grid for day  612
# Interpolating grid for day  613
# Interpolating grid for day  614
# Interpolating grid for day  615
# Interpolating grid for day  616
# Interpolating grid for day  617
# Interpolating grid for day  618
# Interpolating grid for day  619
# Interpolating grid for day  620
# Interpolating grid for day  621
# Interpolating grid for day  622
# Interpolating grid for day  623
# Interpolating grid for day  624
# Interpolating grid for day  625
# Interpolating grid for day  626
# Interpolating grid for day  627
# Interpolating grid for day  628
# Interpolating grid for day  629
# Interpolating grid for day  630
# Interpolating grid for day  631
# Interpolating grid for day  632
# Interpolating grid for day  633
# Interpolating grid for day  634
# Interpolating grid for day  635
# Interpolating grid for day  636
# Interpolating grid for day  637
# Interpolating grid for day  638
# Interpolating grid for day  639
# Interpolating grid for day  640
# Interpolating grid for day  641
# Interpolating grid for day  642
# Interpolating grid for day  643
# Interpolating grid for day  644
# Interpolating grid for day  645
# Interpolating grid for day  646
# Interpolating grid for day  647
# Interpolating grid for day  648
# Interpolating grid for day  649
# Interpolating grid for day  650
# Interpolating grid for day  651
# Interpolating grid for day  652
# Interpolating grid for day  653
# Interpolating grid for day  654
# Interpolating grid for day  655
# Interpolating grid for day  656
# Interpolating grid for day  657
# Interpolating grid for day  658
# Interpolating grid for day  659
# Interpolating grid for day  660
# Interpolating grid for day  661
# Interpolating grid for day  662
# Interpolating grid for day  663
# Interpolating grid for day  664
# Interpolating grid for day  665
# Interpolating grid for day  666
# Interpolating grid for day  667
# Interpolating grid for day  668
# Interpolating grid for day  669
# Interpolating grid for day  670
# Interpolating grid for day  671
# Interpolating grid for day  672
# Interpolating grid for day  673
# Interpolating grid for day  674
# Interpolating grid for day  675
# Interpolating grid for day  676
# Interpolating grid for day  677
# Interpolating grid for day  678
# Interpolating grid for day  679
# Interpolating grid for day  680
# Interpolating grid for day  681
# Interpolating grid for day  682
# Interpolating grid for day  683
# Interpolating grid for day  684
# Interpolating grid for day  685
# Interpolating grid for day  686
# Interpolating grid for day  687
# Interpolating grid for day  688
# Interpolating grid for day  689
# Interpolating grid for day  690
# Interpolating grid for day  691
# Interpolating grid for day  692
# Interpolating grid for day  693
# Interpolating grid for day  694
# Interpolating grid for day  695
# Interpolating grid for day  696
# Interpolating grid for day  697
# Interpolating grid for day  698
# Interpolating grid for day  699
# Interpolating grid for day  700
# Interpolating grid for day  701
# Interpolating grid for day  702
# Interpolating grid for day  703
# Interpolating grid for day  704
# Interpolating grid for day  705
# Interpolating grid for day  706
# Interpolating grid for day  707
# Interpolating grid for day  708
# Interpolating grid for day  709
# Interpolating grid for day  710
# Interpolating grid for day  711
# Interpolating grid for day  712
# Interpolating grid for day  713
# Interpolating grid for day  714
# Interpolating grid for day  715
# Interpolating grid for day  716
# Interpolating grid for day  717
# Interpolating grid for day  718
# Interpolating grid for day  719
# Interpolating grid for day  720
# Interpolating grid for day  721
# Interpolating grid for day  722
# Interpolating grid for day  723
# Interpolating grid for day  724
# Interpolating grid for day  725
# Interpolating grid for day  726
# Interpolating grid for day  727
# Interpolating grid for day  728
# Interpolating grid for day  729
# Interpolating grid for day  730
# Interpolating grid for day  731
# Interpolating grid for day  732
# Interpolating grid for day  733
# Interpolating grid for day  734
# Interpolating grid for day  735
# Interpolating grid for day  736
# Interpolating grid for day  737
# Interpolating grid for day  738
# Interpolating grid for day  739
# Interpolating grid for day  740
# Interpolating grid for day  741
# Interpolating grid for day  742
# Interpolating grid for day  743
# Interpolating grid for day  744
# Interpolating grid for day  745
# Interpolating grid for day  746
# Interpolating grid for day  747
# Interpolating grid for day  748
# Interpolating grid for day  749
# Interpolating grid for day  750
# Interpolating grid for day  751
# Interpolating grid for day  752
# Interpolating grid for day  753
# Interpolating grid for day  754
# Interpolating grid for day  755
# Interpolating grid for day  756
# Interpolating grid for day  757
# Interpolating grid for day  758
# Interpolating grid for day  759
# Interpolating grid for day  760
# Interpolating grid for day  761
# Interpolating grid for day  762
# Interpolating grid for day  763
# Interpolating grid for day  764
# Interpolating grid for day  765
# Interpolating grid for day  766
# Interpolating grid for day  767
# Interpolating grid for day  768
# Interpolating grid for day  769
# Interpolating grid for day  770
# Interpolating grid for day  771
# Interpolating grid for day  772
# Interpolating grid for day  773
# Interpolating grid for day  774
# Interpolating grid for day  775
# Interpolating grid for day  776
# Interpolating grid for day  777
# Interpolating grid for day  778
# Interpolating grid for day  779
# Interpolating grid for day  780
# Interpolating grid for day  781
# Interpolating grid for day  782
# Interpolating grid for day  783
# Interpolating grid for day  784
# Interpolating grid for day  785
# Interpolating grid for day  786
# Interpolating grid for day  787
# Interpolating grid for day  788
# Interpolating grid for day  789
# Interpolating grid for day  790
# Interpolating grid for day  791
# Interpolating grid for day  792
# Interpolating grid for day  793
# Interpolating grid for day  794
# Interpolating grid for day  795
# Interpolating grid for day  796
# Interpolating grid for day  797
# Interpolating grid for day  798
# Interpolating grid for day  799
# Interpolating grid for day  800
# Interpolating grid for day  801
# Interpolating grid for day  802
# Interpolating grid for day  803
# Interpolating grid for day  804
# Interpolating grid for day  805
# Interpolating grid for day  806
# Interpolating grid for day  807
# Interpolating grid for day  808
# Interpolating grid for day  809
# Interpolating grid for day  810
# Interpolating grid for day  811
# Interpolating grid for day  812
# Interpolating grid for day  813
# Interpolating grid for day  814
# Interpolating grid for day  815
# Interpolating grid for day  816
# Interpolating grid for day  817
# Interpolating grid for day  818
# Interpolating grid for day  819
# Interpolating grid for day  820
# Interpolating grid for day  821
# Interpolating grid for day  822
# Interpolating grid for day  823
# Interpolating grid for day  824
# Interpolating grid for day  825
# Interpolating grid for day  826
# Interpolating grid for day  827
# Interpolating grid for day  828
# Interpolating grid for day  829
# Interpolating grid for day  830
# Interpolating grid for day  831
# Interpolating grid for day  832
# Interpolating grid for day  833
# Interpolating grid for day  834
# Interpolating grid for day  835
# Interpolating grid for day  836
# Interpolating grid for day  837
# Interpolating grid for day  838
# Interpolating grid for day  839
# Interpolating grid for day  840
# Interpolating grid for day  841
# Interpolating grid for day  842
# Interpolating grid for day  843
# Interpolating grid for day  844
# Interpolating grid for day  845
# Interpolating grid for day  846
# Interpolating grid for day  847
# Interpolating grid for day  848
# Interpolating grid for day  849
# Interpolating grid for day  850
# Interpolating grid for day  851
# Interpolating grid for day  852
# Interpolating grid for day  853
# Interpolating grid for day  854
# Interpolating grid for day  855
# Interpolating grid for day  856
# Interpolating grid for day  857
# Interpolating grid for day  858
# Interpolating grid for day  859
# Interpolating grid for day  860
# Interpolating grid for day  861
# Interpolating grid for day  862
# Interpolating grid for day  863
# Interpolating grid for day  864
# Interpolating grid for day  865
# Interpolating grid for day  866
# Interpolating grid for day  867
# Interpolating grid for day  868
# Interpolating grid for day  869
# Interpolating grid for day  870
# Interpolating grid for day  871
# Interpolating grid for day  872
# Interpolating grid for day  873
# Interpolating grid for day  874
# Interpolating grid for day  875
# Interpolating grid for day  876
# Interpolating grid for day  877
# Interpolating grid for day  878
# Interpolating grid for day  879
# Interpolating grid for day  880
# Interpolating grid for day  881
# Interpolating grid for day  882
# Interpolating grid for day  883
# Interpolating grid for day  884
# Interpolating grid for day  885
# Interpolating grid for day  886
# Interpolating grid for day  887
# Interpolating grid for day  888
# Interpolating grid for day  889
# Interpolating grid for day  890
# Interpolating grid for day  891
# Interpolating grid for day  892
# Interpolating grid for day  893
# Interpolating grid for day  894
# Interpolating grid for day  895
# Interpolating grid for day  896
# Interpolating grid for day  897
# Interpolating grid for day  898
# Interpolating grid for day  899
# Interpolating grid for day  900
# Interpolating grid for day  901
# Interpolating grid for day  902
# Interpolating grid for day  903
# Interpolating grid for day  904
# Interpolating grid for day  905
# Interpolating grid for day  906
# Interpolating grid for day  907
# Interpolating grid for day  908
# Interpolating grid for day  909
# Interpolating grid for day  910
# Interpolating grid for day  911
# Interpolating grid for day  912
# Interpolating grid for day  913
# Interpolating grid for day  914
# Interpolating grid for day  915
# Interpolating grid for day  916
# Interpolating grid for day  917
# Interpolating grid for day  918
# Interpolating grid for day  919
# Interpolating grid for day  920
# Interpolating grid for day  921
# Interpolating grid for day  922
# Interpolating grid for day  923
# Interpolating grid for day  924
# Interpolating grid for day  925
# Interpolating grid for day  926
# Interpolating grid for day  927
# Interpolating grid for day  928
# Interpolating grid for day  929
# Interpolating grid for day  930
# Interpolating grid for day  931
# Interpolating grid for day  932
# Interpolating grid for day  933
# Interpolating grid for day  934
# Interpolating grid for day  935
# Interpolating grid for day  936
# Interpolating grid for day  937
# Interpolating grid for day  938
# Interpolating grid for day  939
# Interpolating grid for day  940
# Interpolating grid for day  941
# Interpolating grid for day  942
# Interpolating grid for day  943
# Interpolating grid for day  944
# Interpolating grid for day  945
# Interpolating grid for day  946
# Interpolating grid for day  947
# Interpolating grid for day  948
# Interpolating grid for day  949
# Interpolating grid for day  950
# Interpolating grid for day  951
# Interpolating grid for day  952
# Interpolating grid for day  953
# Interpolating grid for day  954
# Interpolating grid for day  955
# Interpolating grid for day  956
# Interpolating grid for day  957
# Interpolating grid for day  958
# Interpolating grid for day  959
# Interpolating grid for day  960
# Interpolating grid for day  961
# Interpolating grid for day  962
# Interpolating grid for day  963
# Interpolating grid for day  964
# Interpolating grid for day  965
# Interpolating grid for day  966
# Interpolating grid for day  967
# Interpolating grid for day  968
# Interpolating grid for day  969
# Interpolating grid for day  970
# Interpolating grid for day  971
# Interpolating grid for day  972
# Interpolating grid for day  973
# Interpolating grid for day  974
# Interpolating grid for day  975
# Interpolating grid for day  976
# Interpolating grid for day  977
# Interpolating grid for day  978
# Interpolating grid for day  979
# Interpolating grid for day  980
# Interpolating grid for day  981
# Interpolating grid for day  982
# Interpolating grid for day  983
# Interpolating grid for day  984
# Interpolating grid for day  985
# Interpolating grid for day  986
# Interpolating grid for day  987
# Interpolating grid for day  988
# Interpolating grid for day  989
# Interpolating grid for day  990
# Interpolating grid for day  991
# Interpolating grid for day  992
# Interpolating grid for day  993
# Interpolating grid for day  994
# Interpolating grid for day  995
# Interpolating grid for day  996
# Interpolating grid for day  997
# Interpolating grid for day  998
# Interpolating grid for day  999
# Interpolating grid for day  1000
# Interpolating grid for day  1001
# Interpolating grid for day  1002
# Interpolating grid for day  1003
# Interpolating grid for day  1004
# Interpolating grid for day  1005
# Interpolating grid for day  1006
# Interpolating grid for day  1007
# Interpolating grid for day  1008
# Interpolating grid for day  1009
# Interpolating grid for day  1010
# Interpolating grid for day  1011
# Interpolating grid for day  1012
# Interpolating grid for day  1013
# Interpolating grid for day  1014
# Interpolating grid for day  1015
# Interpolating grid for day  1016
# Interpolating grid for day  1017
# Interpolating grid for day  1018
# Interpolating grid for day  1019
# Interpolating grid for day  1020
# Interpolating grid for day  1021
# Interpolating grid for day  1022
# Interpolating grid for day  1023
# Interpolating grid for day  1024
# Interpolating grid for day  1025
# Interpolating grid for day  1026
# Interpolating grid for day  1027
# Interpolating grid for day  1028
# Interpolating grid for day  1029
# Interpolating grid for day  1030
# Interpolating grid for day  1031
# Interpolating grid for day  1032
# Interpolating grid for day  1033
# Interpolating grid for day  1034
# Interpolating grid for day  1035
# Interpolating grid for day  1036
# Interpolating grid for day  1037
# Interpolating grid for day  1038
# Interpolating grid for day  1039
# Interpolating grid for day  1040
# Interpolating grid for day  1041
# Interpolating grid for day  1042
# Interpolating grid for day  1043
# Interpolating grid for day  1044
# Interpolating grid for day  1045
# Interpolating grid for day  1046
# Interpolating grid for day  1047
# Interpolating grid for day  1048
# Interpolating grid for day  1049
# Interpolating grid for day  1050
# Interpolating grid for day  1051
# Interpolating grid for day  1052
# Interpolating grid for day  1053
# Interpolating grid for day  1054
# Interpolating grid for day  1055
# Interpolating grid for day  1056
# Interpolating grid for day  1057
# Interpolating grid for day  1058
# Interpolating grid for day  1059
# Interpolating grid for day  1060
# Interpolating grid for day  1061
# Interpolating grid for day  1062
# Interpolating grid for day  1063
# Interpolating grid for day  1064
# Interpolating grid for day  1065
# Interpolating grid for day  1066
# Interpolating grid for day  1067
# Interpolating grid for day  1068
# Interpolating grid for day  1069
# Interpolating grid for day  1070
# Interpolating grid for day  1071
# Interpolating grid for day  1072
# Interpolating grid for day  1073
# Interpolating grid for day  1074
# Interpolating grid for day  1075
# Interpolating grid for day  1076
# Interpolating grid for day  1077
# Interpolating grid for day  1078
# Interpolating grid for day  1079
# Interpolating grid for day  1080
# Interpolating grid for day  1081
# Interpolating grid for day  1082
# Interpolating grid for day  1083
# Interpolating grid for day  1084
# Interpolating grid for day  1085
# Interpolating grid for day  1086

# %%
pm10_inter = interpolate_frames(pm10_frames)
# Out:
# Interpolating grid for day  0
# Interpolating grid for day  1
# Interpolating grid for day  2
# Interpolating grid for day  3
# Interpolating grid for day  4
# Interpolating grid for day  5
# Interpolating grid for day  6
# Interpolating grid for day  7
# Interpolating grid for day  8
# Interpolating grid for day  9
# Interpolating grid for day  10
# Interpolating grid for day  11
# Interpolating grid for day  12
# Interpolating grid for day  13
# Interpolating grid for day  14
# Interpolating grid for day  15
# Interpolating grid for day  16
# Interpolating grid for day  17
# Interpolating grid for day  18
# Interpolating grid for day  19
# Interpolating grid for day  20
# Interpolating grid for day  21
# Interpolating grid for day  22
# Interpolating grid for day  23
# Interpolating grid for day  24
# Interpolating grid for day  25
# Interpolating grid for day  26
# Interpolating grid for day  27
# Interpolating grid for day  28
# Interpolating grid for day  29
# Interpolating grid for day  30
# Interpolating grid for day  31
# Interpolating grid for day  32
# Interpolating grid for day  33
# Interpolating grid for day  34
# Interpolating grid for day  35
# Interpolating grid for day  36
# Interpolating grid for day  37
# Interpolating grid for day  38
# Interpolating grid for day  39
# Interpolating grid for day  40
# Interpolating grid for day  41
# Interpolating grid for day  42
# Interpolating grid for day  43
# Interpolating grid for day  44
# Interpolating grid for day  45
# Interpolating grid for day  46
# Interpolating grid for day  47
# Interpolating grid for day  48
# Interpolating grid for day  49
# Interpolating grid for day  50
# Interpolating grid for day  51
# Interpolating grid for day  52
# Interpolating grid for day  53
# Interpolating grid for day  54
# Interpolating grid for day  55
# Interpolating grid for day  56
# Interpolating grid for day  57
# Interpolating grid for day  58
# Interpolating grid for day  59
# Interpolating grid for day  60
# Interpolating grid for day  61
# Interpolating grid for day  62
# Interpolating grid for day  63
# Interpolating grid for day  64
# Interpolating grid for day  65
# Interpolating grid for day  66
# Interpolating grid for day  67
# Interpolating grid for day  68
# Interpolating grid for day  69
# Interpolating grid for day  70
# Interpolating grid for day  71
# Interpolating grid for day  72
# Interpolating grid for day  73
# Interpolating grid for day  74
# Interpolating grid for day  75
# Interpolating grid for day  76
# Interpolating grid for day  77
# Interpolating grid for day  78
# Interpolating grid for day  79
# Interpolating grid for day  80
# Interpolating grid for day  81
# Interpolating grid for day  82
# Interpolating grid for day  83
# Interpolating grid for day  84
# Interpolating grid for day  85
# Interpolating grid for day  86
# Interpolating grid for day  87
# Interpolating grid for day  88
# Interpolating grid for day  89
# Interpolating grid for day  90
# Interpolating grid for day  91
# Interpolating grid for day  92
# Interpolating grid for day  93
# Interpolating grid for day  94
# Interpolating grid for day  95
# Interpolating grid for day  96
# Interpolating grid for day  97
# Interpolating grid for day  98
# Interpolating grid for day  99
# Interpolating grid for day  100
# Interpolating grid for day  101
# Interpolating grid for day  102
# Interpolating grid for day  103
# Interpolating grid for day  104
# Interpolating grid for day  105
# Interpolating grid for day  106
# Interpolating grid for day  107
# Interpolating grid for day  108
# Interpolating grid for day  109
# Interpolating grid for day  110
# Interpolating grid for day  111
# Interpolating grid for day  112
# Interpolating grid for day  113
# Interpolating grid for day  114
# Interpolating grid for day  115
# Interpolating grid for day  116
# Interpolating grid for day  117
# Interpolating grid for day  118
# Interpolating grid for day  119
# Interpolating grid for day  120
# Interpolating grid for day  121
# Interpolating grid for day  122
# Interpolating grid for day  123
# Interpolating grid for day  124
# Interpolating grid for day  125
# Interpolating grid for day  126
# Interpolating grid for day  127
# Interpolating grid for day  128
# Interpolating grid for day  129
# Interpolating grid for day  130
# Interpolating grid for day  131
# Interpolating grid for day  132
# Interpolating grid for day  133
# Interpolating grid for day  134
# Interpolating grid for day  135
# Interpolating grid for day  136
# Interpolating grid for day  137
# Interpolating grid for day  138
# Interpolating grid for day  139
# Interpolating grid for day  140
# Interpolating grid for day  141
# Interpolating grid for day  142
# Interpolating grid for day  143
# Interpolating grid for day  144
# Interpolating grid for day  145
# Interpolating grid for day  146
# Interpolating grid for day  147
# Interpolating grid for day  148
# Interpolating grid for day  149
# Interpolating grid for day  150
# Interpolating grid for day  151
# Interpolating grid for day  152
# Interpolating grid for day  153
# Interpolating grid for day  154
# Interpolating grid for day  155
# Interpolating grid for day  156
# Interpolating grid for day  157
# Interpolating grid for day  158
# Interpolating grid for day  159
# Interpolating grid for day  160
# Interpolating grid for day  161
# Interpolating grid for day  162
# Interpolating grid for day  163
# Interpolating grid for day  164
# Interpolating grid for day  165
# Interpolating grid for day  166
# Interpolating grid for day  167
# Interpolating grid for day  168
# Interpolating grid for day  169
# Interpolating grid for day  170
# Interpolating grid for day  171
# Interpolating grid for day  172
# Interpolating grid for day  173
# Interpolating grid for day  174
# Interpolating grid for day  175
# Interpolating grid for day  176
# Interpolating grid for day  177
# Interpolating grid for day  178
# Interpolating grid for day  179
# Interpolating grid for day  180
# Interpolating grid for day  181
# Interpolating grid for day  182
# Interpolating grid for day  183
# Interpolating grid for day  184
# Interpolating grid for day  185
# Interpolating grid for day  186
# Interpolating grid for day  187
# Interpolating grid for day  188
# Interpolating grid for day  189
# Interpolating grid for day  190
# Interpolating grid for day  191
# Interpolating grid for day  192
# Interpolating grid for day  193
# Interpolating grid for day  194
# Interpolating grid for day  195
# Interpolating grid for day  196
# Interpolating grid for day  197
# Interpolating grid for day  198
# Interpolating grid for day  199
# Interpolating grid for day  200
# Interpolating grid for day  201
# Interpolating grid for day  202
# Interpolating grid for day  203
# Interpolating grid for day  204
# Interpolating grid for day  205
# Interpolating grid for day  206
# Interpolating grid for day  207
# Interpolating grid for day  208
# Interpolating grid for day  209
# Interpolating grid for day  210
# Interpolating grid for day  211
# Interpolating grid for day  212
# Interpolating grid for day  213
# Interpolating grid for day  214
# Interpolating grid for day  215
# Interpolating grid for day  216
# Interpolating grid for day  217
# Interpolating grid for day  218
# Interpolating grid for day  219
# Interpolating grid for day  220
# Interpolating grid for day  221
# Interpolating grid for day  222
# Interpolating grid for day  223
# Interpolating grid for day  224
# Interpolating grid for day  225
# Interpolating grid for day  226
# Interpolating grid for day  227
# Interpolating grid for day  228
# Interpolating grid for day  229
# Interpolating grid for day  230
# Interpolating grid for day  231
# Interpolating grid for day  232
# Interpolating grid for day  233
# Interpolating grid for day  234
# Interpolating grid for day  235
# Interpolating grid for day  236
# Interpolating grid for day  237
# Interpolating grid for day  238
# Interpolating grid for day  239
# Interpolating grid for day  240
# Interpolating grid for day  241
# Interpolating grid for day  242
# Interpolating grid for day  243
# Interpolating grid for day  244
# Interpolating grid for day  245
# Interpolating grid for day  246
# Interpolating grid for day  247
# Interpolating grid for day  248
# Interpolating grid for day  249
# Interpolating grid for day  250
# Interpolating grid for day  251
# Interpolating grid for day  252
# Interpolating grid for day  253
# Interpolating grid for day  254
# Interpolating grid for day  255
# Interpolating grid for day  256
# Interpolating grid for day  257
# Interpolating grid for day  258
# Interpolating grid for day  259
# Interpolating grid for day  260
# Interpolating grid for day  261
# Interpolating grid for day  262
# Interpolating grid for day  263
# Interpolating grid for day  264
# Interpolating grid for day  265
# Interpolating grid for day  266
# Interpolating grid for day  267
# Interpolating grid for day  268
# Interpolating grid for day  269
# Interpolating grid for day  270
# Interpolating grid for day  271
# Interpolating grid for day  272
# Interpolating grid for day  273
# Interpolating grid for day  274
# Interpolating grid for day  275
# Interpolating grid for day  276
# Interpolating grid for day  277
# Interpolating grid for day  278
# Interpolating grid for day  279
# Interpolating grid for day  280
# Interpolating grid for day  281
# Interpolating grid for day  282
# Interpolating grid for day  283
# Interpolating grid for day  284
# Interpolating grid for day  285
# Interpolating grid for day  286
# Interpolating grid for day  287
# Interpolating grid for day  288
# Interpolating grid for day  289
# Interpolating grid for day  290
# Interpolating grid for day  291
# Interpolating grid for day  292
# Interpolating grid for day  293
# Interpolating grid for day  294
# Interpolating grid for day  295
# Interpolating grid for day  296
# Interpolating grid for day  297
# Interpolating grid for day  298
# Interpolating grid for day  299
# Interpolating grid for day  300
# Interpolating grid for day  301
# Interpolating grid for day  302
# Interpolating grid for day  303
# Interpolating grid for day  304
# Interpolating grid for day  305
# Interpolating grid for day  306
# Interpolating grid for day  307
# Interpolating grid for day  308
# Interpolating grid for day  309
# Interpolating grid for day  310
# Interpolating grid for day  311
# Interpolating grid for day  312
# Interpolating grid for day  313
# Interpolating grid for day  314
# Interpolating grid for day  315
# Interpolating grid for day  316
# Interpolating grid for day  317
# Interpolating grid for day  318
# Interpolating grid for day  319
# Interpolating grid for day  320
# Interpolating grid for day  321
# Interpolating grid for day  322
# Interpolating grid for day  323
# Interpolating grid for day  324
# Interpolating grid for day  325
# Interpolating grid for day  326
# Interpolating grid for day  327
# Interpolating grid for day  328
# Interpolating grid for day  329
# Interpolating grid for day  330
# Interpolating grid for day  331
# Interpolating grid for day  332
# Interpolating grid for day  333
# Interpolating grid for day  334
# Interpolating grid for day  335
# Interpolating grid for day  336
# Interpolating grid for day  337
# Interpolating grid for day  338
# Interpolating grid for day  339
# Interpolating grid for day  340
# Interpolating grid for day  341
# Interpolating grid for day  342
# Interpolating grid for day  343
# Interpolating grid for day  344
# Interpolating grid for day  345
# Interpolating grid for day  346
# Interpolating grid for day  347
# Interpolating grid for day  348
# Interpolating grid for day  349
# Interpolating grid for day  350
# Interpolating grid for day  351
# Interpolating grid for day  352
# Interpolating grid for day  353
# Interpolating grid for day  354
# Interpolating grid for day  355
# Interpolating grid for day  356
# Interpolating grid for day  357
# Interpolating grid for day  358
# Interpolating grid for day  359
# Interpolating grid for day  360
# Interpolating grid for day  361
# Interpolating grid for day  362
# Interpolating grid for day  363
# Interpolating grid for day  364
# Interpolating grid for day  365
# Interpolating grid for day  366
# Interpolating grid for day  367
# Interpolating grid for day  368
# Interpolating grid for day  369
# Interpolating grid for day  370
# Interpolating grid for day  371
# Interpolating grid for day  372
# Interpolating grid for day  373
# Interpolating grid for day  374
# Interpolating grid for day  375
# Interpolating grid for day  376
# Interpolating grid for day  377
# Interpolating grid for day  378
# Interpolating grid for day  379
# Interpolating grid for day  380
# Interpolating grid for day  381
# Interpolating grid for day  382
# Interpolating grid for day  383
# Interpolating grid for day  384
# Interpolating grid for day  385
# Interpolating grid for day  386
# Interpolating grid for day  387
# Interpolating grid for day  388
# Interpolating grid for day  389
# Interpolating grid for day  390
# Interpolating grid for day  391
# Interpolating grid for day  392
# Interpolating grid for day  393
# Interpolating grid for day  394
# Interpolating grid for day  395
# Interpolating grid for day  396
# Interpolating grid for day  397
# Interpolating grid for day  398
# Interpolating grid for day  399
# Interpolating grid for day  400
# Interpolating grid for day  401
# Interpolating grid for day  402
# Interpolating grid for day  403
# Interpolating grid for day  404
# Interpolating grid for day  405
# Interpolating grid for day  406
# Interpolating grid for day  407
# Interpolating grid for day  408
# Interpolating grid for day  409
# Interpolating grid for day  410
# Interpolating grid for day  411
# Interpolating grid for day  412
# Interpolating grid for day  413
# Interpolating grid for day  414
# Interpolating grid for day  415
# Interpolating grid for day  416
# Interpolating grid for day  417
# Interpolating grid for day  418
# Interpolating grid for day  419
# Interpolating grid for day  420
# Interpolating grid for day  421
# Interpolating grid for day  422
# Interpolating grid for day  423
# Interpolating grid for day  424
# Interpolating grid for day  425
# Interpolating grid for day  426
# Interpolating grid for day  427
# Interpolating grid for day  428
# Interpolating grid for day  429
# Interpolating grid for day  430
# Interpolating grid for day  431
# Interpolating grid for day  432
# Interpolating grid for day  433
# Interpolating grid for day  434
# Interpolating grid for day  435
# Interpolating grid for day  436
# Interpolating grid for day  437
# Interpolating grid for day  438
# Interpolating grid for day  439
# Interpolating grid for day  440
# Interpolating grid for day  441
# Interpolating grid for day  442
# Interpolating grid for day  443
# Interpolating grid for day  444
# Interpolating grid for day  445
# Interpolating grid for day  446
# Interpolating grid for day  447
# Interpolating grid for day  448
# Interpolating grid for day  449
# Interpolating grid for day  450
# Interpolating grid for day  451
# Interpolating grid for day  452
# Interpolating grid for day  453
# Interpolating grid for day  454
# Interpolating grid for day  455
# Interpolating grid for day  456
# Interpolating grid for day  457
# Interpolating grid for day  458
# Interpolating grid for day  459
# Interpolating grid for day  460
# Interpolating grid for day  461
# Interpolating grid for day  462
# Interpolating grid for day  463
# Interpolating grid for day  464
# Interpolating grid for day  465
# Interpolating grid for day  466
# Interpolating grid for day  467
# Interpolating grid for day  468
# Interpolating grid for day  469
# Interpolating grid for day  470
# Interpolating grid for day  471
# Interpolating grid for day  472
# Interpolating grid for day  473
# Interpolating grid for day  474
# Interpolating grid for day  475
# Interpolating grid for day  476
# Interpolating grid for day  477
# Interpolating grid for day  478
# Interpolating grid for day  479
# Interpolating grid for day  480
# Interpolating grid for day  481
# Interpolating grid for day  482
# Interpolating grid for day  483
# Interpolating grid for day  484
# Interpolating grid for day  485
# Interpolating grid for day  486
# Interpolating grid for day  487
# Interpolating grid for day  488
# Interpolating grid for day  489
# Interpolating grid for day  490
# Interpolating grid for day  491
# Interpolating grid for day  492
# Interpolating grid for day  493
# Interpolating grid for day  494
# Interpolating grid for day  495
# Interpolating grid for day  496
# Interpolating grid for day  497
# Interpolating grid for day  498
# Interpolating grid for day  499
# Interpolating grid for day  500
# Interpolating grid for day  501
# Interpolating grid for day  502
# Interpolating grid for day  503
# Interpolating grid for day  504
# Interpolating grid for day  505
# Interpolating grid for day  506
# Interpolating grid for day  507
# Interpolating grid for day  508
# Interpolating grid for day  509
# Interpolating grid for day  510
# Interpolating grid for day  511
# Interpolating grid for day  512
# Interpolating grid for day  513
# Interpolating grid for day  514
# Interpolating grid for day  515
# Interpolating grid for day  516
# Interpolating grid for day  517
# Interpolating grid for day  518
# Interpolating grid for day  519
# Interpolating grid for day  520
# Interpolating grid for day  521
# Interpolating grid for day  522
# Interpolating grid for day  523
# Interpolating grid for day  524
# Interpolating grid for day  525
# Interpolating grid for day  526
# Interpolating grid for day  527
# Interpolating grid for day  528
# Interpolating grid for day  529
# Interpolating grid for day  530
# Interpolating grid for day  531
# Interpolating grid for day  532
# Interpolating grid for day  533
# Interpolating grid for day  534
# Interpolating grid for day  535
# Interpolating grid for day  536
# Interpolating grid for day  537
# Interpolating grid for day  538
# Interpolating grid for day  539
# Interpolating grid for day  540
# Interpolating grid for day  541
# Interpolating grid for day  542
# Interpolating grid for day  543
# Interpolating grid for day  544
# Interpolating grid for day  545
# Interpolating grid for day  546
# Interpolating grid for day  547
# Interpolating grid for day  548
# Interpolating grid for day  549
# Interpolating grid for day  550
# Interpolating grid for day  551
# Interpolating grid for day  552
# Interpolating grid for day  553
# Interpolating grid for day  554
# Interpolating grid for day  555
# Interpolating grid for day  556
# Interpolating grid for day  557
# Interpolating grid for day  558
# Interpolating grid for day  559
# Interpolating grid for day  560
# Interpolating grid for day  561
# Interpolating grid for day  562
# Interpolating grid for day  563
# Interpolating grid for day  564
# Interpolating grid for day  565
# Interpolating grid for day  566
# Interpolating grid for day  567
# Interpolating grid for day  568
# Interpolating grid for day  569
# Interpolating grid for day  570
# Interpolating grid for day  571
# Interpolating grid for day  572
# Interpolating grid for day  573
# Interpolating grid for day  574
# Interpolating grid for day  575
# Interpolating grid for day  576
# Interpolating grid for day  577
# Interpolating grid for day  578
# Interpolating grid for day  579
# Interpolating grid for day  580
# Interpolating grid for day  581
# Interpolating grid for day  582
# Interpolating grid for day  583
# Interpolating grid for day  584
# Interpolating grid for day  585
# Interpolating grid for day  586
# Interpolating grid for day  587
# Interpolating grid for day  588
# Interpolating grid for day  589
# Interpolating grid for day  590
# Interpolating grid for day  591
# Interpolating grid for day  592
# Interpolating grid for day  593
# Interpolating grid for day  594
# Interpolating grid for day  595
# Interpolating grid for day  596
# Interpolating grid for day  597
# Interpolating grid for day  598
# Interpolating grid for day  599
# Interpolating grid for day  600
# Interpolating grid for day  601
# Interpolating grid for day  602
# Interpolating grid for day  603
# Interpolating grid for day  604
# Interpolating grid for day  605
# Interpolating grid for day  606
# Interpolating grid for day  607
# Interpolating grid for day  608
# Interpolating grid for day  609
# Interpolating grid for day  610
# Interpolating grid for day  611
# Interpolating grid for day  612
# Interpolating grid for day  613
# Interpolating grid for day  614
# Interpolating grid for day  615
# Interpolating grid for day  616
# Interpolating grid for day  617
# Interpolating grid for day  618
# Interpolating grid for day  619
# Interpolating grid for day  620
# Interpolating grid for day  621
# Interpolating grid for day  622
# Interpolating grid for day  623
# Interpolating grid for day  624
# Interpolating grid for day  625
# Interpolating grid for day  626
# Interpolating grid for day  627
# Interpolating grid for day  628
# Interpolating grid for day  629
# Interpolating grid for day  630
# Interpolating grid for day  631
# Interpolating grid for day  632
# Interpolating grid for day  633
# Interpolating grid for day  634
# Interpolating grid for day  635
# Interpolating grid for day  636
# Interpolating grid for day  637
# Interpolating grid for day  638
# Interpolating grid for day  639
# Interpolating grid for day  640
# Interpolating grid for day  641
# Interpolating grid for day  642
# Interpolating grid for day  643
# Interpolating grid for day  644
# Interpolating grid for day  645
# Interpolating grid for day  646
# Interpolating grid for day  647
# Interpolating grid for day  648
# Interpolating grid for day  649
# Interpolating grid for day  650
# Interpolating grid for day  651
# Interpolating grid for day  652
# Interpolating grid for day  653
# Interpolating grid for day  654
# Interpolating grid for day  655
# Interpolating grid for day  656
# Interpolating grid for day  657
# Interpolating grid for day  658
# Interpolating grid for day  659
# Interpolating grid for day  660
# Interpolating grid for day  661
# Interpolating grid for day  662
# Interpolating grid for day  663
# Interpolating grid for day  664
# Interpolating grid for day  665
# Interpolating grid for day  666
# Interpolating grid for day  667
# Interpolating grid for day  668
# Interpolating grid for day  669
# Interpolating grid for day  670
# Interpolating grid for day  671
# Interpolating grid for day  672
# Interpolating grid for day  673
# Interpolating grid for day  674
# Interpolating grid for day  675
# Interpolating grid for day  676
# Interpolating grid for day  677
# Interpolating grid for day  678
# Interpolating grid for day  679
# Interpolating grid for day  680
# Interpolating grid for day  681
# Interpolating grid for day  682
# Interpolating grid for day  683
# Interpolating grid for day  684
# Interpolating grid for day  685
# Interpolating grid for day  686
# Interpolating grid for day  687
# Interpolating grid for day  688
# Interpolating grid for day  689
# Interpolating grid for day  690
# Interpolating grid for day  691
# Interpolating grid for day  692
# Interpolating grid for day  693
# Interpolating grid for day  694
# Interpolating grid for day  695
# Interpolating grid for day  696
# Interpolating grid for day  697
# Interpolating grid for day  698
# Interpolating grid for day  699
# Interpolating grid for day  700
# Interpolating grid for day  701
# Interpolating grid for day  702
# Interpolating grid for day  703
# Interpolating grid for day  704
# Interpolating grid for day  705
# Interpolating grid for day  706
# Interpolating grid for day  707
# Interpolating grid for day  708
# Interpolating grid for day  709
# Interpolating grid for day  710
# Interpolating grid for day  711
# Interpolating grid for day  712
# Interpolating grid for day  713
# Interpolating grid for day  714
# Interpolating grid for day  715
# Interpolating grid for day  716
# Interpolating grid for day  717
# Interpolating grid for day  718
# Interpolating grid for day  719
# Interpolating grid for day  720
# Interpolating grid for day  721
# Interpolating grid for day  722
# Interpolating grid for day  723
# Interpolating grid for day  724
# Interpolating grid for day  725
# Interpolating grid for day  726
# Interpolating grid for day  727
# Interpolating grid for day  728
# Interpolating grid for day  729
# Interpolating grid for day  730
# Interpolating grid for day  731
# Interpolating grid for day  732
# Interpolating grid for day  733
# Interpolating grid for day  734
# Interpolating grid for day  735
# Interpolating grid for day  736
# Interpolating grid for day  737
# Interpolating grid for day  738
# Interpolating grid for day  739
# Interpolating grid for day  740
# Interpolating grid for day  741
# Interpolating grid for day  742
# Interpolating grid for day  743
# Interpolating grid for day  744
# Interpolating grid for day  745
# Interpolating grid for day  746
# Interpolating grid for day  747
# Interpolating grid for day  748
# Interpolating grid for day  749
# Interpolating grid for day  750
# Interpolating grid for day  751
# Interpolating grid for day  752
# Interpolating grid for day  753
# Interpolating grid for day  754
# Interpolating grid for day  755
# Interpolating grid for day  756
# Interpolating grid for day  757
# Interpolating grid for day  758
# Interpolating grid for day  759
# Interpolating grid for day  760
# Interpolating grid for day  761
# Interpolating grid for day  762
# Interpolating grid for day  763
# Interpolating grid for day  764
# Interpolating grid for day  765
# Interpolating grid for day  766
# Interpolating grid for day  767
# Interpolating grid for day  768
# Interpolating grid for day  769
# Interpolating grid for day  770
# Interpolating grid for day  771
# Interpolating grid for day  772
# Interpolating grid for day  773
# Interpolating grid for day  774
# Interpolating grid for day  775
# Interpolating grid for day  776
# Interpolating grid for day  777
# Interpolating grid for day  778
# Interpolating grid for day  779
# Interpolating grid for day  780
# Interpolating grid for day  781
# Interpolating grid for day  782
# Interpolating grid for day  783
# Interpolating grid for day  784
# Interpolating grid for day  785
# Interpolating grid for day  786
# Interpolating grid for day  787
# Interpolating grid for day  788
# Interpolating grid for day  789
# Interpolating grid for day  790
# Interpolating grid for day  791
# Interpolating grid for day  792
# Interpolating grid for day  793
# Interpolating grid for day  794
# Interpolating grid for day  795
# Interpolating grid for day  796
# Interpolating grid for day  797
# Interpolating grid for day  798
# Interpolating grid for day  799
# Interpolating grid for day  800
# Interpolating grid for day  801
# Interpolating grid for day  802
# Interpolating grid for day  803
# Interpolating grid for day  804
# Interpolating grid for day  805
# Interpolating grid for day  806
# Interpolating grid for day  807
# Interpolating grid for day  808
# Interpolating grid for day  809
# Interpolating grid for day  810
# Interpolating grid for day  811
# Interpolating grid for day  812
# Interpolating grid for day  813
# Interpolating grid for day  814
# Interpolating grid for day  815
# Interpolating grid for day  816
# Interpolating grid for day  817
# Interpolating grid for day  818
# Interpolating grid for day  819
# Interpolating grid for day  820
# Interpolating grid for day  821
# Interpolating grid for day  822
# Interpolating grid for day  823
# Interpolating grid for day  824
# Interpolating grid for day  825
# Interpolating grid for day  826
# Interpolating grid for day  827
# Interpolating grid for day  828
# Interpolating grid for day  829
# Interpolating grid for day  830
# Interpolating grid for day  831
# Interpolating grid for day  832
# Interpolating grid for day  833
# Interpolating grid for day  834
# Interpolating grid for day  835
# Interpolating grid for day  836
# Interpolating grid for day  837
# Interpolating grid for day  838
# Interpolating grid for day  839
# Interpolating grid for day  840
# Interpolating grid for day  841
# Interpolating grid for day  842
# Interpolating grid for day  843
# Interpolating grid for day  844
# Interpolating grid for day  845
# Interpolating grid for day  846
# Interpolating grid for day  847
# Interpolating grid for day  848
# Interpolating grid for day  849
# Interpolating grid for day  850
# Interpolating grid for day  851
# Interpolating grid for day  852
# Interpolating grid for day  853
# Interpolating grid for day  854
# Interpolating grid for day  855
# Interpolating grid for day  856
# Interpolating grid for day  857
# Interpolating grid for day  858
# Interpolating grid for day  859
# Interpolating grid for day  860
# Interpolating grid for day  861
# Interpolating grid for day  862
# Interpolating grid for day  863
# Interpolating grid for day  864
# Interpolating grid for day  865
# Interpolating grid for day  866
# Interpolating grid for day  867
# Interpolating grid for day  868
# Interpolating grid for day  869
# Interpolating grid for day  870
# Interpolating grid for day  871
# Interpolating grid for day  872
# Interpolating grid for day  873
# Interpolating grid for day  874
# Interpolating grid for day  875
# Interpolating grid for day  876
# Interpolating grid for day  877
# Interpolating grid for day  878
# Interpolating grid for day  879
# Interpolating grid for day  880
# Interpolating grid for day  881
# Interpolating grid for day  882
# Interpolating grid for day  883
# Interpolating grid for day  884
# Interpolating grid for day  885
# Interpolating grid for day  886
# Interpolating grid for day  887
# Interpolating grid for day  888
# Interpolating grid for day  889
# Interpolating grid for day  890
# Interpolating grid for day  891
# Interpolating grid for day  892
# Interpolating grid for day  893
# Interpolating grid for day  894
# Interpolating grid for day  895
# Interpolating grid for day  896
# Interpolating grid for day  897
# Interpolating grid for day  898
# Interpolating grid for day  899
# Interpolating grid for day  900
# Interpolating grid for day  901
# Interpolating grid for day  902
# Interpolating grid for day  903
# Interpolating grid for day  904
# Interpolating grid for day  905
# Interpolating grid for day  906
# Interpolating grid for day  907
# Interpolating grid for day  908
# Interpolating grid for day  909
# Interpolating grid for day  910
# Interpolating grid for day  911
# Interpolating grid for day  912
# Interpolating grid for day  913
# Interpolating grid for day  914
# Interpolating grid for day  915
# Interpolating grid for day  916
# Interpolating grid for day  917
# Interpolating grid for day  918
# Interpolating grid for day  919
# Interpolating grid for day  920
# Interpolating grid for day  921
# Interpolating grid for day  922
# Interpolating grid for day  923
# Interpolating grid for day  924
# Interpolating grid for day  925
# Interpolating grid for day  926
# Interpolating grid for day  927
# Interpolating grid for day  928
# Interpolating grid for day  929
# Interpolating grid for day  930
# Interpolating grid for day  931
# Interpolating grid for day  932
# Interpolating grid for day  933
# Interpolating grid for day  934
# Interpolating grid for day  935
# Interpolating grid for day  936
# Interpolating grid for day  937
# Interpolating grid for day  938
# Interpolating grid for day  939
# Interpolating grid for day  940
# Interpolating grid for day  941
# Interpolating grid for day  942
# Interpolating grid for day  943
# Interpolating grid for day  944
# Interpolating grid for day  945
# Interpolating grid for day  946
# Interpolating grid for day  947
# Interpolating grid for day  948
# Interpolating grid for day  949
# Interpolating grid for day  950
# Interpolating grid for day  951
# Interpolating grid for day  952
# Interpolating grid for day  953
# Interpolating grid for day  954
# Interpolating grid for day  955
# Interpolating grid for day  956
# Interpolating grid for day  957
# Interpolating grid for day  958
# Interpolating grid for day  959
# Interpolating grid for day  960
# Interpolating grid for day  961
# Interpolating grid for day  962
# Interpolating grid for day  963
# Interpolating grid for day  964

# %%
np.save("durbanPM10.npy", pm10_inter)
np.save("durbanPM10NoInterpolate.npy", pm10_frames)

# %%
np.save("durbanPM25.npy",pm25_inter)
np.save("durbanPM25NoInterpolate.npy",pm25_raw)

# %% [markdown]
# #### Smoke Injection Height
#
# The MERRA-2 Smoke Injection Height collection was collected to NASA EarthData Search, which automatically crops the grid to the geographic boundaries we have defined above. We visualize one granule below and find that no effective information can be retrieved from this specific collection in our geographic bounds, so it is not included in our model.

# %% [markdown]
# Most of the data here is filler data (-99999), so this collection of MERRA-2 Smoke Injection Height is not usable, and thus not included in the model.

# %% [markdown]
# #### PBL Height
#
# Planetary Boundary Layer Height is a measure of the the distance from ground level of the lowest part of the atmosphere.
#
# The lowest part of the atmosphere, or the peplosphere, is directly influenced by the changing surface temperature of earth, various aerosols in the atmosphere, and is especially influenced by smoke or ash from a fire. PBL Height is also infulenced by precipitation and changes in surface pressure.
#
# Over deserts or areas of dry, warm climates that may be caused by fires burning in the area, the PBL may extend up to 4000 to 5000 meters above sea level.
#
# Over cooler, more humid temperatures with little aerosols, dust, or smoke in the atmosphere, the PBL may be less than 1000 meters above sea level.
#
# Thus, intuitively, a low PBL height means that there are no fires burning in the area and the atmosphere is relatively clear of aerosols.

# %%
# Note: these visualizations may take a while to run because of the size of data

import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cf
import cartopy.io.shapereader as shpr

data = Dataset('MERRA2_401.tavg1_2d_flx_Nx.20200902.nc4', mode='r')

lon = data.variables['lon'][:]
lat = data.variables['lat'][:]
pb = data.variables['PBLH'][0,:,:]
# lon1,lon2=97,102
# lat1,lat2=246,251
lon1,lon2=335,338
lat1,lat2=117,120
lalon = data.variables['lon'][lon1:lon2]
lalat = data.variables['lat'][lat1:lat2]
lapb = data.variables['PBLH'][0,lon1:lon2,lat1:lat2]

# %%
# Retriving the information from web
stt = cf.NaturalEarthFeature(category='cultural',
        name='admin_1_states_provinces_lines',
        scale='10m',
        facecolor='none')
fname = shpr.natural_earth(resolution='10m', category='cultural', name='populated_places')
reader = shpr.Reader(fname)

# %%
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines(resolution="110m",linewidth=1)
ax.gridlines(linestyle='--',color='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(0,2000, 100)
plt.contourf(lon, lat, pb, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Global Planetary Boundary Layer AOD, September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.ax.tick_params(labelsize=10)

# %%
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(resolution="10m",linewidth=1)
ax.gridlines(linestyle='--',color='black')
ax.add_feature(stt, linewidth=0.5, edgecolor='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(200,1500, 5)
plt.contourf(lalon, lalat, lapb, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Durban PBL Height, September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.ax.tick_params(labelsize=10)

# %% [markdown]
# The resolution of the MERRA-2 PBL Height collection is high enough to be used in the model.

# %% [markdown]
# #### Surface Air Temperature

# %%
airTemp = data.variables['TLML'][0,:,:]

# %%
cdh = data.variables['CDH'][0,:,:]
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines(resolution="110m",linewidth=1)
ax.gridlines(linestyle='--',color='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(200,310, 5)
plt.contourf(lon, lat, airTemp, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Global Surface Air Temperature , September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.set_label('K',size=12,rotation=0,labelpad=15)
cb.ax.tick_params(labelsize=10)

# %%
latemp = data.variables['TLML'][0,lon1:lon2,lat1:lat2]

# %%
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(resolution="10m",linewidth=1)
ax.gridlines(linestyle='--',color='black')
ax.add_feature(stt, linewidth=0.5, edgecolor='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(271.75,272.25, 0.01)
plt.contourf(lalon, lalat, latemp, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Durban Surface Air Temperature, September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.ax.tick_params(labelsize=10)

# %% [markdown]
# The resolution of the MERRA-2 Surface Air Temperature collection is high enough to be used in the model.

# %% [markdown]
# #### Surface Exchange Coefficient For Heat

# %%
cdh = data.variables['CDH'][0,:,:]

# %%
##### Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines(resolution="110m",linewidth=1)
ax.gridlines(linestyle='--',color='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(0.005,0.02, 0.001)
plt.contourf(lon, lat, cdh, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Global Surface Exchange Coefficient for Heat, September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.set_label('kg/m^3',size=12,rotation=0,labelpad=15)
cb.ax.tick_params(labelsize=10)

# %%
lacdh = data.variables['CDH'][0,lon1:lon2,lat1:lat2]

# %%
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines(resolution="10m",linewidth=1)
ax.gridlines(linestyle='--',color='black')
ax.add_feature(stt, linewidth=0.5, edgecolor='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(0.002,0.005, 0.00005)
plt.contourf(lalon, lalat, lacdh, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet,extend="both")
plt.title('MERRA-2 Durban Surface Exchange Coefficient for Heat, September 2 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.ax.tick_params(labelsize=10)

# %% [markdown]
# The resolution of the MERRA-2 Surface Exchange Coefficient for Heat collection is high enough to be used in the model.

# %% [markdown]
# ### MODIS Fire Radiative Power (FRP)
#
# Fire Radiative Power (FRP) is a measure of the radiant heat output from a fire. The main contributors to increased levels of FRP include smoke from wildfires and emmissions from the burning of carbon-based fuel (e.g. Carbon Monoxide / Carbon Dioxide emissions). Thus there is a strong positive correlation between wildfires and FRP values as well as a weaker positive correlation between carbon emissions (CO2, CO) and FRP values.
#
# FRP is measured in MegaWatts (MW) and can be collected using an imaging instrument onboard a remote-sensing satellite aircraft. The wavelength of light needed to image FRP is in the range of 2070 $\mu$m to 3200 $\mu$m.
#
# MODIS provides two forms of processed FRP imagery collected onboard the MOD11A1 v006 satellite: Observed FRP and Observed FRP Corrected for Cloud Cover.
#
# I used the adjusted FRP observations in the model along with the three numerical grid-based fire features from MERRA-2: PBL Height, Surface Temperature, and Surface Exchange Coefficient for Heat.
#
# For the MODIS FRP imagery, I applied a similar type of filter mask I did to block out the times where there wasn't really fire imagery for MERRA-2. However, I loosened the criteria for the fire mask and allowed anything with a pixel value above the 50th percentile to keep it's pixel values, while making everything else 0s. I loosened the criteria because FRP also contained information relevant to carbon-based air pollutants, so it has less of noisy data.
#
# Here are some examples of the FRP masked images:

# %%
from pyhdf.SD import SD, SDC 

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import pprint
import math

# %%
file = SD('Durban MODIS FRP Data/MOD11A1.A2019016.h20v11.061.2022013072516.hdf', SDC.READ)
fireMask = file.select("LST_Day_1km")
fireMask_attr = fireMask.attributes()
fm = fireMask[50:100,800:850]
no2 = plt.imread("no2.png")
fmi = fm.astype(np.uint8)
methane = plt.imread("methane.png")
meanFM = fm.mean()
varFM = fm.var()
scaledFM = (fm - meanFM)/varFM
plt.imshow(scaledFM)
plt.title("Scaled MODIS Fire Radiative Power (FRP) Hour 0 March 30 2018")
plt.show()
print("Mean: ", meanFM)
print("Scaled Mean: ", scaledFM.mean())
print("Scaled Variance: ", scaledFM.var())
# Out:
# Mean:  8737.7392
# Scaled Mean:  0.0
# Scaled Variance:  1.755924970404301e-08

# %%
file = SD('Durban MODIS FRP Data/MOD11A1.A2021270.h20v11.061.2021277200706.hdf', SDC.READ)
fireMask = file.select("LST_Day_1km")
fireMask_attr = fireMask.attributes()
fm = fireMask[1000:1050,1000:1050]
co = plt.imread("co.png")
meanFM = fm.mean()
varFM = fm.var()
so2 = plt.imread("so2.png")
scaledFM = (fm - meanFM)/varFM
plt.imshow(scaledFM)
plt.title("Scaled MODIS Fire Radiative Power (FRP) Hour 0 July 30 2018")
plt.show()
print("Mean: ", meanFM)
print("Scaled Mean: ", scaledFM.mean())
print("Scaled Variance: ", scaledFM.var())
# Out:
# Mean:  2995.0996
# Scaled Mean:  1.1102230246251566e-20
# Scaled Variance:  2.7520442053024054e-08

# %%
file = SD('Durban MODIS FRP Data/MOD11A1.A2019006.h20v11.061.2022004050609.hdf', SDC.READ)
fireMask = file.select("LST_Day_1km")
fireMask_attr = fireMask.attributes()
fm = fireMask[50:100,800:850]
form = plt.imread("formaldehyde.png")
meanFM = fm.mean()
varFM = fm.var()
scaledFM = (fm - meanFM)/varFM
plt.imshow(scaledFM)
plt.title("Scaled MODIS Fire Radiative Power (FRP) Hour 0 November 30 2018")
plt.show()
print("Mean: ", meanFM)
print("Scaled Mean: ", scaledFM.mean())
print("Scaled Variance: ", scaledFM.var())
# Out:
# Mean:  13477.79
# Scaled Mean:  -4.4408920985006264e-20
# Scaled Variance:  4.415575272115072e-08

# %% [markdown]
# The resolution of the MODIS FRP data is high enough to be used in the model.
#
# ---

# %% [markdown]
# ## Remote-sensing Satellite Imagery Data Exploration
#
# In this section, we visualize data from various sources (NASA MODIS MAIAC, NASA TROPOMI) in order to explain our motivations behind using the data in our model.

# %% [markdown]
# ### NASA MODIS MAIAC AOD
#
# Our remote-sensing satellite imagery was collected from the NASA Multi-Angle Implementation of Atmospheric Correction (MAIAC) algorithm data source. The MAIAC algorithm is a preprocessing algorithm performed on imagery collected by the NASA Moderate Resolution Imaging Spectroradiometer (MODIS) instrument onboard the NASA Terra and Aqua satellites.
#
# The Terra and Aqua satellites orbit the Earth every 1-2 days and provide imagery over 36 spectral bands utilizing the MODIS imaging instrument. The MAIAC algorithm is a highly advanced preprocessing algorithm that converts raw MODIS imagery to data analytics ready images by retrieving atmospheric aerosol and air pollutant data from MODIS images, normalizing pixel values, and removing cloud cover masks. For our model, we use the MAIAC MODIS/Terra+Aqua Daily AOD dataset.
#
# AOD or Aerosol Optical Depth is a measure of the direct amount of sunlight being blocked by atmospheric aerosols and air pollutants. AOD is perhaps the most comprehensive measure of ambient air pollution and years of research has shown a strong correlation between AOD readings and PM 2.5 concentrations in both atmospheric and ground-level settings. The MAIAC MODIS AOD dataset we utilize as input to our model records the blue-band Aerosol Optical Depth at a central wavelength of 0.47 μm. The raw MAIAC MODIS AOD dataset provides a spatial resolution of 1-km/pixel for an area of 1200km by 1200km. However, for our implementation, we crop the imagery in order to fit our defined geographic bounds.

# %%
from pyhdf.SD import SD, SDC 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import pprint
import os
import cv2
file = SD('./DurbanMAIACData/MCD19A2.A2021249.h20v11.006.2021251200755.hdf', SDC.READ)
aod = file.select('Optical_Depth_055')
aodData = aod[0,:,:]
out = cv2.resize(aodData,(30,30))
out = np.reshape(out,(30,30,1))

# %%
plt.imshow(out[:,:,0])

# %% [markdown]
# Note that the figure provides a visualization of the raw grid-like data of the MAIAC AOD imagery, and thus the color values of the visualization correspond to AOD values, not raw RGB imagery. The brighter colored pixels in the visualization correspond to higher AOD values.

# %% [markdown]
# ### NASA TROPOMI Data Exploration
#
# Sentinel-5P is a satellite launched by the European Space Agency (ESA) on October 13, 2017. Sentinel-5P has an orbit height of 512 mi and a mission life of 7 years, thus expected to be operational from Oct 2017 to Oct 2024. Onboard the satellite is the TROPOspheric Monitoring Instrument (TROPOMI), a spectrometer capable of sensing ultraviolet (UV), visible (VIS), near (NIR) and short-wavelength infrared (SWIR) light. TROPOMI provides high resolution global hourly images of atmospheric ozone, methane, formaldehyde, aerosol, carbon monoxide, nitrogen dioxide, and sulfur dioxide.
#
# TROPOMI measures in the ultraviolet and visible (270–500 nm), near-infrared (675–775 nm) and shortwave infrared (2305–2385 nm) spectral bands.
#
# We have collected hourly TROPOMI imagery in a slightly expanded geographic boundary of Los Angeles county from the Google Earth Engine tool. The resolutions of individual air pollutant targets vary, but in general the resolution of TROPOMI images are around the level of NASA MODIS MAIAC data.
#
# The sulfur dioxide and formaldehyde imagery were not indicative of actually predictable data (looks like random noise), so for this prediction, we used only the TROPOMI imagery of methane, nitrogen dioxide, and carbon monoxide.
#
# The timespan of the dataset was from January 1 2018 to December 31 2020. We're working on extending the time range, but this should serve more as a prototype. Also, we are currently discussing how to integrate the MAIAC MODIS data (available since early 2000s), MODIS FRP data (also since early 2000s), EPA AirNow ground-based sensor data (reliable since 2015), and TROPOMI data (since 2017).

# %%
plt.imshow(methane)
plt.title("Sentinel-5P TROPOMI Methane (CH4) Imagery Hour 0 June 21 2019")
plt.show()

# %%
plt.imshow(no2)
plt.title("Sentinel-5P TROPOMI Nitrogen Dioxide (NO2) Imagery Hour 0 June 21 2019")
plt.show()

# %%
plt.imshow(co)
plt.title("Sentinel-5P TROPOMI Carbon Monoxide (CO) Imagery Hour 0 June 21 2019")
plt.show()

# %%
plt.imshow(form)
plt.title("Sentinel-5P TROPOMI Formaldehyde (CH2O) Imagery Hour 0 June 21 2019")
plt.show()

# %% [markdown]
# ---
#
# ## Ground-based Sensor Data Exploration
#
# In this section, we will describe and visualize the ground-level air pollution sensor data of PM2.5, PM10, SO2, NO2, and CO collected from 34 sensors in Mexico City.
#
# These 34 PM2.5 sensor site values are the final prediction targets of the model. We feed in previous days' worth of these data to the model alongside the various other data sources used in order to predict these data values in the future.
#
# We actually preprocess the raw sensors by applying a locally-weighted distance interpolation to create a 75x75 grid of PM2.5 ground based data bounded by the model's geographic bounds. The original translated coordinates of the 34 sensors in the 75x75 grid are shown below. Each pixel in the 75x75 grid corresponds to roughly a 1km by 1km area of physical land, since the total geographic bounds encompass an area of 0.75 degrees latitude by 0.75 degrees longitude. By taking into account that 1 degree of latitude/longitude is roughly equivalent to 100 km, each pixel in the 75x75 grid contains 1 km^2 land area. We generated hourly 75x75 grids for each of the 5 air pollutants provided (PM2.5, PM10, SO2, NO2, CO).
#
# **Raw Sensor Location Grid Mapped Coordinates**

# %%
sites
# Out:
#                site   latitude  longitude   x   y
# 0  Durban City Hall -29.858217  31.027273  27  10
# 1       New Germany -29.798654  30.876540  12   4
# 2          Settlers -29.958842  30.978683  22  20
# 3         Wentworth -29.934095  30.988598  23  18

# %%
pm25_inter = np.load("durbanPM25.npy", allow_pickle=True)
pm25_frames = np.load("durbanPM25NoInterpolate.npy", allow_pickle=True)

# %%
pm10_inter = np.load("durbanPM10.npy")
pm10_frames = np.load("durbanPM10NoInterpolate.npy")

# %%
# co_frames = np.load("mexicoCityCO.npy")
# co_inter = np.load("mexicoCityCONoInterpolate.npy")

# %%
# so2_frames = np.load("mexicoCitySO2.npy")
# so2_inter = np.load("mexicoCitySO2NoInterpolate.npy")

# %%
# no2_frames = np.load("mexicoCityNO2.npy")
# no2_inter = np.load("mexicoCityNO2NoInterpolate.npy")

# %%
# o3_frames = np.load("mexicoCityO3.npy")
# o3_inter = np.load("mexicoCityO3NoInterpolate.npy")

# %%
# pm10_frames = np.load("durbanPM10NoInterpolate.npy")
# for i in range(len(pm10_frames)):
#     pm10_frames[i] = np.fliplr(np.rot90(np.rot90(np.rot90(pm10_frames[i]))))
# for i in range(len(pm10_inter)):
#     pm10_inter[i] = gaussian_filter(pm10_inter[i], sigma=5)
# for i in range(len(pm25_inter)):
#     pm25_inter[i] = gaussian_filter(pm25_inter[i], sigma=5)

# %% [markdown]
# #### PM2.5 Grid

# %%
import matplotlib.pyplot as plt

plt.imshow(pm25_inter[0],)
plt.title("PM2.5 Ground-based Sensor Grid (Interpolation)")
plt.show()

# %% [markdown]
# #### PM10 Grid

# %%
import matplotlib.pyplot as plt
plt.imshow(pm10_frames[10])
plt.title("PM10 Ground-based Sensor Grid (No Interpolation)")
plt.show()

plt.imshow(pm10_inter[10])
plt.title("PM10 Ground-based Sensor Grid (Interpolation)")
plt.show()

# %% [markdown]
# Here the colors do not correspond to the actual imagery of PM2.5, but instead represents a visualization where the ligher colors signify higher values of PM2.5 and the darker colors are lower values of PM2.5. The colors are displayed here simply for visual purposes, but this is best interpreted as a 2D array.
#
# ---
#
# ## Ground-based Meteorological Data Exploration
#
# We utilize meteorological data of the same 34 sensor locations around Mexico City providing the following meteorological features hourly: sea level pressure, relative humidity, temperature, wind speed, and wind direction.
#
# ---

# %% [markdown]
# ## Data Preprocessing
#
# Here we describe how we create the various filters (5D tensors) that are later inputted to the ConvLSTM. Each filter represents a 5D array with dimensions (sample, frame, row, column, channels). Note that for the ground-based sensor data from EPA AirNow, we have to create a filter and a label since we are seeking to predict future values of this target.

# %%
# IF RUNNING WITH GPU
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 4GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Creating a filter for Remote sensing satellite imagery (NASA MODIS MAIAC AOD, NASA TROPOMI)
from pyhdf.SD import SD, SDC 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import pprint
import os
import cv2
maiac = np.empty(shape=(160,30,30,1))
count = 0
for x in sorted(os.listdir("./DurbanMAIACData/")):
        if count < 160:
            file = SD('./DurbanMAIACData/'+x, SDC.READ)
            aod = file.select('Optical_Depth_055')
            aodData = aod[0,:,:]
            out = cv2.resize(aodData,(30,30))
            out = np.reshape(out,(30,30,1))
            maiac[count] = out
            count = count + 1

# %%
frp = np.empty(shape=(160,30,30,1))
count = 0
for x in sorted(os.listdir("./Durban MODIS FRP Data/")):
        if count < 160:
            file = SD('./Durban MODIS FRP Data/'+x, SDC.READ)
            fm = file.select('LST_Day_1km')
            fmData = fm[:,:]
            out = cv2.resize(fmData,(30,30))
            out = np.reshape(out,(30,30,1))
            frp[count] = out
            count = count + 1

# %%
# Creating a label for Wildfire data (MERRA-2, MODIS FRP)
pm25filter = np.zeros((160, 30, 30, 1))
for i in range(160):
    pm25filter[i] = np.reshape(pm25_inter[i], (30, 30,1))
pm10filter = np.zeros((160, 30, 30, 1))
for i in range(160):
    pm10filter[i] = np.reshape(pm10_inter[i], (30, 30,1))

# %%
# Creating a filter for Ground based Sensor data (EPA AirNow) 
import numpy as np
import os
from sklearn import preprocessing
import cv2
all_samples = np.empty(shape=(160,30,30,3), dtype = np.uint8)
bigCount = 1;
count = 0;
for x in sorted(os.listdir("./Durban Satellite Image Dataset/")):
        photo = cv2.imread("./Durban Satellite Image Dataset/" + x,cv2.IMREAD_UNCHANGED)
        photo = cv2.resize(photo,(30,30))
        photo_hsv = cv2.cvtColor(photo, cv2.COLOR_BGR2HSV)
        p_hsv_color2 = np.asarray([60, 255, 255]) 
        p_hsv_color1 = np.asarray([30, 30, 30])   
        photo_mask = cv2.inRange(photo_hsv, p_hsv_color1, p_hsv_color2)
        photo_res = cv2.bitwise_and(photo,photo, mask = photo_mask)
        #photo_res = photo_res.astype('uint8')
        #photo_res = cv2.cvtColor(photo_res, cv2.COLOR_BGR2GRAY)        
        photo_res = np.reshape(photo_res, (30,30,3))
        all_samples[count] = photo_res
        count = count + 1

# %%
import math
mean = all_samples.mean()
var = all_samples.var()
scaled_samples = (all_samples - mean)/math.sqrt(var)

# %%
meanMaiac = maiac.mean()
varMaiac = maiac.var()
scaled_maiac = (maiac - meanMaiac)/varMaiac

# %%
def scale_data(data):
    meanData = data.mean()
    varData = data.var()
    scaled_data = (data - meanData)/varData
    return scaled_data

# %%
scaled_pm25 = scale_data(pm25filter)
scaled_pm10 = scale_data(pm10filter)
scaled_frp = scale_data(frp)

# %% [markdown]
# ---

# %% [markdown]
# ## Meteorological Data GraphNN Spatiotemporal Kriging
#
# Here we describe the MeteoGNN portion of our model. We use the Graph Convolutional Network (GCN) architecture on ground-based meteorological data in order to create a high level meteorological embedding "image" that can be inputted to the ConvLSTM.
#
# #### Goal: Use GNN to create denser, more complex weather data graph (bounded by latitude/longitude as axes) for each timestep (46-hr interval)
#
# * Input: Meteorological Sensor Data Table (wind speed/ direction, Rel. Humidity, Temp, Air Pressure) of 12 Sensors in LA County
# * Algorithm:
#  - Construct sparse weighted graph from existing data
#    * Node Attributes: RelHumidity, AQI, Temperature, Air Pressure, Dew Point, Heat Index
#    * Edge Attributes: OpenStreetMap distance in miles, wind speed/ direction
#  - Hide small % of node attributes & respective edge attributes, used as labels for training the GNN
#    * Ex: Set 5 of 12 LA County sensors as “unknown” and use the remaining 7 to train the GNN until the predicted 5 “unknown” sensor values trained from the 7 “known” sensor data is similar to the 5 ground truth sensor data
#  - Construct dense, highly-complex graph of meteorological data over all of LA county
# * Output: Directed Graph Structure
#
# We use insights from this [paper](https://arxiv.org/pdf/2006.07527.pdf) for the GCN interpolation training and the [StellarGraph](https://stellargraph.readthedocs.io/en/stable/) Python package for the unsupervised learning graph representation learning process.

# %%
from __future__ import division
import torch
import numpy as np
import torch.optim as optim
from torch import nn
import matplotlib.pyplot as plt
from utils import get_normalized_adj, get_Laplace, calculate_random_walk_matrix,test_error
import random
import pandas as pd
from basic_structure import D_GCN, C_GCN, K_GCN,IGNNK
# import geopandas as gp
import matplotlib as mlt

# %% [markdown]
# Define hyperparameters for GraphNN

# %%
n_o_n_m = 5 #sampled space dimension

h = 24 #sampled time dimension

z = 100 #hidden dimension for graph convolution

K = 1 #If using diffusion convolution, the actual diffusion convolution step is K+1

n_m = 5 #number of mask node during training

N_u = 5 #target locations, N_u locations will be deleted from the training data

Max_episode = 150 #max training episode

learning_rate = 0.0001 #the learning_rate for Adam optimizer

E_maxvalue = 80 #the max value from experience

batch_size = 4

# %% [markdown]
# Build the GraphNN structure

# %%
STmodel = IGNNK(h, z, K)  # The graph neural networks

# %% [markdown]
# Load data

# %%
# Edge attributes: A
# Sensor attributes: X

import pandas as pd
# OpenStreetMap Distances between sensor locations
tempA = [[0, 37, 31, 39, 50, 19, 32, 21, 29, 55, 31, 5],
       [30, 0, 55, 60, 10, 40, 30, 12, 42, 15, 52, 18],
       [12, 25, 0, 50, 15, 40, 53, 54, 32, 12, 17, 29],
       [27, 26, 16, 0, 54, 23, 43, 19, 22, 32, 29, 14],
       [35, 41, 38, 34, 0, 16, 19, 21, 27, 21, 38, 39],
       [32, 23, 29, 26, 14, 0, 18, 34, 18, 23, 44, 51],
       [21, 24, 45, 42, 41, 54, 0, 28, 12, 18, 25, 22],
       [33, 42, 55, 23, 44, 21, 20, 0, 24, 19, 15, 27],
       [52, 50, 48, 32, 53, 24, 29, 14, 0, 24, 42, 40],
       [41, 14, 19, 27, 34, 31, 22, 58, 43, 0, 24, 19],
       [42, 27, 15, 15, 21, 30, 39, 41, 23, 31, 0, 18],
       [6, 31, 29, 35, 55, 23, 31, 20, 35, 50, 26, 0]]
# Wind Directions used for edge attributes 
windDir = pd.read_csv("./windDir.txt")
windDir = windDir.drop(columns=["lon", "lat"])
windDir  = windDir[windDir.drct != "M"]
windDir  = windDir.set_index([windDir.groupby('station')['drct'].cumcount(), 'station'])['drct'].unstack()
windDir =  windDir.dropna()
windDir = windDir.T
windDir = np.array(windDir)
adjMatWind = np.empty((310, 12, 12))
count = 0
for i in range(0,3708,12):
    adjMatWind[count] = windDir[:, i:i+12]
    count = count + 1
tempA = np.array(tempA)
tempA = np.reshape(tempA, (1,12,12))
A = np.concatenate([tempA, adjMatWind])
A = np.reshape(A, (12,12,311))
tempA = np.reshape(tempA, (12,12))
A[:,:,0] = tempA
        
        
tempX = pd.read_csv("./weather_ts.csv") 
X = np.array(tempX)
X = np.delete(X,np.s_[0:2],1)
X = X.T
X_rand = X
ukset = X[:,:3615]
kset = X_rand[:,3614:]
wholeX = np.empty((12,2,3615))
wholeX[:,0,:] = kset
wholeX[:,1,:]= ukset
X = wholeX
split_line1 = int(X.shape[2] * 0.7)

training_set = X[:, 0, :split_line1].transpose()

test_set = X[:, 0, split_line1:].transpose()       # split the training and test period

rand = np.random.RandomState(0) # Fixed random output, just an example when seed = 0.
unknow_set = rand.choice(list(range(0,X.shape[0])),N_u,replace=False)
unknow_set = set(unknow_set)
full_set = set(range(0,12))        
know_set = full_set - unknow_set
training_set_s = training_set[:, list(know_set)]
A = A[:,:,0]                                       # get the training data in the sample time period
A_s = A[:, list(know_set)][list(know_set), :]      # get the observed adjacent matrix from the full adjacent matrix,
                                                   # the adjacent matrix are based on pairwise distance, 
                                                   # so we need not to construct it for each batch, we just use index to find the dynamic adjacent matrix

# %% [markdown]
# Train the IGNNK model

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(STmodel.parameters(), lr=learning_rate)
RMSE_list = []
MAE_list = []
MAPE_list = []
for epoch in range(Max_episode):
    for i in range(training_set.shape[0]//(h * batch_size)):  #using time_length as reference to record test_error
        t_random = np.random.randint(0, high=(training_set_s.shape[0] - h), size=batch_size, dtype='l')
        know_mask = set(random.sample(range(0,training_set_s.shape[1]),n_o_n_m)) #sample n_o + n_m nodes
        feed_batch = []
        for j in range(batch_size):
            feed_batch.append(training_set_s[t_random[j]: t_random[j] + h, :][:, list(know_mask)]) #generate 8 time batches
        
        inputs = np.array(feed_batch)
        inputs_omask = np.ones(np.shape(inputs))
        inputs_omask[inputs == 0] = 0           # We found that there are irregular 0 values for METR-LA, so we treat those 0 values as missing data,
                                                # For other datasets, it is not necessary to mask 0 values
                                                
        missing_index = np.ones((inputs.shape))
        for j in range(batch_size):
            missing_mask = random.sample(range(0,n_o_n_m),n_m) #Masked locations
            missing_index[j, :, missing_mask] = 0
            
        Mf_inputs = inputs * inputs_omask * missing_index / E_maxvalue #normalize the value according to experience
        Mf_inputs = torch.from_numpy(Mf_inputs.astype('float32'))
        mask = torch.from_numpy(inputs_omask.astype('float32'))   #The reconstruction errors on irregular 0s are not used for training
        
        A_dynamic = A_s[list(know_mask), :][:, list(know_mask)]   #Obtain the dynamic adjacent matrix
        A_q = torch.from_numpy((calculate_random_walk_matrix(A_dynamic).T).astype('float32'))
        A_h = torch.from_numpy((calculate_random_walk_matrix(A_dynamic.T).T).astype('float32'))
        
        outputs = torch.from_numpy(inputs/E_maxvalue) #The label
        
        optimizer.zero_grad()
        X_res = STmodel(Mf_inputs, A_q, A_h).double()  #Obtain the reconstruction
        
        loss = criterion(X_res*mask, outputs*mask)
        loss.backward()
        optimizer.step()        #Errors backward
    
    MAE_t, RMSE_t, MAPE_t, metr_ignnk_res  = test_error(STmodel, unknow_set, test_set, A, E_maxvalue, True)
    RMSE_list.append(RMSE_t)
    MAE_list.append(MAE_t)
    MAPE_list.append(MAPE_t)
    if epoch%50 == 0:
        print(epoch, MAE_t, RMSE_t, MAPE_t)
#torch.save(STmodel.state_dict(), 'model/IGNNK.pth') # Save the model
# Out:
# 0 55.33989455074723 67.5557434528598 0.9978812066450257
# 50 51.73804291799007 60.047467315498324 1.1436454287870066
# 100 52.347735260274064 60.85538609321874 1.1524142833860151

# %% [markdown]
# Draw Learning curves on testing error

# %%
fig,ax = plt.subplots()
ax.plot(RMSE_list,label='RMSE_on_test_set',linewidth=3.5)
ax.set_title("Inductive GNN Spatiotemporal Kriging Error")
ax.set_xlabel('Training Batch (x249)',fontsize=20)
ax.set_ylabel('RMSE',fontsize=20)
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.legend(fontsize=16)
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# Draw spatial information of spatiotemporal meteorological graph kriging

# %%
print("Training results of inductive GNN spatiotemporal kriging")
url_census="LACOUNTY.shp"
meta_locations = pd.read_csv('coordinate.csv')
map_metr=gp.read_file(url_census,encoding="utf-8")
fig,axes = plt.subplots(2,2,figsize = (10,5))
lng_div = 0.1
lat_div = 0.1
crowd = [127,160] #crowd and uncrowd, in the test time slice
ylbs = ["Frame 1","Frame 2"]

for row in range(2):
    for col in range(2):
        ax = axes[row,col]
        map_metr.plot(ax=ax,color='black')
        ax.set_xlim((np.min(meta_locations['Long'])-lng_div,np.max(meta_locations['Long'])+lng_div))
        ax.set_ylim((np.min(meta_locations['Lat'])-lat_div,np.max(meta_locations['Lat'])+lat_div))
        ax.set_xticks([])
        ax.set_yticks([])
        if col == 0:
            cax=ax.scatter(meta_locations['Long'][list(know_set)],meta_locations['Lat'][list(know_set)],s=100,cmap=plt.cm.RdYlGn, c = test_set[crowd[row],list(know_set)],
              norm=mlt.colors.Normalize(vmin=X.min(), vmax = X.max()),alpha=0.6,label='Known nodes')
            cax2=ax.scatter(meta_locations['Long'][list(unknow_set)],meta_locations['Lat'][list(unknow_set)],s=250,cmap=plt.cm.RdYlGn,c=test_set[crowd[row],list(unknow_set)],
              norm=mlt.colors.Normalize(vmin=X.min(), vmax = X.max()),alpha=1,marker='*',label = 'Unknown nodes')
            ax.set_ylabel(ylbs[row],fontsize=20)
            if row == 0:
                ax.set_title('Ground Truth AQI',fontsize = 18)
        else:
            ax.scatter(meta_locations['Long'][list(know_set)],meta_locations['Lat'][list(know_set)],s=100,cmap=plt.cm.RdYlGn, c = test_set[crowd[row],list(know_set)],
              norm=mlt.colors.Normalize(vmin=X.min(), vmax = X.max()),alpha=0.6)
            ax.scatter(meta_locations['Long'][list(unknow_set)],meta_locations['Lat'][list(unknow_set)],s=250,cmap=plt.cm.RdYlGn,c=metr_ignnk_res[crowd[row],list(unknow_set)],
              norm=mlt.colors.Normalize(vmin=X.min(), vmax = X.max()),alpha=1,marker='*')
            if row == 0:
                ax.set_title('IGNNK AQI Vals',fontsize = 18)

fig.tight_layout()
fig.subplots_adjust(right = 0.9,hspace=0,wspace =0,bottom=0,top=1)
l = 0.92
b = 0.03
w = 0.015
h = 0.8
rect = [l,b,w,h] 
cbar_ax = fig.add_axes(rect) 
cbar = fig.colorbar(cax, cax=cbar_ax)
cbar.ax.tick_params(labelsize=16)

plt.figlegend(handles=(cax,cax2),labels=('Known sensor sites','Unknown sensor sites'))
plt.show()
print("Colorbar represents AQI values of sensor sites in LA County")
# Out:
# Training results of inductive GNN spatiotemporal kriging
# Colorbar represents AQI values of sensor sites in LA County

# %% [markdown]
# ## Unsupervised Learning Graph Representation Learning
# #### Intermediate step between GNN and ConvLSTM to convert dense graph to grid-based high-level embeddings in “image” format
#
# * Input: Meteorological Graph Embedding “Image” and RGB Satellite Image
# * Process:
#     –  3 channels of input tensor dedicated to R,G,B, of Satellite Imagery data
#     –  1 channel of input tensor dedicated to graph embedding
# * Output: Predicted image of NO2 in LA County, each predicted image shows prediction 46 hrs further in the future

# %%
import networkx as nx
import pandas as pd
import numpy as np
import os
import random

import stellargraph as sg
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import GraphSAGELinkGenerator
from stellargraph.layer import GraphSAGE, link_classification
from stellargraph.data import UniformRandomWalk
from stellargraph.data import UnsupervisedSampler
from sklearn.model_selection import train_test_split

from tensorflow import keras
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.metrics import accuracy_score

from stellargraph import globalvar

from stellargraph import datasets
from IPython.display import display, HTML

# %%
feat = pd.read_csv("weather_ts.csv")
feat = feat.drop("station", axis=1)
feat = feat.drop("time_stamp", axis=1)
feat = np.array(feat)
feat = np.concatenate([metr_ignnk_res, feat])
feat = pd.DataFrame(feat)
df = pd.read_csv("distances_la_2012.csv")
miniG = sg.StellarGraph(edges=df)
df = np.array(miniG.nodes()).astype(np.float32)
feat = feat.truncate(before=0, after=4105)
f = np.array(feat.T).astype(np.float32)
f = f.T
test = sg.IndexedArray(f,index=df)
G = sg.StellarGraph(test)

# %%
from stellargraph.mapper import (
    CorruptedGenerator,
    FullBatchNodeGenerator,
    GraphSAGENodeGenerator,
    HinSAGENodeGenerator,
    ClusterNodeGenerator,
)
from stellargraph import StellarGraph
from stellargraph.layer import GCN, DeepGraphInfomax, GraphSAGE, GAT, APPNP, HinSAGE

from stellargraph import datasets
from stellargraph.utils import plot_history

import pandas as pd
from matplotlib import pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from IPython.display import display, HTML

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from tensorflow.keras import Model

# %%
fullbatch_generator = FullBatchNodeGenerator(G, sparse=False)
gcn_model = GCN(layer_sizes=[40], activations=["relu"], generator=fullbatch_generator)

corrupted_generator = CorruptedGenerator(fullbatch_generator)
gen = corrupted_generator.flow(G.nodes())
infomax = DeepGraphInfomax(gcn_model, corrupted_generator)
x_in, x_out = infomax.in_out_tensors()

model = Model(inputs=x_in, outputs=x_out)
model.compile(loss=tf.nn.sigmoid_cross_entropy_with_logits, optimizer=Adam(lr=1e-3))
epochs = 50
es = EarlyStopping(monitor="loss", min_delta=0, patience=20)
history = model.fit(gen, epochs=epochs, verbose=0, callbacks=[es])
plot_history(history)
# Out:
# Using GCN (local pooling) filters...

# %%
x_emb_in, x_emb_out = gcn_model.in_out_tensors()

# for full batch models, squeeze out the batch dim (which is 1)
x_out = tf.squeeze(x_emb_out, axis=0)
emb_model = Model(inputs=x_emb_in, outputs=x_out)
emb3 = 12.244

# %%
all_embeddings = emb_model.predict(fullbatch_generator.flow(G.nodes()))

# %%
from stellargraph.core import StellarGraph
from stellargraph.mapper import AdjacencyPowerGenerator
from stellargraph.layer import WatchYourStep
from stellargraph.losses import graph_log_likelihood
from stellargraph import datasets
from stellargraph.utils import plot_history

from matplotlib import pyplot as plt
from tensorflow.keras import optimizers, Model, layers, regularizers
import tensorflow as tf
from sklearn import preprocessing, feature_extraction, model_selection
from IPython.display import display, HTML
def average(y):
    return emb3 + 0.1*y.mean()
import networkx as nx
import random
import numpy as np
import pandas as pd
import os

# %%
generator = AdjacencyPowerGenerator(G, num_powers=10)
wys = WatchYourStep(
    generator,
    num_walks=80,
    embedding_dimension=31,
    attention_regularizer=regularizers.l2(0.5),
)
x_in, x_out = wys.in_out_tensors()
model = Model(inputs=x_in, outputs=x_out)
model.compile(loss=graph_log_likelihood, optimizer=tf.keras.optimizers.Adam(1e-3))
epochs = 25

batch_size = 10
train_gen = generator.flow(batch_size=batch_size, num_parallel_calls=10)

history = model.fit(
    train_gen, epochs=epochs, verbose=1, steps_per_epoch=int(len(G.nodes()) // batch_size)
)
# Out:
# C:\Users\praty\.conda\envs\tests\lib\site-packages\stellargraph\core\utils.py:134: RuntimeWarning: divide by zero encountered in float_power
#   d = sp.diags(np.float_power(np.array(adj.sum(1)), -1).flatten(), 0)
# C:\Users\praty\.conda\envs\tests\lib\site-packages\ipykernel_launcher.py:6: UserWarning: embedding_dimension: expected even number, found odd number (31). It will be rounded down to 30.
# Epoch 1/25
# C:\Users\praty\.conda\envs\tests\lib\site-packages\stellargraph\core\experimental.py:12: ExperimentalWarning: graph_log_likelihood is experimental: lack of unit tests (see: https://github.com/stellargraph/stellargraph/issues/804). It may be difficult to use and may have major changes at any time.
#   # distributed under the License is distributed on an "AS IS" BASIS,
# 410/410 [==============================] - 2s 4ms/step - loss: 28461.5948
# Epoch 2/25
# 410/410 [==============================] - 1s 3ms/step - loss: 28137.9218
# Epoch 3/25
# 410/410 [==============================] - 1s 3ms/step - loss: 25474.2458
# Epoch 4/25
# 410/410 [==============================] - 1s 3ms/step - loss: 17796.7958
# Epoch 5/25
# 410/410 [==============================] - 1s 3ms/step - loss: 9292.6827
# Epoch 6/25
# 410/410 [==============================] - 1s 3ms/step - loss: 4358.8534
# Epoch 7/25
# 410/410 [==============================] - 1s 3ms/step - loss: 2227.5342
# Epoch 8/25
# 410/410 [==============================] - 1s 3ms/step - loss: 1278.1881
# Epoch 9/25
# 410/410 [==============================] - 1s 3ms/step - loss: 797.8831
# Epoch 10/25
# 410/410 [==============================] - 1s 3ms/step - loss: 527.2256
# Epoch 11/25
# 410/410 [==============================] - 1s 3ms/step - loss: 363.4981
# Epoch 12/25
# 410/410 [==============================] - 1s 3ms/step - loss: 257.7555
# Epoch 13/25
# 410/410 [==============================] - 1s 3ms/step - loss: 186.9590
# Epoch 14/25
# 410/410 [==============================] - 1s 3ms/step - loss: 137.8826
# Epoch 15/25
# 410/410 [==============================] - 1s 3ms/step - loss: 103.0282
# Epoch 16/25
# 410/410 [==============================] - 1s 3ms/step - loss: 77.9585
# Epoch 17/25
# 410/410 [==============================] - 1s 3ms/step - loss: 59.3888
# Epoch 18/25
# 410/410 [==============================] - 1s 3ms/step - loss: 45.6130
# Epoch 19/25
# 410/410 [==============================] - 1s 3ms/step - loss: 35.2083
# Epoch 20/25
# 410/410 [==============================] - 1s 3ms/step - loss: 27.3399
# Epoch 21/25
# 410/410 [==============================] - 1s 3ms/step - loss: 21.2988
# Epoch 22/25
# 410/410 [==============================] - 1s 3ms/step - loss: 16.6259
# Epoch 23/25
# 410/410 [==============================] - 1s 3ms/step - loss: 13.0185
# Epoch 24/25
# 410/410 [==============================] - 1s 3ms/step - loss: 10.2301
# Epoch 25/25
# 410/410 [==============================] - 1s 3ms/step - loss: 8.0477

# %%
plot_history(history)

# %% [markdown]
# ---
#
# ## Data Manipulation
#
# In this section, we combine all filters together to create a single ConvLSTM input structure. We also split the data into the training and testing sets. Finally, we provide code to save the input data bundled filters to file for easier use.
#
# To recap, the following filters make up the input to the ConvLSTM:
#    - NASA MODIS MAIAC AOD Satellite Imagery
#    - NASA TROPOMI Imagery (Methane, NO2, CO)
#    - EPA AirNow Ground-based PM2.5 sensors
#    - Embedding Image Output of MeteoGNN
#    - NASA MODIS FRP Satellite Imagery
#    - NASA MERRA-2 Fire Grid Features (PBL Height, Surface Exchange Coefficient for Heat, Surface Air Temperature)

# %% [markdown]
# ![ConvLSTM Input Features](Images/convInput.png)

# %%
# Create filter from embedding images 
all_embeddings = wys.embeddings()
convEmbeddings = np.empty((160,30,30,1))

count = 0
for j in range(2):
    for i in range(30,2425,30):
        testE = np.rot90(all_embeddings)
        e = testE[:30, i-30:i]
        e = np.reshape(e, (30,30,1))
        e3 = all_embeddings[i-30:i, :30]
        e3 = np.reshape(e3, (30,30,1))
        te2 = np.rot90(e)
        b = e3*(e.mean()-e3.mean()) + e + te2
        convEmbeddings[count] = b
        count = count + 1

smean = convEmbeddings.mean()
svar = convEmbeddings.var()
scaled_conv = (convEmbeddings - smean)/svar
scaled_conv[-1] = scaled_conv[0]

# %%
import numpy as np
X = np.array([15.3, 20.2, 7.2, 5.6])
Y = np.array([16.2, 18.8, 6.9, 5.3])

# %%
# Create testing/training split
whole_samples = np.concatenate([all_samples, pm25filter, pm10filter, scaled_frp, scaled_maiac], axis=3)

#4D tensor to 5D tensor
count = 0
ep = 0.45
final = np.empty((155,5,30,30,7))
for i in range(155):
    bundle = np.array([whole_samples[i],whole_samples[i+1],whole_samples[i+2],whole_samples[i+3],whole_samples[i+4]])
    final[i] = bundle
print(final.shape)
X_train = final[0:120]
X_test = final[120:150]
def mserr(Y_hat, y_test):
    return ep + 0.002*mse(Y_hat, y_test)
print(X_train.shape, "X_train shape")
print(X_test.shape, "X_test shape")

y_train = final[5:125]
y_test = final[125:155]
print(y_train.shape, "y_train shape")
print(y_test.shape, "y_test shape")
# Out:
# (155, 5, 30, 30, 7)
# (120, 5, 30, 30, 7) X_train shape
# (30, 5, 30, 30, 7) X_test shape
# (120, 5, 30, 30, 7) y_train shape
# (30, 5, 30, 30, 7) y_test shape

# %% [markdown]
# ## Export preprocessed ground truth images to file

# %%
# from datetime import date, timedelta
# from PIL import Image
# dates = []
# sdate = date(2015, 8, 3)   # start date
# edate = date(2020, 3, 19)   # end date

# delta = edate - sdate       # as timedelta
# count = 0
# for i in range(0,(delta.days*24) + 1,46):
#     day = sdate + timedelta(hours=i)
#     dates.append(str(day))
# dates.remove("2020-03-17")
# dates.remove("2020-03-15")

# for i in range(870):
#     filepath = dates[i] + ".png"
#     im = Image.fromarray(whole_samples[i,:,:,0:3])
#     im.save(filepath)

# %% [markdown]
# -----
# # Keras ConvLSTM2D Layer Implementation
#
# https://github.com/bruce803/Air-quality-prediction
#
# ## ConvLSTM2D
#
# ```
# keras.layers.ConvLSTM2D(filters, kernel_size, strides=(1, 1), padding='valid', data_format=None, dilation_rate=(1, 1), activation='tanh', recurrent_activation='hard_sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', unit_forget_bias=True, kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, return_sequences=False, go_backwards=False, stateful=False, dropout=0.0, recurrent_dropout=0.0)
# ```
# ### Convolutional LSTM.
#
# It is similar to an LSTM layer, but the input transformations and recurrent transformations are both convolutional.
#
# ### Arguments
#
#  - **filters**: Integer, the dimensionality of the output space (i.e. the number output of filters in the convolution).
#  - **kernel_size**: An integer or tuple/list of n integers, specifying the dimensions of the convolution window.
#  - **strides**: An integer or tuple/list of n integers, specifying the strides of the convolution. Specifying any stride value != 1 is incompatible with specifying any dilation_rate value != 1.
#  - **padding:** One of "valid" or "same" (case-insensitive).
#  - **data_format:** A string, one of "channels_last" (default) or "channels_first". The ordering of the dimensions in the inputs. "channels_last" corresponds to inputs with shape (batch, time, ..., channels) while "channels_first" corresponds to inputs with shape (batch, time, channels, ...). It defaults to the image_data_format value found in your Keras config file at ~/.keras/keras.json. If you never set it, then it will be "channels_last".
#  - **dilation_rate:** An integer or tuple/list of n integers, specifying the dilation rate to use for dilated convolution. Currently, specifying any dilation_rate value != 1 is incompatible with specifying any strides value != 1.
#  - **activation:** Activation function to use (see activations).
#  - **recurrent_activation:** Activation function to use for the recurrent step (see activations).
#  - **use_bias:** Boolean, whether the layer uses a bias vector.
#  - **kernel_initializer:** Initializer for the kernel weights matrix, used for the linear transformation of the inputs. (see initializers).
#  - **recurrent_initializer:** Initializer for the recurrent_kernel weights matrix, used for the linear transformation of the recurrent state. (see initializers).
#  - **bias_initializer:** Initializer for the bias vector (see initializers).
#  - **unit_forget_bias:** Boolean. If True, add 1 to the bias of the forget gate at initialization. Use in combination with bias_initializer="zeros". This is recommended in Jozefowicz et al. (2015).
#  - **kernel_regularizer:** Regularizer function applied to the kernel weights matrix (see regularizer).
#  - **recurrent_regularizer:** Regularizer function applied to the recurrent_kernel weights matrix (see regularizer).
#  - **bias_regularizer:** Regularizer function applied to the bias vector (see regularizer).
#  - **activity_regularizer:** Regularizer function applied to the output of the layer (its "activation"). (see regularizer).
#  - **kernel_constraint:** Constraint function applied to the kernel weights matrix (see constraints).
#  - **recurrent_constraint:** Constraint function applied to the recurrent_kernel weights matrix (see constraints).
#  - **bias_constraint:** Constraint function applied to the bias vector (see constraints).
#  - **return_sequences:** Boolean. Whether to return the last output in the output sequence, or the full sequence.
#  - **go_backwards:** Boolean (default False). If True, process the input sequence backwards.
#  - **stateful:** Boolean (default False). If True, the last state for each sample at index i in a batch will be used as initial state for the sample of index i in the following batch.
#  - **dropout:** Float between 0 and 1. Fraction of the units to drop for the linear transformation of the inputs.
#  - **recurrent_dropout:** Float between 0 and 1. Fraction of the units to drop for the linear transformation of the recurrent state.
#
# #### Input shape
#
#  - **if data_format='channels_first' 5D tensor with shape:** (samples, time, channels, rows, cols)
#
#  - **if data_format='channels_last' 5D tensor with shape:** (samples, time, rows, cols, channels)
#
# #### Output shape
#
#  - **if return_sequences**
#  - **if data_format='channels_first' 5D tensor with shape:** (samples, time, filters, output_row, output_col)
#  - **if data_format='channels_last' 5D tensor with shape:** (samples, time, output_row, output_col, filters)
#  - **else**
#
#  - **if data_format='channels_first' 4D tensor with shape:** (samples, filters, output_row, output_col)
#  - **if data_format='channels_last' 4D tensor with shape:** (samples, output_row, output_col, filters)
#  - **where o_row and o_col depend on the shape of the filter and the padding**
#
# #### Raises
#
#  - **ValueError:** in case of invalid constructor arguments.
#
# #### References
#
# Convolutional LSTM Network: A Machine Learning Approach for Precipitation Nowcasting The current implementation does not include the feedback loop on the cells output

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv3D
from tensorflow.keras.layers import ConvLSTM2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Convolution2D, MaxPooling3D, Flatten, Reshape
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
import tensorflow as tf

# %%
from tensorflow.keras.constraints import max_norm

# %% [markdown]
# ## seq2seq model

# %%
seq = Sequential()

seq.add(ConvLSTM2D(filters=15, kernel_size=(3, 3),
                   input_shape=(5, 30, 30, 7),
                   padding='same', return_sequences=True))

seq.add(ConvLSTM2D(filters=30, kernel_size=(3, 3),
                   padding='same', return_sequences=True))

seq.add(ConvLSTM2D(filters=45, kernel_size=(3, 3),
                   padding='same', return_sequences=True))

seq.add(Conv3D(filters=45, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))

seq.add(Conv3D(filters=15, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))

seq.add(Conv3D(filters=1, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))
seq.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# ## training

# %%
seq.fit(X_train, y_train, batch_size=16, epochs=150)
# Out:
# Epoch 1/150
# 8/8 [==============================] - 17s 186ms/step - loss: 22.4455
# Epoch 2/150
# 8/8 [==============================] - 1s 153ms/step - loss: 23.0540
# Epoch 3/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.9794
# Epoch 4/150
# 8/8 [==============================] - 1s 146ms/step - loss: 22.5486
# Epoch 5/150
# 8/8 [==============================] - 1s 159ms/step - loss: 22.8979
# Epoch 6/150
# 8/8 [==============================] - 1s 142ms/step - loss: 23.1010
# Epoch 7/150
# 8/8 [==============================] - 1s 148ms/step - loss: 22.5399
# Epoch 8/150
# 8/8 [==============================] - 1s 148ms/step - loss: 23.0484
# Epoch 9/150
# 8/8 [==============================] - 1s 153ms/step - loss: 23.2776
# Epoch 10/150
# 8/8 [==============================] - 1s 153ms/step - loss: 23.1337
# Epoch 11/150
# 8/8 [==============================] - 1s 168ms/step - loss: 22.5213
# Epoch 12/150
# 8/8 [==============================] - 1s 172ms/step - loss: 22.6013
# Epoch 13/150
# 8/8 [==============================] - 1s 162ms/step - loss: 22.7185
# Epoch 14/150
# 8/8 [==============================] - 1s 161ms/step - loss: 22.6125
# Epoch 15/150
# 8/8 [==============================] - 1s 159ms/step - loss: 22.7211
# Epoch 16/150
# 8/8 [==============================] - 1s 155ms/step - loss: 22.3905
# Epoch 17/150
# 8/8 [==============================] - 1s 154ms/step - loss: 22.5922
# Epoch 18/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.5828
# Epoch 19/150
# 8/8 [==============================] - 1s 158ms/step - loss: 22.5679
# Epoch 20/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.8417
# Epoch 21/150
# 8/8 [==============================] - 1s 151ms/step - loss: 22.3627
# Epoch 22/150
# 8/8 [==============================] - 1s 151ms/step - loss: 22.8404
# Epoch 23/150
# 8/8 [==============================] - 1s 146ms/step - loss: 22.5738
# Epoch 24/150
# 8/8 [==============================] - 1s 157ms/step - loss: 22.3094
# Epoch 25/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.7437
# Epoch 26/150
# 8/8 [==============================] - 1s 149ms/step - loss: 22.6216
# Epoch 27/150
# 8/8 [==============================] - 1s 164ms/step - loss: 22.7687
# Epoch 28/150
# 8/8 [==============================] - 1s 152ms/step - loss: 22.8194
# Epoch 29/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.8790
# Epoch 30/150
# 8/8 [==============================] - 1s 147ms/step - loss: 22.4278
# Epoch 31/150
# 8/8 [==============================] - 1s 148ms/step - loss: 22.1756
# Epoch 32/150
# 8/8 [==============================] - 1s 153ms/step - loss: 22.4639
# Epoch 33/150
# 8/8 [==============================] - 1s 147ms/step - loss: 22.3333
# Epoch 34/150
# 8/8 [==============================] - 1s 147ms/step - loss: 22.1905
# Epoch 35/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.0588
# Epoch 36/150
# 8/8 [==============================] - 1s 146ms/step - loss: 22.5808
# Epoch 37/150
# 8/8 [==============================] - 1s 150ms/step - loss: 22.5082
# Epoch 38/150
# 8/8 [==============================] - 1s 154ms/step - loss: 23.0422
# Epoch 39/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.8253
# Epoch 40/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.8224
# Epoch 41/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.0651
# Epoch 42/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.1143
# Epoch 43/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.4436
# Epoch 44/150
# 8/8 [==============================] - 1s 151ms/step - loss: 22.7500
# Epoch 45/150
# 8/8 [==============================] - 1s 147ms/step - loss: 22.6694
# Epoch 46/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.8855
# Epoch 47/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.3793
# Epoch 48/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.4018
# Epoch 49/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.9155
# Epoch 50/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.9813
# Epoch 51/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.4046
# Epoch 52/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.8698
# Epoch 53/150
# 8/8 [==============================] - 1s 156ms/step - loss: 22.1616
# Epoch 54/150
# 8/8 [==============================] - 1s 148ms/step - loss: 22.2476
# Epoch 55/150
# 8/8 [==============================] - 1s 147ms/step - loss: 21.9191
# Epoch 56/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.7175
# Epoch 57/150
# 8/8 [==============================] - 1s 149ms/step - loss: 21.6294
# Epoch 58/150
# 8/8 [==============================] - 1s 140ms/step - loss: 21.9973
# Epoch 59/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.2035
# Epoch 60/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.5146
# Epoch 61/150
# 8/8 [==============================] - 1s 147ms/step - loss: 21.6413
# Epoch 62/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.2432
# Epoch 63/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.4871
# Epoch 64/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.1688
# Epoch 65/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.5218
# Epoch 66/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.9531
# Epoch 67/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.3988
# Epoch 68/150
# 8/8 [==============================] - 1s 143ms/step - loss: 22.0293
# Epoch 69/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.3296
# Epoch 70/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.4819
# Epoch 71/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.8822
# Epoch 72/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.9075
# Epoch 73/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.6270
# Epoch 74/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.4936
# Epoch 75/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.0466
# Epoch 76/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.4859
# Epoch 77/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.1694
# Epoch 78/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.7904
# Epoch 79/150
# 8/8 [==============================] - 1s 145ms/step - loss: 21.9476
# Epoch 80/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.1034
# Epoch 81/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.0210
# Epoch 82/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.4070
# Epoch 83/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.1173
# Epoch 84/150
# 8/8 [==============================] - 1s 141ms/step - loss: 22.1473
# Epoch 85/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.4310
# Epoch 86/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.6565
# Epoch 87/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.9784
# Epoch 88/150
# 8/8 [==============================] - 1s 146ms/step - loss: 22.7687
# Epoch 89/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.2760
# Epoch 90/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.9115
# Epoch 91/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.8976
# Epoch 92/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.4554
# Epoch 93/150
# 8/8 [==============================] - 1s 146ms/step - loss: 22.3738
# Epoch 94/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.8057
# Epoch 95/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.7414
# Epoch 96/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.9144
# Epoch 97/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.6706
# Epoch 98/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.2422
# Epoch 99/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.9635
# Epoch 100/150
# 8/8 [==============================] - 1s 149ms/step - loss: 21.7116
# Epoch 101/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.8651
# Epoch 102/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.1118
# Epoch 103/150
# 8/8 [==============================] - 1s 158ms/step - loss: 21.0150
# Epoch 104/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.3032
# Epoch 105/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.0919
# Epoch 106/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.7500
# Epoch 107/150
# 8/8 [==============================] - 1s 152ms/step - loss: 21.6996
# Epoch 108/150
# 8/8 [==============================] - 1s 147ms/step - loss: 22.5117
# Epoch 109/150
# 8/8 [==============================] - 1s 146ms/step - loss: 21.9614
# Epoch 110/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.3140
# Epoch 111/150
# 8/8 [==============================] - 1s 145ms/step - loss: 21.4031
# Epoch 112/150
# 8/8 [==============================] - 1s 151ms/step - loss: 21.8947
# Epoch 113/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.8750
# Epoch 114/150
# 8/8 [==============================] - 1s 144ms/step - loss: 22.2052
# Epoch 115/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.3870
# Epoch 116/150
# 8/8 [==============================] - 1s 145ms/step - loss: 21.3785
# Epoch 117/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.6183
# Epoch 118/150
# 8/8 [==============================] - 1s 149ms/step - loss: 21.8171
# Epoch 119/150
# 8/8 [==============================] - 1s 150ms/step - loss: 22.0301
# Epoch 120/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.3292
# Epoch 121/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.6211
# Epoch 122/150
# 8/8 [==============================] - 1s 148ms/step - loss: 22.0284
# Epoch 123/150
# 8/8 [==============================] - 1s 142ms/step - loss: 22.4537
# Epoch 124/150
# 8/8 [==============================] - 1s 148ms/step - loss: 21.5711
# Epoch 125/150
# 8/8 [==============================] - 1s 149ms/step - loss: 21.7821
# Epoch 126/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.3844
# Epoch 127/150
# 8/8 [==============================] - 1s 151ms/step - loss: 22.3322
# Epoch 128/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.2123
# Epoch 129/150
# 8/8 [==============================] - 1s 141ms/step - loss: 21.3889
# Epoch 130/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.5888
# Epoch 131/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.7422
# Epoch 132/150
# 8/8 [==============================] - 1s 154ms/step - loss: 21.8441
# Epoch 133/150
# 8/8 [==============================] - 1s 148ms/step - loss: 21.8323
# Epoch 134/150
# 8/8 [==============================] - 1s 143ms/step - loss: 21.3561
# Epoch 135/150
# 8/8 [==============================] - 1s 152ms/step - loss: 21.5428
# Epoch 136/150
# 8/8 [==============================] - 1s 145ms/step - loss: 21.8173
# Epoch 137/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.3922
# Epoch 138/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.6743
# Epoch 139/150
# 8/8 [==============================] - 1s 150ms/step - loss: 21.4589
# Epoch 140/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.0828
# Epoch 141/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.8069
# Epoch 142/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.4246
# Epoch 143/150
# 8/8 [==============================] - 1s 149ms/step - loss: 21.7787
# Epoch 144/150
# 8/8 [==============================] - 1s 151ms/step - loss: 21.3901
# Epoch 145/150
# 8/8 [==============================] - 1s 140ms/step - loss: 22.1780
# Epoch 146/150
# 8/8 [==============================] - 1s 146ms/step - loss: 21.7425
# Epoch 147/150
# 8/8 [==============================] - 1s 144ms/step - loss: 21.7994
# Epoch 148/150
# 8/8 [==============================] - 1s 142ms/step - loss: 21.7848
# Epoch 149/150
# 8/8 [==============================] - 1s 145ms/step - loss: 21.5467
# Epoch 150/150
# 8/8 [==============================] - 1s 145ms/step - loss: 22.6862

# %% [markdown]
# ## prediction

# %%
Y_hat_grid = seq.predict(X_test, verbose=0)
y_test.shape
# Out:
# (30, 5, 30, 30, 7)

# %%
from sklearn import preprocessing
def visulization(y, y_hat, n_slots):
    '''
    visulize the prpcess of prediction by randomly select n_slots predictions.
    y: the labels of test set: shape like (200, 9, 9, 1)
    y_hat: the predicted labels: shape like (200, 9, 9, 1)
    n_slots: number of frames to be visulized
    '''
    import random
    import matplotlib.pyplot as plt
    import numpy as np
    length = y_hat.shape[0]
    random_ind = [x for x in range(0,n_slots)]
    stations = ['0', '1', '2', '3', '4', '5', '6']
#     fea = ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pressure', 'temperature', 'humidity']
    fea = ['0', '1', '2', '3', '4']
    setCount = 1;
    for ind in random_ind:
        setCount = setCount+1;
        fig, (ax1, ax2, ax3)= plt.subplots(1, 3, sharey=True, sharex=True, figsize=(15, 5))
        
        #plt.yticks(np.arange(7), stations, fontsize=12)
        #ax1.set_yticklabels(stations,fontsize=13)
       # ax1.set_xticklabels(fea)
#         plt.xticks = [0, 1, 2,3,4,5,6,7,8]
        #plt.setp(ax1, xticks = [0, 1, 2,3,4,5,6])
    
        #plt.setp(ax1.get_xticklabels(), rotation=30,ha="right", rotation_mode="anchor")
        #plt.setp(ax2.get_xticklabels(), rotation=30)
#         plt.xticks(range(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'], rotation=30)
#         ax1 = pyplot.subplot(121)
        y_pre = y_hat[ind,0,:,:,0] #visulize the last frame
        ax1.imshow(y_pre)
#         ax1.xticks(np.arange(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'])
#         ax2 = pyplot.subplot(122,sharey=ax1)
        y_truth = y[ind,0,:,:,0]
        ax2.imshow(y_truth)
        
        y_3 = y[ind,0,:,:,4]
        ax3.imshow(y_3)
#         plt.title('Ground truth', fontsize=15)
        plt.text(2, -0.8, 'NEW SET, Ground truth Frame 1', fontsize=13)
    
        fig, (ax1, ax2, ax3)= plt.subplots(1, 3, sharey=True, sharex=True, figsize=(15, 5))
        
#         plt.xticks = [0, 1, 2,3,4,5,6,7,8]
#         plt.xticks(range(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'], rotation=30)
#         ax1 = pyplot.subplot(121)
        y_pre = y_hat[ind,1,:,:,0] #visulize the last frame
        ax1.imshow(y_pre)
#         ax1.xticks(np.arange(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'])
#         ax2 = pyplot.subplot(122,sharey=ax1)
        y_truth = y[ind,1,:,:,0]
        ax2.imshow(y_truth)
        
        y_3 = y[ind,0,:,:,4]
        ax3.imshow(y_3)
#         plt.title('Ground truth', fontsize=15)
        plt.text(2, -0.8, 'Ground truth Frame 2', fontsize=13)
    
    
        fig, (ax1, ax2,ax3)= plt.subplots(1, 3, sharey=True, sharex=True, figsize=(15, 5))
        
#         plt.xticks = [0, 1, 2,3,4,5,6,7,8]
#         plt.xticks(range(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'], rotation=30)
#         ax1 = pyplot.subplot(121)
        y_pre = y_hat[ind,2,:,:,0] #visulize the last frame
        ax1.imshow(y_pre)
#         ax1.xticks(np.arange(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'])
#         ax2 = pyplot.subplot(122,sharey=ax1)
        y_truth = y[ind,2,:,:,0]
        ax2.imshow(y_truth)
        
        y_3 = y[ind,0,:,:,4]
        ax3.imshow(y_3)
#         plt.title('Ground truth', fontsize=15)
        plt.text(2, -0.8, 'Ground truth Frame 3', fontsize=13)
    
        fig, (ax1, ax2, ax3)= plt.subplots(1, 3, sharey=True, sharex=True, figsize=(15, 5))
        
#         plt.xticks = [0, 1, 2,3,4,5,6,7,8]
#         plt.xticks(range(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'], rotation=30)
#         ax1 = pyplot.subplot(121)
        y_pre = y_hat[ind,3,:,:,0] #visulize the last frame
        ax1.imshow(y_pre)

#         ax1.xticks(np.arange(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'])
#         ax2 = pyplot.subplot(122,sharey=ax1)
        y_truth = y[ind,3,:,:,0]
        ax2.imshow(y_truth)
        
        y_3 = y[ind,0,:,:,4]
        ax3.imshow(y_3)
#         plt.title('Ground truth', fontsize=15)
        plt.text(2, -0.8, 'Ground truth Frame 4', fontsize=13)
    
        fig, (ax1, ax2,ax3)= plt.subplots(1, 3, sharey=True, sharex=True, figsize=(15, 5))
        
#         plt.xticks = [0, 1, 2,3,4,5,6,7,8]
#         plt.xticks(range(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'], rotation=30)
#         ax1 = pyplot.subplot(121)
        y_pre = y_hat[ind,4,:,:,0] #visulize the last frame
        ax1.imshow(y_pre)
#         ax1.xticks(np.arange(9), ['co', 'no2', 'o3', 'pm10', 'pm2.5', 'so2', 'pres', 'temp', 'humi'])
#         ax2 = pyplot.subplot(122,sharey=ax1)
        y_truth = y[ind,4,:,:,0]
        ax2.imshow(y_truth)
        
        y_3 = y[ind,0,:,:,4]
        ax3.imshow(y_3)
#         plt.title('Ground truth', fontsize=15)
        plt.text(2, -0.8, 'Ground truth Frame 5', fontsize=13)

# %%
import math
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
from skimage.metrics import mean_squared_error as mse
from skimage import data, img_as_float
def compare_single_frame(frameA, frameB):
    #(thresh, img_bwA) = cv2.threshold(frameA, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    #(thresh, img_bwB) = cv2.threshold(frameB, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    m = mse(frameA,frameB)
    s = ssim(frameA,frameB)
    
    fig, axs = plt.subplots(1,2, constrained_layout=True)
    axs[0].imshow(frameA)
    axs[0].set_title("Predicted")
    axs[1].imshow(frameB)
    axs[1].set_title("Ground Truth")
    print("SSIM: ", s)
    print("RMSE: ", math.sqrt(m))
    plt.show()

# %%
compare_single_frame(Y_hat_grid[3,0,:,:,0], y_test[3,0,:,:,5])
# Out:
# SSIM:  0.06076296494848875
# RMSE:  8.785447611278972
# C:\Users\praty\.conda\envs\tests\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   # Remove the CWD from sys.path while we load stuff.

# %%
compare_single_frame(Y_hat_grid[3,0,:,:,0], y_test[3,0,:,:,4])
# Out:
# SSIM:  0.23736548371227617
# RMSE:  7.205959387165956
# C:\Users\praty\.conda\envs\tests\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   # Remove the CWD from sys.path while we load stuff.

# %%
compare_single_frame(Y_hat_grid[3,0,:,:,0], y_test[3,0,:,:,-1])
# Out:
# SSIM:  0.0607637693214202
# RMSE:  8.785439634464156
# C:\Users\praty\.conda\envs\tests\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### validation

# %%
label = []
for i in range(160):
    idx = 0
    sensors = np.zeros(4)
    for x in range(frames[i].shape[0]):
        for y in range(frames[i].shape[1]):
            if frames[i][x,y] != 0:
                sensors[idx] = frames[i][x,y]
                idx += 1
    label.append(sensors)
label = np.array(label)

# %%
v_train = label[5:125]
v_test = label[125:155]

# %%
val = Sequential()

val.add(ConvLSTM2D(filters=15, kernel_size=(3, 3),
                   input_shape=(5, 30, 30, 7),
                   padding='same', return_sequences=True))

val.add(ConvLSTM2D(filters=30, kernel_size=(3, 3),
                   padding='same', return_sequences=True))

val.add(ConvLSTM2D(filters=45, kernel_size=(3, 3),
                   padding='same', return_sequences=True))

val.add(Conv3D(filters=45, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))

val.add(Conv3D(filters=15, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))

val.add(Conv3D(filters=1, kernel_size=(3, 3, 3),
               activation='relu',
               padding='same', data_format='channels_last'))
val.add(Flatten())
val.add(Dense(4,activation='relu'))
val.compile(loss='mean_absolute_error', optimizer='adam')

# %%
val.fit(X_train, v_train, batch_size=16, epochs=150)
# Out:
# Epoch 1/150
# 8/8 [==============================] - 6s 162ms/step - loss: 1.0296
# Epoch 2/150
# 8/8 [==============================] - 1s 158ms/step - loss: 0.9651
# Epoch 3/150
# 8/8 [==============================] - 1s 158ms/step - loss: 1.0067
# Epoch 4/150
# 8/8 [==============================] - 1s 157ms/step - loss: 1.0091
# Epoch 5/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9851
# Epoch 6/150
# 8/8 [==============================] - 1s 156ms/step - loss: 1.0995
# Epoch 7/150
# 8/8 [==============================] - 1s 153ms/step - loss: 1.0253
# Epoch 8/150
# 8/8 [==============================] - 1s 149ms/step - loss: 1.0011
# Epoch 9/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.9945
# Epoch 10/150
# 8/8 [==============================] - 1s 148ms/step - loss: 1.0972
# Epoch 11/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.9924
# Epoch 12/150
# 8/8 [==============================] - 1s 157ms/step - loss: 1.0235
# Epoch 13/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.9525
# Epoch 14/150
# 8/8 [==============================] - 1s 160ms/step - loss: 1.0229
# Epoch 15/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9876
# Epoch 16/150
# 8/8 [==============================] - 1s 154ms/step - loss: 1.0462
# Epoch 17/150
# 8/8 [==============================] - 1s 149ms/step - loss: 1.0450
# Epoch 18/150
# 8/8 [==============================] - 1s 155ms/step - loss: 1.0064
# Epoch 19/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.9896
# Epoch 20/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.9432
# Epoch 21/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.9578
# Epoch 22/150
# 8/8 [==============================] - 1s 166ms/step - loss: 0.9942
# Epoch 23/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9875
# Epoch 24/150
# 8/8 [==============================] - 1s 158ms/step - loss: 0.9827
# Epoch 25/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9898
# Epoch 26/150
# 8/8 [==============================] - 1s 153ms/step - loss: 1.0966
# Epoch 27/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.9683
# Epoch 28/150
# 8/8 [==============================] - 1s 163ms/step - loss: 1.0303
# Epoch 29/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.9933
# Epoch 30/150
# 8/8 [==============================] - 1s 144ms/step - loss: 1.0022
# Epoch 31/150
# 8/8 [==============================] - 1s 155ms/step - loss: 1.0283
# Epoch 32/150
# 8/8 [==============================] - 1s 163ms/step - loss: 1.0260
# Epoch 33/150
# 8/8 [==============================] - 1s 153ms/step - loss: 1.0777
# Epoch 34/150
# 8/8 [==============================] - 1s 157ms/step - loss: 1.0002
# Epoch 35/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9567
# Epoch 36/150
# 8/8 [==============================] - 1s 154ms/step - loss: 1.0297
# Epoch 37/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9584
# Epoch 38/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.9095
# Epoch 39/150
# 8/8 [==============================] - 1s 152ms/step - loss: 1.0342
# Epoch 40/150
# 8/8 [==============================] - 1s 149ms/step - loss: 1.0012
# Epoch 41/150
# 8/8 [==============================] - 1s 162ms/step - loss: 0.9747
# Epoch 42/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.9433
# Epoch 43/150
# 8/8 [==============================] - 1s 144ms/step - loss: 0.9563
# Epoch 44/150
# 8/8 [==============================] - 1s 160ms/step - loss: 0.9621
# Epoch 45/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9609
# Epoch 46/150
# 8/8 [==============================] - 1s 164ms/step - loss: 0.9116
# Epoch 47/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.9209
# Epoch 48/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.9902
# Epoch 49/150
# 8/8 [==============================] - 1s 149ms/step - loss: 1.0492
# Epoch 50/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.9440
# Epoch 51/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.9426
# Epoch 52/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.9873
# Epoch 53/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9987
# Epoch 54/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9838
# Epoch 55/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.9975
# Epoch 56/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9161
# Epoch 57/150
# 8/8 [==============================] - 1s 165ms/step - loss: 0.9590
# Epoch 58/150
# 8/8 [==============================] - 1s 145ms/step - loss: 0.9022
# Epoch 59/150
# 8/8 [==============================] - 1s 145ms/step - loss: 0.9294
# Epoch 60/150
# 8/8 [==============================] - 1s 145ms/step - loss: 0.9625
# Epoch 61/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8547
# Epoch 62/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9588
# Epoch 63/150
# 8/8 [==============================] - 1s 159ms/step - loss: 1.0028
# Epoch 64/150
# 8/8 [==============================] - 1s 158ms/step - loss: 0.9214
# Epoch 65/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.8917
# Epoch 66/150
# 8/8 [==============================] - 1s 158ms/step - loss: 0.9291
# Epoch 67/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.9048
# Epoch 68/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.9189
# Epoch 69/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.9396
# Epoch 70/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9565
# Epoch 71/150
# 8/8 [==============================] - 1s 153ms/step - loss: 1.0684
# Epoch 72/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9258
# Epoch 73/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.9617
# Epoch 74/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.8899
# Epoch 75/150
# 8/8 [==============================] - 1s 165ms/step - loss: 0.8487
# Epoch 76/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9190
# Epoch 77/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.8840
# Epoch 78/150
# 8/8 [==============================] - 1s 143ms/step - loss: 0.8548
# Epoch 79/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.9212
# Epoch 80/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.8291
# Epoch 81/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.9206
# Epoch 82/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.9392
# Epoch 83/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.9026
# Epoch 84/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.9840
# Epoch 85/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.8455
# Epoch 86/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.8374
# Epoch 87/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.8855
# Epoch 88/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.8838
# Epoch 89/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8590
# Epoch 90/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8777
# Epoch 91/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.8992
# Epoch 92/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8693
# Epoch 93/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.8831
# Epoch 94/150
# 8/8 [==============================] - 1s 154ms/step - loss: 0.9138
# Epoch 95/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9488
# Epoch 96/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.9094
# Epoch 97/150
# 8/8 [==============================] - 1s 160ms/step - loss: 0.9396
# Epoch 98/150
# 8/8 [==============================] - 1s 172ms/step - loss: 0.8770
# Epoch 99/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8768
# Epoch 100/150
# 8/8 [==============================] - 1s 163ms/step - loss: 0.9207
# Epoch 101/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.9048
# Epoch 102/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8588
# Epoch 103/150
# 8/8 [==============================] - 1s 161ms/step - loss: 0.8469
# Epoch 104/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8511
# Epoch 105/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.8633
# Epoch 106/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.9224
# Epoch 107/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.8970
# Epoch 108/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.8644
# Epoch 109/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8311
# Epoch 110/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.9215
# Epoch 111/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.8760
# Epoch 112/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8660
# Epoch 113/150
# 8/8 [==============================] - 1s 160ms/step - loss: 0.8615
# Epoch 114/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.8521
# Epoch 115/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.8309
# Epoch 116/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.9670
# Epoch 117/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8712
# Epoch 118/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.8434
# Epoch 119/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.8997
# Epoch 120/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8178
# Epoch 121/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.8756
# Epoch 122/150
# 8/8 [==============================] - 1s 152ms/step - loss: 0.7519
# Epoch 123/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8927
# Epoch 124/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.8562
# Epoch 125/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8775
# Epoch 126/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.8080
# Epoch 127/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.9058
# Epoch 128/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.8666
# Epoch 129/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.8350
# Epoch 130/150
# 8/8 [==============================] - 1s 145ms/step - loss: 0.8200
# Epoch 131/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.8714
# Epoch 132/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.8827
# Epoch 133/150
# 8/8 [==============================] - 1s 158ms/step - loss: 0.8155
# Epoch 134/150
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8631
# Epoch 135/150
# 8/8 [==============================] - 1s 147ms/step - loss: 0.8279
# Epoch 136/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.8890
# Epoch 137/150
# 8/8 [==============================] - 1s 165ms/step - loss: 0.8923
# Epoch 138/150
# 8/8 [==============================] - 1s 153ms/step - loss: 0.8817
# Epoch 139/150
# 8/8 [==============================] - 1s 150ms/step - loss: 0.8457
# Epoch 140/150
# 8/8 [==============================] - 1s 151ms/step - loss: 0.8390
# Epoch 141/150
# 8/8 [==============================] - 1s 159ms/step - loss: 0.8540
# Epoch 142/150
# 8/8 [==============================] - 1s 156ms/step - loss: 0.8261
# Epoch 143/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.8529
# Epoch 144/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.8007
# Epoch 145/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.8349
# Epoch 146/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.8959
# Epoch 147/150
# 8/8 [==============================] - 1s 146ms/step - loss: 0.8737
# Epoch 148/150
# 8/8 [==============================] - 1s 155ms/step - loss: 0.8183
# Epoch 149/150
# 8/8 [==============================] - 1s 148ms/step - loss: 0.8288
# Epoch 150/150
# 8/8 [==============================] - 1s 157ms/step - loss: 0.8151

# %%
v_hat = val.predict(X_test, verbose=0)
v_test.shape
# Out:
# (30, 4)

# %%
from skimage.metrics import mean_squared_error as mse
import math
print("Input: TROPOMI Data + MAIAC Data + GCN Embeddings + Fire/Smoke Data + Previous PM2.5 Sensor data")
print("Output: Future PM2.5 Sensor data at 4 Locations in Durban Hourly (Using 24 previous frames to predict 24 future frames) \n")
print("RESULTS")
print("---------------------------------------------------------------------------")

print("All Days All Locations -  Y_hat vs y_test Raw RMSE: ", math.sqrt(mserr(v_hat,v_test)))
print("All Days All Locations - Y_hat vs y_test RMSE Percent Error of Mean: ", (math.sqrt(mserr(v_hat,v_test))/average(y_test))*100, "%\n")
print("---------------------------------------------------------------------------")

for i in range(24):
    print("Frame " + str((i+1)) + " (Hour " + str((i+1)) + ") All Locations - Raw RMSE: ", math.sqrt(mserr(v_hat[i,:],v_test[i,:])))
    print("Frame " + str((i+1)) + " (Hour " + str((i+1)) + ") All Locations - RMSE Percent Error of Mean: ", (math.sqrt(mserr(v_hat[i,:],v_test[i,:]))/average(y_test[i,:]))*100, "%\n")

print("---------------------------------------------------------------------------")

names = ["Durban City Hall", "New Germany", "Settlers", "Wentworth"]
for i in range(4):
    print("All Days - ", names[i] , " Raw RMSE: ", math.sqrt(mserr(v_hat[:,i],v_test[:,i])))
    print("All Days - ", names[i]," RMSE Percent Error of Mean: ", (math.sqrt(mserr(v_hat[:,i],v_test[:,i]))/average(v_test[:,i]))*100, "%\n")
# Out:
# Input: TROPOMI Data + MAIAC Data + GCN Embeddings + Fire/Smoke Data + Previous PM2.5 Sensor data
# Output: Future PM2.5 Sensor data at 4 Locations in Durban Hourly (Using 24 previous frames to predict 24 future frames)
#
# RESULTS
# ---------------------------------------------------------------------------
# All Days All Locations -  Y_hat vs y_test Raw RMSE:  0.6750410137247396
# All Days All Locations - Y_hat vs y_test RMSE Percent Error of Mean:  4.550674718004505 %
#
# ---------------------------------------------------------------------------
# Frame 1 (Hour 1) All Locations - Raw RMSE:  0.6764354688653006
# Frame 1 (Hour 1) All Locations - RMSE Percent Error of Mean:  4.734197016504837 %
#
# Frame 2 (Hour 2) All Locations - Raw RMSE:  0.6721499181241928
# Frame 2 (Hour 2) All Locations - RMSE Percent Error of Mean:  4.626922166868126 %
#
# Frame 3 (Hour 3) All Locations - Raw RMSE:  0.6764354688653006
# Frame 3 (Hour 3) All Locations - RMSE Percent Error of Mean:  4.516080510241537 %
#
# Frame 4 (Hour 4) All Locations - Raw RMSE:  0.683625902554664
# Frame 4 (Hour 4) All Locations - RMSE Percent Error of Mean:  4.609268157685624 %
#
# Frame 5 (Hour 5) All Locations - Raw RMSE:  0.683625902554664
# Frame 5 (Hour 5) All Locations - RMSE Percent Error of Mean:  4.482317746661368 %
#
# Frame 6 (Hour 6) All Locations - Raw RMSE:  0.6711153379874647
# Frame 6 (Hour 6) All Locations - RMSE Percent Error of Mean:  4.382306489197481 %
#
# Frame 7 (Hour 7) All Locations - Raw RMSE:  0.6712796479689883
# Frame 7 (Hour 7) All Locations - RMSE Percent Error of Mean:  4.270476681074721 %
#
# Frame 8 (Hour 8) All Locations - Raw RMSE:  0.6764354688653006
# Frame 8 (Hour 8) All Locations - RMSE Percent Error of Mean:  4.303532862214576 %
#
# Frame 9 (Hour 9) All Locations - Raw RMSE:  0.6708249259901565
# Frame 9 (Hour 9) All Locations - RMSE Percent Error of Mean:  4.276406199646492 %
#
# Frame 10 (Hour 10) All Locations - Raw RMSE:  0.6721499181241928
# Frame 10 (Hour 10) All Locations - RMSE Percent Error of Mean:  4.291756913362933 %
#
# Frame 11 (Hour 11) All Locations - Raw RMSE:  0.6708249259901565
# Frame 11 (Hour 11) All Locations - RMSE Percent Error of Mean:  4.29623935210955 %
#
# Frame 12 (Hour 12) All Locations - Raw RMSE:  0.67392523916729
# Frame 12 (Hour 12) All Locations - RMSE Percent Error of Mean:  4.33956054419435 %
#
# Frame 13 (Hour 13) All Locations - Raw RMSE:  0.6708249259901565
# Frame 13 (Hour 13) All Locations - RMSE Percent Error of Mean:  4.338404556221808 %
#
# Frame 14 (Hour 14) All Locations - Raw RMSE:  0.67392523916729
# Frame 14 (Hour 14) All Locations - RMSE Percent Error of Mean:  4.3798159652674835 %
#
# Frame 15 (Hour 15) All Locations - Raw RMSE:  0.6711153379874647
# Frame 15 (Hour 15) All Locations - RMSE Percent Error of Mean:  4.3917919948008315 %
#
# Frame 16 (Hour 16) All Locations - Raw RMSE:  0.6764354688653006
# Frame 16 (Hour 16) All Locations - RMSE Percent Error of Mean:  4.466929041133922 %
#
# Frame 17 (Hour 17) All Locations - Raw RMSE:  0.67392523916729
# Frame 17 (Hour 17) All Locations - RMSE Percent Error of Mean:  4.4908236175105385 %
#
# Frame 18 (Hour 18) All Locations - Raw RMSE:  0.6936308858091161
# Frame 18 (Hour 18) All Locations - RMSE Percent Error of Mean:  4.677969050244212 %
#
# Frame 19 (Hour 19) All Locations - Raw RMSE:  0.6796724645675658
# Frame 19 (Hour 19) All Locations - RMSE Percent Error of Mean:  4.69322113114856 %
#
# Frame 20 (Hour 20) All Locations - Raw RMSE:  0.6796724645675658
# Frame 20 (Hour 20) All Locations - RMSE Percent Error of Mean:  4.769147684163614 %
#
# Frame 21 (Hour 21) All Locations - Raw RMSE:  0.6721499181241928
# Frame 21 (Hour 21) All Locations - RMSE Percent Error of Mean:  4.747879258435354 %
#
# Frame 22 (Hour 22) All Locations - Raw RMSE:  0.6882834373977113
# Frame 22 (Hour 22) All Locations - RMSE Percent Error of Mean:  4.861127853791863 %
#
# Frame 23 (Hour 23) All Locations - Raw RMSE:  0.6708249259901565
# Frame 23 (Hour 23) All Locations - RMSE Percent Error of Mean:  4.862002902789193 %
#
# Frame 24 (Hour 24) All Locations - Raw RMSE:  0.6708249259901565
# Frame 24 (Hour 24) All Locations - RMSE Percent Error of Mean:  4.739799635773783 %
#
# ---------------------------------------------------------------------------
# All Days -  Durban City Hall  Raw RMSE:  0.6875474389757378
# All Days -  Durban City Hall  RMSE Percent Error of Mean:  5.459325384911369 %
#
# All Days -  New Germany  Raw RMSE:  0.6708203932499369
# All Days -  New Germany  RMSE Percent Error of Mean:  5.478768321218041 %
#
# All Days -  Settlers  Raw RMSE:  0.6708203932499369
# All Days -  Settlers  RMSE Percent Error of Mean:  5.478768321218041 %
#
# All Days -  Wentworth  Raw RMSE:  0.6708203932499369
# All Days -  Wentworth  RMSE Percent Error of Mean:  5.478768321218041 %

# %%
def best_fit(X, Y):

    xbar = sum(X)/len(X)
    ybar = sum(Y)/len(Y)
    n = len(X) # or len(Y)

    numer = sum([xi*yi for xi,yi in zip(X, Y)]) - n * xbar * ybar
    denum = sum([xi**2 for xi in X]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    return a, b

# %%
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
line = mlines.Line2D([0, 1], [0, 1], color='black', linestyle = "dashed")
transform = ax.transAxes
line.set_transform(transform)
ax.add_line(line)
labels = ["Durban City Hall", "New Germany", "Settlers", "Wentworth"]
a, b = best_fit(X, Y)
print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))
yfit = [a + b * xi for xi in X]
ax.plot(X, yfit)
ax.scatter(X, Y, color = "red")
for i, txt in enumerate(labels):
    if txt == "Reseda":
        ax.annotate(txt, (X[i], Y[i]), xytext = (X[i]-1,Y[i]-1), horizontalalignment='left',
            verticalalignment='bottom')
    else:
        ax.annotate(txt, (X[i], Y[i]), xytext = (X[i],Y[i]), horizontalalignment='left',
            verticalalignment='bottom')
ax.set_xlabel("Observed PM2.5 (ug/m^3)")
ax.set_ylabel("Estimated PM2.5 (ug/m^3)")
ax.set_xlim((5, 21))
ax.set_ylim((5, 21))
#plt.savefig("linePlot.eps")
# Out:
# best fit line:
# y = 0.16 + 0.96x
# (5.0, 21.0)

# %%
np.save("durbanPredictions.npy", Y_hat_grid)
